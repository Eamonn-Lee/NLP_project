# %%
import pandas as pd
df = pd.read_csv('../DATASETS/salary_labelled_development_set.csv')
df.head()
# Out:
#      job_id                                          job_title  \
# 0  72000415  Financial Account - Call Center Agent - Up to 34k
# 1  69481519  Aspiring Call Center Agents - Work from Home -...
# 2  55838599  Production Staff Required - Afternoon & Night-...
# 3  64369104                                      Payer Analyst
# 4  54861511            Solicitor, Restructuring (ID: 2100013K)
#
#                                       job_ad_details nation_short_desc  \
# 0  <div><div><div>\n \n Job Opening \n \n <p>\n F...                PH
# 1  <div><div>\n <div>\n <p><b>Job Opening</b></p>...                PH
# 2  <p>Original Foods Baking Co. is one of New Zea...                NZ
# 3  <div> </div><div> </div>The Payer Analyst indi...                PH
# 4  <p>The DLA Piper team operates across more tha...               AUS
#
#   salary_additional_text                   y_true
# 0                    NaN  17500-17500-PHP-MONTHLY
# 1                    NaN  16000-16000-PHP-MONTHLY
# ...

# %%
df.info()
df.describe()
df['y_true'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2267 entries, 0 to 2266
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   job_id                  2267 non-null   int64
#  1   job_title               2267 non-null   object
#  2   job_ad_details          2267 non-null   object
#  3   nation_short_desc       2267 non-null   object
#  4   salary_additional_text  973 non-null    object
#  5   y_true                  2267 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 106.4+ KB
# array(['17500-17500-PHP-MONTHLY', '16000-16000-PHP-MONTHLY',
#        '0-0-None-None', '50-60-HKD-HOURLY', '32-32-NZD-HOURLY',
#        '2800-3200-MYR-MONTHLY', '65-65-HKD-HOURLY', '28-30-NZD-HOURLY',
#        '35-35-AUD-HOURLY', '6000-6000-MYR-MONTHLY', '65-75-HKD-HOURLY',
#        '100-100-HKD-HOURLY', '1700-3500-MYR-MONTHLY',
#        '67357-94568-AUD-ANNUAL', '4000-6000-SGD-MONTHLY',
# ...

# %%
import pandas as pd

# 加载开发集数据
dev_df = pd.read_csv('../DATASETS/salary_labelled_development_set.csv', encoding='utf-8')
# 查看前几行数据
print(dev_df.head())

# 查看数据信息（如总行数、数据类型、缺失值）
print(dev_df.info())
# Out:
#      job_id                                          job_title  \
# 0  72000415  Financial Account - Call Center Agent - Up to 34k
# 1  69481519  Aspiring Call Center Agents - Work from Home -...
# 2  55838599  Production Staff Required - Afternoon & Night-...
# 3  64369104                                      Payer Analyst
# 4  54861511            Solicitor, Restructuring (ID: 2100013K)
#
#                                       job_ad_details nation_short_desc  \
# 0  <div><div><div>\n \n Job Opening \n \n <p>\n F...                PH
# 1  <div><div>\n <div>\n <p><b>Job Opening</b></p>...                PH
# 2  <p>Original Foods Baking Co. is one of New Zea...                NZ
# 3  <div> </div><div> </div>The Payer Analyst indi...                PH
# 4  <p>The DLA Piper team operates across more tha...               AUS
#
#   salary_additional_text                   y_true
# 0                    NaN  17500-17500-PHP-MONTHLY
# 1                    NaN  16000-16000-PHP-MONTHLY
# ...

# %%
# 查看薪水字段的一些样本
print(dev_df['y_true'].dropna().unique()[:10])

# 查看薪水信息的描述性统计（如数值统计，如果能够转换为数值）
print(dev_df['y_true'].describe())

# 如果薪水信息包含文本数据，可以先计算每条描述的长度，了解是否存在特别短或异常长的数据条目
dev_df['salary_length'] = dev_df['y_true'].astype(str).apply(len)
print(dev_df['salary_length'].describe())
# Out:
# ['17500-17500-PHP-MONTHLY' '16000-16000-PHP-MONTHLY' '0-0-None-None'
#  '50-60-HKD-HOURLY' '32-32-NZD-HOURLY' '2800-3200-MYR-MONTHLY'
#  '65-65-HKD-HOURLY' '28-30-NZD-HOURLY' '35-35-AUD-HOURLY'
#  '6000-6000-MYR-MONTHLY']
# count              2267
# unique              734
# top       0-0-None-None
# freq                950
# Name: y_true, dtype: object
# count    2267.000000
# mean       16.637406
# std         3.858139
# min        13.000000
# 25%        13.000000
# 50%        16.000000
# 75%        21.000000
# max        29.000000
# Name: salary_length, dtype: float64

# %%
from bs4 import BeautifulSoup

def clean_html_tags(html_text):
    soup = BeautifulSoup(html_text, 'html.parser')
    return soup.get_text()

dev_df['cleaned_ad_text'] = dev_df['job_ad_details'].astype(str).apply(clean_html_tags)
print(dev_df[['job_ad_details', 'cleaned_ad_text']].head())
# Out:
#                                       job_ad_details  \
# 0  <div><div><div>\n \n Job Opening \n \n <p>\n F...
# 1  <div><div>\n <div>\n <p><b>Job Opening</b></p>...
# 2  <p>Original Foods Baking Co. is one of New Zea...
# 3  <div> </div><div> </div>The Payer Analyst indi...
# 4  <p>The DLA Piper team operates across more tha...
#
#                                      cleaned_ad_text
# 0  \n \n Job Opening \n \n \n Financial Account -...
# 1  \n\nJob Opening\n\nAspiring Call Center Agents...
# 2  Original Foods Baking Co. is one of New Zealan...
# 3    The Payer Analyst individual is assigned to ...
# 4  The DLA Piper team operates across more than 4...

# %%
from transformers import BertTokenizer, BertModel

# 加载多语言模型和分词器
model_name = "bert-base-multilingual-cased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(119547, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
# ...

# %%
from tqdm.notebook import tqdm
import pandas as pd
tqdm.pandas()

df_test = pd.DataFrame({"A": range(1000)})
df_test['A'].progress_apply(lambda x: x)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Name: A, Length: 1000, dtype: int64

# %%
# %%
import re
import torch
import pandas as pd
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity

df = pd.read_csv('../DATASETS/salary_labelled_development_set.csv', encoding='utf-8')
print(df.info())
display(df.head())


def clean_text(text):
    """
    去除 HTML 标签及多余空格，保留中英文及标点符号
    """
    if pd.isna(text):
        return ""
    # 去除 HTML 标签
    cleaned = re.sub(r'<[^>]+>', '', text)
    # 替换多个空白字符为单个空格
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    return cleaned

df['cleaned_ad_details'] = df['job_ad_details'].apply(clean_text)


model_name = "bert-base-multilingual-cased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
model.eval()  # 切换到评估模式

def extract_salary_rule(text):
    """
    针对薪水格式的规则提取：
    尝试匹配 8000-12000、8000 ~ 12000、8000～12000 或 “月薪8000”等格式
    """
    # 匹配数字区间，例如 "8000-12000"
    pattern_range = r'(\d{3,6}\s*[-~～]\s*\d{3,6})(元|PHP|人民币)?'
    # 匹配单个数字，例如 "月薪8000" 或 "8000元"
    pattern_single = r'(\d{3,6})(元|PHP|人民币)'

    match = re.search(pattern_range, text)
    if match:
        return match.group(1).strip()
    else:
        match = re.search(pattern_single, text)
        if match:
            return match.group(1).strip()
    return ""


def get_keyword_embedding(keyword):
    """
    使用 BERT 得到关键字（例如 '联系方式' 或 'contact'）的向量表示（平均池化）
    """
    inputs_kw = tokenizer(keyword, return_tensors="pt")
    with torch.no_grad():
        outputs_kw = model(**inputs_kw)
    return outputs_kw.last_hidden_state.mean(dim=1)  # shape (1, hidden_dim)

def extract_contact_candidate(last_hidden_states, tokens, keyword, sim_threshold=0.5):
    """
    计算广告文本中每个 token 与关键字之间的余弦相似度，
    返回所有相似度超过阈值的 token 的拼接结果作为候选输出。
    """
    kw_vector = get_keyword_embedding(keyword)
    token_vectors = last_hidden_states.squeeze(0)  # shape: (seq_length, hidden_dim)
    sims = cosine_similarity(token_vectors.numpy(), kw_vector.numpy()).squeeze()  # shape: (seq_length,)
    candidate_indices = [i for i, sim in enumerate(sims) if sim > sim_threshold]
    candidate_tokens = [tokens[i] for i in candidate_indices]
    # 这里简单拼接 token，实际情况中可以结合上下文进行更精细的抽取
    return "".join(candidate_tokens)

# %%
# 6. 构建完整的广告信息提取函数
def extract_ad_info(ad_text):
    """
    输入原始广告文本，返回一个字典：
    - 'salary': 利用正则规则提取的薪水信息
    - 'contact_candidate': 通过 BERT 表示与关键字匹配提取的候选联系方式（可扩展其他信息）
    """
    # 清洗文本
    cleaned = clean_text(ad_text)

    # 规则提取薪水信息
    salary_info = extract_salary_rule(cleaned)

    # 获取 BERT 表示
    inputs = tokenizer(cleaned, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    last_hidden_states = outputs.last_hidden_state
    tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"].squeeze().tolist())

    # 这里设定中英文都考虑，如 '联系方式' 和 'contact'
    contact_candidate_zh = extract_contact_candidate(last_hidden_states, tokens, "联系方式", sim_threshold=0.5)
    contact_candidate_en = extract_contact_candidate(last_hidden_states, tokens, "contact", sim_threshold=0.5)
    contact_candidate = contact_candidate_zh + " / " + contact_candidate_en if (contact_candidate_zh or contact_candidate_en) else ""

    return {
        "salary_extracted": salary_info,
        "contact_candidate": contact_candidate
    }

# %%
# 7. 对 DataFrame 中的广告进行批量信息提取，并添加进度条显示
from tqdm.notebook import tqdm
tqdm.pandas()  # 为 pandas DataFrame 增加 progress_apply 方法

# 对 job_ad_details 列应用提取函数，显示处理进度
extracted_info = df['cleaned_ad_details'].progress_apply(extract_ad_info)

# 将提取结果转换为 DataFrame 格式，再与原 DataFrame 合并
info_df = pd.json_normalize(extracted_info)
df = pd.concat([df, info_df], axis=1)
# Out:
# 数据集基本信息：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2267 entries, 0 to 2266
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   job_id                  2267 non-null   int64
#  1   job_title               2267 non-null   object
#  2   job_ad_details          2267 non-null   object
#  3   nation_short_desc       2267 non-null   object
#  4   salary_additional_text  973 non-null    object
#  5   y_true                  2267 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 106.4+ KB
# None
#      job_id                                          job_title  \
# 0  72000415  Financial Account - Call Center Agent - Up to 34k
# 1  69481519  Aspiring Call Center Agents - Work from Home -...
# 2  55838599  Production Staff Required - Afternoon & Night-...
# 3  64369104                                      Payer Analyst
# ...
