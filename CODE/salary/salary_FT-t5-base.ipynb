# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration, Seq2SeqTrainingArguments, Seq2SeqTrainer, DataCollatorForSeq2Seq, EarlyStoppingCallback
from datasets import Dataset
import pandas as pd
import re
from bs4 import BeautifulSoup
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

df = pd.read_csv('../../MISC/salary_labelled_development_set.csv', encoding='utf-8')
df.columns = ["job_id", "job_title", "job_ad_details", "nation_short_desc", "salary_additional_text", "y_true"]
df = df[df['y_true'].notna()]
df['y_true'] = (
    df['y_true']
    .fillna("0-0-None-None")
    .str.strip()
    .str.replace(
        r'(\d+)-(\d+)-([A-Za-z]+)-([A-Za-z]+)',
        r'\1 \2 \3 \4',
        regex=True
    )
)

def clean_html_tags(html_text):
    soup = BeautifulSoup(html_text, 'html.parser')
    for tag in soup(["script", "style"]):
        tag.decompose()
    return soup.get_text(separator="\n", strip=True)

examples = []
for _, row in df.iterrows():
    context = str(row["job_ad_details"])
    question = (
        "Extract the salary info from the job ad below and return it as: "
        '"MinimumSalary MaximumSalary Currency PayPeriod"'
    )
    input_text = f"{question}\n\n{clean_html_tags(context)}"
    output_text = row["y_true"] if row["y_true"] else "0 0 None None"
    examples.append({"input_text": input_text, "target_text": output_text})

dataset = Dataset.from_list(examples)
split = dataset.train_test_split(test_size=0.1, seed=42)
train_dataset = split["train"]
eval_dataset = split["test"]


model_name = "t5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)


max_input_length = 512
max_target_length = 32

def preprocess(example):
    model_inputs = tokenizer(example["input_text"], max_length=max_input_length, padding="max_length", truncation=True)
    labels = tokenizer(example["target_text"], max_length=max_target_length, padding="max_length", truncation=True)
    labels["input_ids"] = [l if l != tokenizer.pad_token_id else -100 for l in labels["input_ids"]]
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

FORMAT_RE = re.compile(r'^\s*\d+\s+\d+\s+[A-Za-z]+\s+[A-Za-z]+\s*$')
PARSE_RE  = re.compile(r'^\s*(\d+)\s+(\d+)\s+([A-Za-z]+)\s+([A-Za-z]+)\s*$')

def validate_pred(pred: str) -> str:
    return pred if FORMAT_RE.match(pred) else "0 0 None None"

def parse_salary(s: str):
    m = PARSE_RE.match(s)
    if not m:
        return None
    return (
        int(m.group(1)),
        int(m.group(2)),
        m.group(3).lower(),
        m.group(4).lower()
    )

def compute_metrics(eval_preds):
    preds_ids, labels_ids = eval_preds
    vocab_size = tokenizer.vocab_size

    # 1. 过滤并解码预测 ID
    filtered_preds = []
    for seq in preds_ids:
        seq = seq.tolist() if hasattr(seq, "tolist") else seq
        filtered_preds.append([tok for tok in seq if 0 <= tok < vocab_size])

    filtered_labels = []
    for seq in labels_ids:
        seq = seq.tolist() if hasattr(seq, "tolist") else seq
        filtered_labels.append([
            tok if tok != -100 else tokenizer.pad_token_id
            for tok in seq
        ])

    decoded_preds  = tokenizer.batch_decode(filtered_preds, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(filtered_labels, skip_special_tokens=True)

    preds = [validate_pred(p.strip()) for p in decoded_preds]
    trues = [l.strip() for l in decoded_labels]

    parsed_preds = [parse_salary(p.lower()) for p in preds]
    parsed_trues = [parse_salary(t.lower()) for t in trues]

    default = (0, 0, 'none', 'none')
    TP = FP = FN = TN = 0

    for p, t in zip(parsed_preds, parsed_trues):
        is_def_p = (p == default)
        is_def_t = (t == default)
        match    = (
            p is not None and t is not None
            and not is_def_p and not is_def_t
            and p[0] == t[0]
            and p[1] == t[1]
            and p[2] == t[2]
            and p[3] == t[3]
        )

        if match:
            TP += 1
        elif not is_def_p:
            FP += 1
        elif not is_def_t:
            FN += 1
        else:
            TN += 1

    precision = TP / (TP+FP) if TP+FP else 0.0
    recall    = TP / (TP+FN) if TP+FN else 0.0
    f1        = 2*precision*recall/(precision+recall) if precision+recall else 0.0
    accuracy  = (TP+TN)/(TP+FP+FN+TN)

    return {"precision": precision,
            "recall":    recall,
            "f1":        f1,
            "accuracy":  accuracy}



tokenized_train = train_dataset.map(preprocess, batched=True)
tokenized_eval = eval_dataset.map(preprocess, batched=True)


data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    model=model,
    label_pad_token_id=-100
)

training_args = Seq2SeqTrainingArguments(
    output_dir="./t5-finetuned-salary",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    learning_rate=3e-5,
    weight_decay=0.01,
    num_train_epochs=15,

    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,

    predict_with_generate=True,
    generation_num_beams=4,
    generation_max_length=32,

    label_smoothing_factor=0.1,
    warmup_ratio=0.1,
    lr_scheduler_type="linear",

    logging_dir="./logs",
    logging_steps=50,
    save_total_limit=2,
    fp16=True,

    seed=42
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_eval,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    data_collator=DataCollatorForSeq2Seq(tokenizer, model),
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
)

trainer.train()
trainer.save_model("t5-finetuned-salary/best")
tokenizer.save_pretrained("t5-finetuned-salary/best")
best_ckpt = trainer.state.best_model_checkpoint
print("Best checkpoint dir:", best_ckpt)
best_dir = "./t5-finetuned-salary/best"
trainer.model.save_pretrained(best_dir)
tokenizer.save_pretrained(best_dir)

metrics = trainer.evaluate()
print(metrics)
# Out:
# Map:   0%|          | 0/2040 [00:00<?, ? examples/s]
# Map:   0%|          | 0/227 [00:00<?, ? examples/s]
# C:\Users\user\AppData\Local\Temp\ipykernel_41320\3099921007.py:181: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='2805' max='3825' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2805/3825 10:43 < 03:54, 4.35 it/s, Epoch 11/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.165200</td>
#       <td>1.828198</td>
#       <td>0.444444</td>
#       <td>0.067797</td>
#       <td>0.117647</td>
#       <td>0.471366</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.636600</td>
#       <td>1.543275</td>
#       <td>0.686441</td>
#       <td>0.880435</td>
#       <td>0.771429</td>
#       <td>0.788546</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.564300</td>
#       <td>1.500295</td>
#       <td>0.696721</td>
#       <td>0.913978</td>
#       <td>0.790698</td>
#       <td>0.801762</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.534100</td>
#       <td>1.487391</td>
#       <td>0.756098</td>
#       <td>0.930000</td>
#       <td>0.834081</td>
#       <td>0.837004</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.521900</td>
#       <td>1.476565</td>
#       <td>0.736000</td>
#       <td>0.938776</td>
#       <td>0.825112</td>
#       <td>0.828194</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.501600</td>
#       <td>1.468378</td>
#       <td>0.746032</td>
#       <td>0.949495</td>
#       <td>0.835556</td>
#       <td>0.837004</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.491700</td>
#       <td>1.458851</td>
#       <td>0.770492</td>
#       <td>0.930693</td>
#       <td>0.843049</td>
#       <td>0.845815</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.483400</td>
#       <td>1.462233</td>
#       <td>0.801653</td>
#       <td>0.932692</td>
#       <td>0.862222</td>
#       <td>0.863436</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.483200</td>
#       <td>1.453942</td>
#       <td>0.772358</td>
#       <td>0.950000</td>
#       <td>0.852018</td>
#       <td>0.854626</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.476000</td>
#       <td>1.452573</td>
#       <td>0.772358</td>
#       <td>0.950000</td>
#       <td>0.852018</td>
#       <td>0.854626</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.480000</td>
#       <td>1.448949</td>
#       <td>0.764228</td>
#       <td>0.949495</td>
#       <td>0.846847</td>
#       <td>0.850220</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight'].
# Best checkpoint dir: ./t5-finetuned-salary\checkpoint-2040
# {'eval_loss': 1.462233066558838, 'eval_precision': 0.8016528925619835, 'eval_recall': 0.9326923076923077, 'eval_f1': 0.8622222222222222, 'eval_accuracy': 0.8634361233480177, 'eval_runtime': 15.0191, 'eval_samples_per_second': 15.114, 'eval_steps_per_second': 1.931, 'epoch': 11.0}

# %%
pred_out = trainer.predict(tokenized_eval)

decoded_preds = tokenizer.batch_decode(
    pred_out.predictions, skip_special_tokens=True
)
decoded_labels = tokenizer.batch_decode(
    np.where(pred_out.label_ids != -100, pred_out.label_ids, tokenizer.pad_token_id),
    skip_special_tokens=True
)

default = (0, 0, 'none', 'none')
TP = FP = FN = TN = 0

print(" idx | Prediction                | True                       |Flag")
print("-" * 70)

for i, (raw_p, raw_t) in enumerate(zip(decoded_preds, decoded_labels)):
    p_str = validate_pred(raw_p.strip())
    t_str = raw_t.strip()

    p_parsed = parse_salary(p_str.lower())
    t_parsed = parse_salary(t_str.lower())

    is_def_pred = (p_parsed == default)
    is_def_true = (t_parsed == default)

    match = (
        not is_def_pred and not is_def_true
        and p_parsed[0] == t_parsed[0]
        and p_parsed[1] == t_parsed[1]
        and p_parsed[2] == t_parsed[2]
        and p_parsed[3] == t_parsed[3]
    )

    if match:
        TP += 1
    elif not is_def_pred and (is_def_true or not match):
        FP += 1
    elif is_def_pred and not is_def_true:
        FN += 1
    else:
        TN += 1

    flag = "✔" if p_str == t_str else "✘"
    print(f"[{i:3d}] | {p_str:<25} | {t_str:<25} | {flag}")

print("\n🔢 Confusion Matrix Counts:")
print(f"  TP: {TP}")
print(f"  FP: {FP}")
print(f"  FN: {FN}")
print(f"  TN: {TN}")

precision = TP / (TP + FP) if TP + FP else 0.0
recall    = TP / (TP + FN) if TP + FN else 0.0
f1        = 2 * precision * recall / (precision + recall) if precision + recall else 0.0
accuracy  = (TP + TN) / (TP + FP + FN + TN)

print("\n📊 Metrics:")
print(f"  Precision: {precision:.4f}")
print(f"  Recall:    {recall:.4f}")
print(f"  F1 Score:  {f1:.4f}")
print(f"  Accuracy:  {accuracy:.4f}")
# Out:
#  idx | Prediction                | True                       |Flag
# ----------------------------------------------------------------------
# [  0] | 0 0 None None             | 0 0 None None             | ✔
# [  1] | 0 0 None None             | 0 0 None None             | ✔
# [  2] | 65000 95000 THB MONTHLY   | 65000 95000 THB MONTHLY   | ✔
# [  3] | 67 100 SGD DAILY          | 67 100 SGD DAILY          | ✔
# [  4] | 0 0 None None             | 0 0 None None             | ✔
# [  5] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [  6] | 0 0 None None             | 0 0 None None             | ✔
# [  7] | 0 0 None None             | 50 100 SGD HOURLY         | ✘
# [  8] | 0 0 None None             | 0 0 None None             | ✔
# [  9] | 0 0 None None             | 0 0 None None             | ✔
# [ 10] | 0 0 None None             | 0 0 None None             | ✔
# [ 11] | 0 0 None None             | 0 0 None None             | ✔
# [ 12] | 18000 18000 PHP MONTHLY   | 18000 18000 PHP MONTHLY   | ✔
# [ 13] | 0 0 None None             | 0 0 None None             | ✔
# [ 14] | 95 95 HKD HOURLY          | 95 95 HKD HOURLY          | ✔
# [ 15] | 1500 1800 MYR MONTHLY     | 1500 1800 MYR MONTHLY     | ✔
# [ 16] | 0 0 None None             | 0 0 None None             | ✔
# [ 17] | 27000 27000 PHP MONTHLY   | 27000 27000 PHP MONTHLY   | ✔
# [ 18] | 0 0 None None             | 0 0 None None             | ✔
# [ 19] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [ 20] | 17500 17500 PHP MONTHLY   | 17500 17500 PHP MONTHLY   | ✔
# [ 21] | 0 0 None None             | 0 0 None None             | ✔
# [ 22] | 2500 3200 SGD MONTHLY     | 2500 3200 SGD MONTHLY     | ✔
# [ 23] | 0 0 None None             | 0 0 None None             | ✔
# [ 24] | 3400 3400 SGD MONTHLY     | 3400 3400 SGD MONTHLY     | ✔
# [ 25] | 0 0 None None             | 0 0 None None             | ✔
# [ 26] | 0 0 None None             | 0 0 None None             | ✔
# [ 27] | 150 180 AUD HOURLY        | 150 180 AUD HOURLY        | ✔
# [ 28] | 90 90 HKD HOURLY          | 90 90 HKD HOURLY          | ✔
# [ 29] | 25 30 AUD HOURLY          | 25 30 AUD HOURLY          | ✔
# [ 30] | 750 125 SGD DAILY         | 750 1125 HKD WEEKLY       | ✘
# [ 31] | 0 0 None None             | 0 0 None None             | ✔
# [ 32] | 0 0 None None             | 0 0 None None             | ✔
# [ 33] | 0 0 None None             | 0 0 None None             | ✔
# [ 34] | 41 41 AUD HOURLY          | 41 41 AUD HOURLY          | ✔
# [ 35] | 0 0 None None             | 0 0 None None             | ✔
# [ 36] | 0 0 None None             | 0 0 None None             | ✔
# [ 37] | 0 0 None None             | 0 0 None None             | ✔
# [ 38] | 70000 70000 AUD ANNUAL    | 70000 70000 AUD ANNUAL    | ✔
# [ 39] | 68 68 HKD HOURLY          | 68 68 HKD HOURLY          | ✔
# [ 40] | 0 0 None None             | 0 0 None None             | ✔
# [ 41] | 0 0 None None             | 0 0 None None             | ✔
# [ 42] | 0 0 None None             | 0 0 None None             | ✔
# [ 43] | 0 0 None None             | 0 0 None None             | ✔
# [ 44] | 1000 1500 SGD MONTHLY     | 1000 1500 SGD MONTHLY     | ✔
# [ 45] | 0 0 None None             | 0 0 None None             | ✔
# [ 46] | 0 0 None None             | 0 0 None None             | ✔
# [ 47] | 0 0 None None             | 0 0 None None             | ✔
# [ 48] | 0 0 None None             | 0 0 None None             | ✔
# [ 49] | 0 0 None None             | 25000 25000 PHP MONTHLY   | ✘
# [ 50] | 29 32 NZD HOURLY          | 29 32 NZD HOURLY          | ✔
# [ 51] | 2500 3000 MYR MONTHLY     | 2500 3000 MYR MONTHLY     | ✔
# [ 52] | 37 83 AUD HOURLY          | 37 84 AUD HOURLY          | ✘
# [ 53] | 70 75 HKD HOURLY          | 70 75 HKD HOURLY          | ✔
# [ 54] | 0 0 None None             | 0 0 None None             | ✔
# [ 55] | 0 0 None None             | 0 0 None None             | ✔
# [ 56] | 30 30 AUD HOURLY          | 30 30 AUD HOURLY          | ✔
# [ 57] | 1640 1640 SGD MONTHLY     | 1640 1640 SGD MONTHLY     | ✔
# [ 58] | 0 0 None None             | 0 0 None None             | ✔
# [ 59] | 0 0 None None             | 0 0 None None             | ✔
# [ 60] | 0 0 None None             | 0 0 None None             | ✔
# [ 61] | 43 43 AUD HOURLY          | 44 44 AUD HOURLY          | ✘
# [ 62] | 0 0 None None             | 0 0 None None             | ✔
# [ 63] | 0 0 None None             | 0 0 None None             | ✔
# [ 64] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [ 65] | 0 0 None None             | 0 0 None None             | ✔
# [ 66] | 45 45 AUD HOURLY          | 45 45 AUD HOURLY          | ✔
# [ 67] | 0 0 None None             | 0 0 None None             | ✔
# [ 68] | 60 60 AUD HOURLY          | 60 60 AUD HOURLY          | ✔
# [ 69] | 0 0 None None             | 0 0 None None             | ✔
# [ 70] | 65 75 HKD HOURLY          | 65 75 HKD HOURLY          | ✔
# [ 71] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [ 72] | 950 125 SGD DAILY         | 950 1125 HKD WEEKLY       | ✘
# [ 73] | 2200 3300 MYR MONTHLY     | 2200 3300 MYR MONTHLY     | ✔
# [ 74] | 35 37 AUD HOURLY          | 35 37 AUD HOURLY          | ✔
# [ 75] | 500 667 PHP DAILY         | 500 667 PHP DAILY         | ✔
# [ 76] | 90000 130000 AUD ANNUAL   | 90000 130000 AUD ANNUAL   | ✔
# [ 77] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [ 78] | 150 283 SGD DAILY         | 150 283 SGD DAILY         | ✔
# [ 79] | 100 100 HKD HOURLY        | 100 100 HKD HOURLY        | ✔
# [ 80] | 2000 2000 MYR MONTHLY     | 2000 2000 MYR MONTHLY     | ✔
# [ 81] | 875 875 SGD WEEKLY        | 875 875 SGD WEEKLY        | ✔
# [ 82] | 135000 150000 AUD ANNUAL  | 135000 150000 AUD ANNUAL  | ✔
# [ 83] | 800 800 SGD MONTHLY       | 800 800 SGD MONTHLY       | ✔
# [ 84] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [ 85] | 60000 60000 AUD ANNUAL    | 60000 60000 AUD ANNUAL    | ✔
# [ 86] | 90 100 HKD HOURLY         | 90 100 HKD HOURLY         | ✔
# [ 87] | 89095 139187 AUD ANNUAL   | 89095 139187 AUD ANNUAL   | ✔
# [ 88] | 30 35 AUD HOURLY          | 30 35 AUD HOURLY          | ✔
# [ 89] | 0 0 None None             | 28 28 NZD HOURLY          | ✘
# [ 90] | 12500 12500 PHP MONTHLY   | 12500 12500 PHP MONTHLY   | ✔
# [ 91] | 23 35 NZD HOURLY          | 24 36 NZD HOURLY          | ✘
# [ 92] | 30000 50000 THB MONTHLY   | 30000 50000 THB MONTHLY   | ✔
# [ 93] | 29 29 AUD HOURLY          | 30 30 AUD HOURLY          | ✘
# [ 94] | 65 70 HKD HOURLY          | 65 70 HKD HOURLY          | ✔
# [ 95] | 0 0 None None             | 0 0 None None             | ✔
# [ 96] | 0 0 None None             | 0 0 None None             | ✔
# [ 97] | 0 0 None None             | 0 0 None None             | ✔
# [ 98] | 0 0 None None             | 0 0 None None             | ✔
# [ 99] | 123 140 SGD DAILY         | 123 140 HKD DAILY         | ✘
# [100] | 0 0 None None             | 0 0 None None             | ✔
# [101] | 55 80 HKD HOURLY          | 55 80 HKD HOURLY          | ✔
# [102] | 35 42 AUD HOURLY          | 35 42 AUD HOURLY          | ✔
# [103] | 0 0 None None             | 0 0 None None             | ✔
# [104] | 0 0 None None             | 0 0 None None             | ✔
# [105] | 158194 160730 AUD ANNUAL  | 158194 160730 AUD ANNUAL  | ✔
# [106] | 1500 1800 MYR MONTHLY     | 1500 1800 MYR MONTHLY     | ✔
# [107] | 0 0 None None             | 0 0 None None             | ✔
# [108] | 100 250 THB HOURLY        | 100 250 THB HOURLY        | ✔
# [109] | 90 120 HKD HOURLY         | 90 120 HKD HOURLY         | ✔
# [110] | 0 0 None None             | 0 0 None None             | ✔
# [111] | 0 0 None None             | 0 0 None None             | ✔
# [112] | 0 0 None None             | 0 0 None None             | ✔
# [113] | 700 1000 SGD WEEKLY       | 700 1000 SGD WEEKLY       | ✔
# [114] | 31 32 AUD HOURLY          | 32 33 AUD HOURLY          | ✘
# [115] | 875 100 HKD WEEKLY        | 875 1000 SGD WEEKLY       | ✘
# [116] | 400 500 HKD HOURLY        | 400 500 THB HOURLY        | ✘
# [117] | 700 800 SGD MONTHLY       | 700 800 SGD WEEKLY        | ✘
# [118] | 26 30 AUD HOURLY          | 26 30 AUD HOURLY          | ✔
# [119] | 0 0 None None             | 0 0 None None             | ✔
# [120] | 23000 23000 PHP MONTHLY   | 23000 23000 PHP MONTHLY   | ✔
# [121] | 0 0 None None             | 0 0 None None             | ✔
# [122] | 0 0 None None             | 0 0 None None             | ✔
# [123] | 60 60 SGD DAILY           | 60 60 HKD DAILY           | ✘
# [124] | 12000 15000 MYR MONTHLY   | 12000 15000 MYR MONTHLY   | ✔
# [125] | 0 0 None None             | 0 0 None None             | ✔
# [126] | 30 30 AUD HOURLY          | 30 30 AUD HOURLY          | ✔
# [127] | 0 0 None None             | 0 0 None None             | ✔
# [128] | 63 137 SGD DAILY          | 63 137 SGD DAILY          | ✔
# [129] | 140 167 SGD DAILY         | 140 167 SGD DAILY         | ✔
# [130] | 0 0 None None             | 0 0 None None             | ✔
# [131] | 0 0 None None             | 0 0 None None             | ✔
# [132] | 24 35 MYR HOURLY          | 2500 3000 MYR MONTHLY     | ✘
# [133] | 28 28 NZD HOURLY          | 28 28 NZD HOURLY          | ✔
# [134] | 0 0 None None             | 0 0 None None             | ✔
# [135] | 1360 2900 SGD MONTHLY     | 1760 2900 SGD MONTHLY     | ✘
# [136] | 60221 64571 AUD ANNUAL    | 60221 64571 AUD ANNUAL    | ✔
# [137] | 45 48 AUD HOURLY          | 45 48 AUD HOURLY          | ✔
# [138] | 3300 4000 MYR MONTHLY     | 3300 4000 MYR MONTHLY     | ✔
# [139] | 20000 25000 THB MONTHLY   | 20000 25000 THB MONTHLY   | ✔
# [140] | 0 0 None None             | 0 0 None None             | ✔
# [141] | 83 113 SGD DAILY          | 83 113 HKD DAILY          | ✘
# [142] | 625 750 SGD DAILY         | 625 750 SGD WEEKLY        | ✘
# [143] | 0 0 None None             | 0 0 None None             | ✔
# [144] | 0 0 None None             | 0 0 None None             | ✔
# [145] | 2000 3000 SGD MONTHLY     | 2000 3000 SGD MONTHLY     | ✔
# [146] | 0 0 None None             | 0 0 None None             | ✔
# [147] | 0 0 None None             | 0 0 None None             | ✔
# [148] | 0 0 None None             | 0 0 None None             | ✔
# [149] | 110 110 HKD HOURLY        | 110 110 HKD HOURLY        | ✔
# [150] | 0 0 None None             | 0 0 None None             | ✔
# [151] | 85 105 AUD HOURLY         | 86 86 AUD HOURLY          | ✘
# [152] | 0 0 None None             | 0 0 None None             | ✔
# [153] | 0 0 None None             | 0 0 None None             | ✔
# [154] | 2500 2800 SGD MONTHLY     | 2500 2800 SGD MONTHLY     | ✔
# [155] | 45 65 AUD HOURLY          | 45 65 AUD HOURLY          | ✔
# [156] | 28 28 NZD HOURLY          | 23 28 NZD HOURLY          | ✘
# [157] | 73 77 SGD DAILY           | 73 77 SGD DAILY           | ✔
# [158] | 0 0 None None             | 0 0 None None             | ✔
# [159] | 0 0 None None             | 0 0 None None             | ✔
# [160] | 1500 1800 MYR MONTHLY     | 1500 1800 MYR MONTHLY     | ✔
# [161] | 3750 3750 AUD ANNUAL      | 30 35 AUD HOURLY          | ✘
# [162] | 0 0 None None             | 0 0 None None             | ✔
# [163] | 0 0 None None             | 0 0 None None             | ✔
# [164] | 2200 2500 MYR MONTHLY     | 2200 2500 MYR MONTHLY     | ✔
# [165] | 0 0 None None             | 0 0 None None             | ✔
# [166] | 0 0 None None             | 0 0 None None             | ✔
# [167] | 2200 3000 SGD MONTHLY     | 2200 3000 SGD MONTHLY     | ✔
# [168] | 20000 25000 THB MONTHLY   | 20000 25000 THB MONTHLY   | ✔
# [169] | 117 200 SGD DAILY         | 117 200 SGD DAILY         | ✔
# [170] | 0 0 None None             | 0 0 None None             | ✔
# [171] | 0 0 None None             | 0 0 None None             | ✔
# [172] | 0 0 None None             | 0 0 None None             | ✔
# [173] | 1600 2200 MYR MONTHLY     | 1600 2200 MYR MONTHLY     | ✔
# [174] | 40 50 SGD HOURLY          | 40 50 SGD HOURLY          | ✔
# [175] | 67357 94568 AUD ANNUAL    | 67357 94568 AUD ANNUAL    | ✔
# [176] | 35 49 AUD HOURLY          | 35 50 AUD HOURLY          | ✘
# [177] | 0 0 None None             | 0 0 None None             | ✔
# [178] | 51 53 AUD HOURLY          | 51 53 AUD HOURLY          | ✔
# [179] | 0 0 None None             | 0 0 None None             | ✔
# [180] | 65 83 HKD HOURLY          | 65 65 HKD HOURLY          | ✘
# [181] | 0 0 None None             | 0 0 None None             | ✔
# [182] | 20000 30000 THB MONTHLY   | 20000 30000 THB MONTHLY   | ✔
# [183] | 0 0 None None             | 0 0 None None             | ✔
# [184] | 0 0 None None             | 0 0 None None             | ✔
# [185] | 49 49 AUD HOURLY          | 49 49 AUD HOURLY          | ✔
# [186] | 1500 2000 SGD WEEKLY      | 1500 2000 SGD WEEKLY      | ✔
# [187] | 85 100 HKD HOURLY         | 85 100 HKD HOURLY         | ✔
# [188] | 0 0 None None             | 0 0 None None             | ✔
# [189] | 1125 1500 SGD MONTHLY     | 1125 1500 SGD WEEKLY      | ✘
# [190] | 23 33 NZD HOURLY          | 24 24 NZD HOURLY          | ✘
# [191] | 0 0 None None             | 0 0 None None             | ✔
# [192] | 0 0 None None             | 0 0 None None             | ✔
# [193] | 100000 140000 AUD ANNUAL  | 100000 140000 AUD ANNUAL  | ✔
# [194] | 0 0 None None             | 32 32 AUD HOURLY          | ✘
# [195] | 0 0 None None             | 0 0 None None             | ✔
# [196] | 0 0 None None             | 0 0 None None             | ✔
# [197] | 50 68 HKD HOURLY          | 50 68 HKD HOURLY          | ✔
# [198] | 52 75 HKD HOURLY          | 52 75 HKD HOURLY          | ✔
# [199] | 0 0 None None             | 0 0 None None             | ✔
# [200] | 0 0 None None             | 0 0 None None             | ✔
# [201] | 0 0 None None             | 0 0 None None             | ✔
# [202] | 0 0 None None             | 0 0 None None             | ✔
# [203] | 17000 17000 PHP MONTHLY   | 17000 17000 PHP MONTHLY   | ✔
# [204] | 2200 3000 MYR MONTHLY     | 2200 3000 MYR MONTHLY     | ✔
# [205] | 75 75 HKD HOURLY          | 75 75 HKD HOURLY          | ✔
# [206] | 0 0 None None             | 0 0 None None             | ✔
# [207] | 32 33 AUD HOURLY          | 32 33 AUD HOURLY          | ✔
# [208] | 500 4000 SGD MONTHLY      | 500 4000 SGD MONTHLY      | ✔
# [209] | 0 0 None None             | 3250 4050 SGD MONTHLY     | ✘
# [210] | 0 0 None None             | 0 0 None None             | ✔
# [211] | 0 0 None None             | 65489 65489 AUD ANNUAL    | ✘
# [212] | 0 0 None None             | 0 0 None None             | ✔
# [213] | 0 0 None None             | 0 0 None None             | ✔
# [214] | 70 80 HKD HOURLY          | 70 80 HKD HOURLY          | ✔
# [215] | 0 0 None None             | 0 0 None None             | ✔
# [216] | 65000 70000 AUD ANNUAL    | 65000 70000 AUD ANNUAL    | ✔
# [217] | 0 0 None None             | 0 0 None None             | ✔
# [218] | 0 0 None None             | 0 0 None None             | ✔
# [219] | 68 80 HKD HOURLY          | 68 80 HKD HOURLY          | ✔
# [220] | 3000 3300 SGD MONTHLY     | 3000 3300 SGD MONTHLY     | ✔
# [221] | 0 0 None None             | 0 0 None None             | ✔
# [222] | 48 60 HKD HOURLY          | 48 60 HKD HOURLY          | ✔
# [223] | 0 0 None None             | 0 0 None None             | ✔
# [224] | 60 80 HKD HOURLY          | 60 80 HKD HOURLY          | ✔
# [225] | 0 0 None None             | 2500 3000 MYR MONTHLY     | ✘
# [226] | 18000 18000 THB MONTHLY   | 18000 18000 HKD MONTHLY   | ✘
#
# 🔢 Confusion Matrix Counts:
#   TP: 97
#   FP: 24
#   FN: 7
#   TN: 99
#
# 📊 Metrics:
#   Precision: 0.8017
#   Recall:    0.9327
#   F1 Score:  0.8622
#   Accuracy:  0.8634

# %%
import pandas as pd
import numpy as np
from datasets import Dataset

df_test = pd.read_csv(
    "../../MISC/salary_labelled_test_set.csv",
    encoding="utf-8"
)
df_test.columns = [
    "job_id","job_title","job_ad_details",
    "nation_short_desc","salary_additional_text","y_true"
]
df_test['y_true'] = (
    df_test['y_true']
      .fillna("0-0-None-None")
      .str.strip()
      .str.replace(
          r'(\d+)-(\d+)-([A-Za-z]+)-([A-Za-z]+)',
          r'\1 \2 \3 \4',
          regex=True
      )
)

test_examples = []
PREFIX =("Extract the salary info from the job ad below and return it as: "
        '"MinimumSalary MaximumSalary Currency PayPeriod"')
for _, row in df_test.iterrows():
    inp = PREFIX + clean_html_tags(str(row["job_ad_details"]))
    gold = row["y_true"]
    test_examples.append({"input_text": inp, "target_text": gold})

test_ds = Dataset.from_list(test_examples)
tokenized_test = test_ds.map(preprocess, batched=True)

pred_out = trainer.predict(tokenized_test)

decoded_preds  = tokenizer.batch_decode(
    pred_out.predictions, skip_special_tokens=True
)
decoded_labels = [ex["target_text"] for ex in test_examples]

default = parse_salary("0 0 None None")
TP = FP = FN = TN = 0
print(" idx | Prediction                | True                       | ✔/✘")
print("-"*70)
for i, (rp, rt) in enumerate(zip(decoded_preds, decoded_labels)):
    p_str = validate_pred(rp.strip())
    t_str = rt.strip()
    pp = parse_salary(p_str.lower())
    tp = parse_salary(t_str.lower())
    is_def_p = (pp == default)
    is_def_t = (tp == default)
    match = (
        not is_def_p and not is_def_t
        and pp[0]==tp[0]
        and pp[1]==tp[1]
        and pp[2]==tp[2]
        and pp[3]==tp[3]
    )
    if match:        TP += 1
    elif not is_def_p: FP += 1
    elif not is_def_t: FN += 1
    else:             TN += 1

    flag = "✔" if p_str == t_str else "✘"
    print(f"[{i:3d}] | {p_str:<25} | {t_str:<25} | {flag}")

print(f"\n🔢 TP: {TP}   FP: {FP}   FN: {FN}   TN: {TN}")
precision = TP/(TP+FP) if TP+FP else 0.0
recall    = TP/(TP+FN) if TP+FN else 0.0
f1        = 2*precision*recall/(precision+recall) if precision+recall else 0.0
accuracy  = (TP+TN)/(TP+FP+FN+TN)
print("\n📊 Precision: {:.4f}".format(precision))
print("    Recall:    {:.4f}".format(recall))
print("    F1 Score:  {:.4f}".format(f1))
print("    Accuracy:  {:.4f}".format(accuracy))
# Out:
# Map:   0%|          | 0/567 [00:00<?, ? examples/s]
#  idx | Prediction                | True                       | ✔/✘
# ----------------------------------------------------------------------
# [  0] | 1500 1800 MYR MONTHLY     | 1500 1800 MYR MONTHLY     | ✔
# [  1] | 60 60 HKD HOURLY          | 60 60 HKD HOURLY          | ✔
# [  2] | 0 0 None None             | 0 0 None None             | ✔
# [  3] | 0 0 None None             | 0 0 None None             | ✔
# [  4] | 0 0 None None             | 0 0 None None             | ✔
# [  5] | 21 21 AUD HOURLY          | 21 21 NZD HOURLY          | ✘
# [  6] | 0 0 None None             | 0 0 None None             | ✔
# [  7] | 0 0 None None             | 0 0 None None             | ✔
# [  8] | 32 32 AUD HOURLY          | 32 32 AUD HOURLY          | ✔
# [  9] | 1500 2000 MYR MONTHLY     | 2000 3000 MYR MONTHLY     | ✘
# [ 10] | 3000 4000 MYR MONTHLY     | 3000 4000 MYR MONTHLY     | ✔
# [ 11] | 0 0 None None             | 0 0 None None             | ✔
# [ 12] | 0 0 None None             | 0 0 None None             | ✔
# [ 13] | 80 90 HKD HOURLY          | 80 90 HKD HOURLY          | ✔
# [ 14] | 142642 156491 AUD ANNUAL  | 142642 156491 AUD ANNUAL  | ✔
# [ 15] | 0 0 None None             | 0 0 None None             | ✔
# [ 16] | 28 28 AUD HOURLY          | 29 29 AUD HOURLY          | ✘
# [ 17] | 1500 2500 MYR MONTHLY     | 1500 2500 MYR MONTHLY     | ✔
# [ 18] | 66027 68085 AUD ANNUAL    | 66028 68086 AUD ANNUAL    | ✘
# [ 19] | 0 0 None None             | 0 0 None None             | ✔
# [ 20] | 30000 40000 SGD MONTHLY   | 3000 4000 SGD MONTHLY     | ✘
# [ 21] | 0 0 None None             | 0 0 None None             | ✔
# [ 22] | 0 0 None None             | 0 0 None None             | ✔
# [ 23] | 73 85 HKD HOURLY          | 73 85 HKD HOURLY          | ✔
# [ 24] | 0 0 None None             | 5000 8000 MYR MONTHLY     | ✘
# [ 25] | 0 0 None None             | 30 30 NZD HOURLY          | ✘
# [ 26] | 0 0 None None             | 0 0 None None             | ✔
# [ 27] | 0 0 None None             | 500 1250 SGD WEEKLY       | ✘
# [ 28] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [ 29] | 750 1125 SGD WEEKLY       | 750 1125 SGD WEEKLY       | ✔
# [ 30] | 0 0 None None             | 0 0 None None             | ✔
# [ 31] | 0 0 None None             | 0 0 None None             | ✔
# [ 32] | 0 0 None None             | 0 0 None None             | ✔
# [ 33] | 0 0 None None             | 1500 1500 MYR MONTHLY     | ✘
# [ 34] | 2000 2500 SGD MONTHLY     | 2000 2500 SGD MONTHLY     | ✔
# [ 35] | 58008 58008 AUD ANNUAL    | 58008 58008 AUD ANNUAL    | ✔
# [ 36] | 23 29 NZD HOURLY          | 23 29 NZD HOURLY          | ✔
# [ 37] | 3000 6000 MYR MONTHLY     | 3000 6000 MYR MONTHLY     | ✔
# [ 38] | 31 31 NZD HOURLY          | 31 31 NZD HOURLY          | ✔
# [ 39] | 100 100 HKD HOURLY        | 100 100 HKD HOURLY        | ✔
# [ 40] | 500 667 PHP DAILY         | 500 667 PHP DAILY         | ✔
# [ 41] | 107 150 SGD DAILY         | 107 150 SGD DAILY         | ✔
# [ 42] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [ 43] | 25 25 AUD HOURLY          | 20 25 AUD HOURLY          | ✘
# [ 44] | 0 0 None None             | 0 0 None None             | ✔
# [ 45] | 0 0 None None             | 0 0 None None             | ✔
# [ 46] | 2700 3000 SGD MONTHLY     | 2700 3000 SGD MONTHLY     | ✔
# [ 47] | 0 0 None None             | 0 0 None None             | ✔
# [ 48] | 0 0 None None             | 0 0 None None             | ✔
# [ 49] | 0 0 None None             | 0 0 None None             | ✔
# [ 50] | 2300 2700 SGD MONTHLY     | 2300 2700 SGD MONTHLY     | ✔
# [ 51] | 0 0 None None             | 0 0 None None             | ✔
# [ 52] | 61868 61868 AUD ANNUAL    | 61868 61868 AUD ANNUAL    | ✔
# [ 53] | 0 0 None None             | 0 0 None None             | ✔
# [ 54] | 0 0 None None             | 0 0 None None             | ✔
# [ 55] | 0 0 None None             | 0 0 None None             | ✔
# [ 56] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [ 57] | 0 0 None None             | 0 0 None None             | ✔
# [ 58] | 25 30 NZD HOURLY          | 25 30 NZD HOURLY          | ✔
# [ 59] | 0 0 None None             | 0 0 None None             | ✔
# [ 60] | 3750 5000 HKD DAILY       | 3750 5000 HKD WEEKLY      | ✘
# [ 61] | 0 0 None None             | 0 0 None None             | ✔
# [ 62] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [ 63] | 0 0 None None             | 0 0 None None             | ✔
# [ 64] | 0 0 None None             | 0 0 None None             | ✔
# [ 65] | 0 0 None None             | 0 0 None None             | ✔
# [ 66] | 0 0 None None             | 0 0 None None             | ✔
# [ 67] | 500 800 SGD DAILY         | 500 800 SGD MONTHLY       | ✘
# [ 68] | 625 800 SGD DAILY         | 625 800 HKD WEEKLY        | ✘
# [ 69] | 0 0 None None             | 0 0 None None             | ✔
# [ 70] | 60 60 SGD DAILY           | 60 60 SGD DAILY           | ✔
# [ 71] | 0 0 None None             | 0 0 None None             | ✔
# [ 72] | 0 0 None None             | 30 30 AUD HOURLY          | ✘
# [ 73] | 0 0 None None             | 0 0 None None             | ✔
# [ 74] | 0 0 None None             | 0 0 None None             | ✔
# [ 75] | 0 0 None None             | 0 0 None None             | ✔
# [ 76] | 0 0 None None             | 0 0 None None             | ✔
# [ 77] | 0 0 None None             | 0 0 None None             | ✔
# [ 78] | 0 0 None None             | 0 0 None None             | ✔
# [ 79] | 1800 2000 MYR MONTHLY     | 1800 2000 MYR MONTHLY     | ✔
# [ 80] | 0 0 None None             | 0 0 None None             | ✔
# [ 81] | 27 27 NZD HOURLY          | 27 27 NZD HOURLY          | ✔
# [ 82] | 0 0 None None             | 0 0 None None             | ✔
# [ 83] | 0 0 None None             | 0 0 None None             | ✔
# [ 84] | 0 0 None None             | 130378 132799 AUD ANNUAL  | ✘
# [ 85] | 21000 21000 PHP MONTHLY   | 21000 21000 PHP MONTHLY   | ✔
# [ 86] | 0 0 None None             | 0 0 None None             | ✔
# [ 87] | 123870 127316 AUD ANNUAL  | 123870 127316 AUD ANNUAL  | ✔
# [ 88] | 0 0 None None             | 0 0 None None             | ✔
# [ 89] | 106 106 HKD HOURLY        | 106 106 HKD HOURLY        | ✔
# [ 90] | 0 0 None None             | 0 0 None None             | ✔
# [ 91] | 80 160 HKD HOURLY         | 90 160 HKD HOURLY         | ✘
# [ 92] | 2800 4000 SGD MONTHLY     | 2800 4000 SGD MONTHLY     | ✔
# [ 93] | 35 45 NZD HOURLY          | 35 45 NZD HOURLY          | ✔
# [ 94] | 60 60 AUD HOURLY          | 60 70 AUD HOURLY          | ✘
# [ 95] | 500 750 SGD WEEKLY        | 500 750 SGD WEEKLY        | ✔
# [ 96] | 26 26 AUD HOURLY          | 26 29 NZD HOURLY          | ✘
# [ 97] | 0 0 None None             | 0 0 None None             | ✔
# [ 98] | 0 0 None None             | 0 0 None None             | ✔
# [ 99] | 0 0 None None             | 0 0 None None             | ✔
# [100] | 0 0 None None             | 0 0 None None             | ✔
# [101] | 76171 87565 AUD ANNUAL    | 76171 87566 AUD ANNUAL    | ✘
# [102] | 0 0 None None             | 0 0 None None             | ✔
# [103] | 40 46 AUD HOURLY          | 40 46 AUD HOURLY          | ✔
# [104] | 29 29 AUD HOURLY          | 30 30 AUD HOURLY          | ✘
# [105] | 0 0 None None             | 0 0 None None             | ✔
# [106] | 0 0 None None             | 0 0 None None             | ✔
# [107] | 0 0 None None             | 0 0 None None             | ✔
# [108] | 12 12 SGD HOURLY          | 12 12 SGD HOURLY          | ✔
# [109] | 0 0 None None             | 0 0 None None             | ✔
# [110] | 125 170 HKD HOURLY        | 125 170 HKD HOURLY        | ✔
# [111] | 100 250 THB HOURLY        | 100 250 THB HOURLY        | ✔
# [112] | 35 49 AUD HOURLY          | 35 49 AUD HOURLY          | ✔
# [113] | 51 54 AUD HOURLY          | 51 55 AUD HOURLY          | ✘
# [114] | 2800 3600 SGD MONTHLY     | 2800 3600 SGD MONTHLY     | ✔
# [115] | 0 0 None None             | 0 0 None None             | ✔
# [116] | 26 26 NZD HOURLY          | 26 26 NZD HOURLY          | ✔
# [117] | 0 0 None None             | 0 0 None None             | ✔
# [118] | 38 40 AUD HOURLY          | 38 40 AUD HOURLY          | ✔
# [119] | 33 33 AUD HOURLY          | 34 34 AUD HOURLY          | ✘
# [120] | 17000 17000 PHP MONTHLY   | 17000 17000 PHP MONTHLY   | ✔
# [121] | 0 0 None None             | 0 0 None None             | ✔
# [122] | 12000 30000 THB MONTHLY   | 12000 30000 HKD MONTHLY   | ✘
# [123] | 2500 3300 SGD MONTHLY     | 2500 3300 SGD MONTHLY     | ✔
# [124] | 0 0 None None             | 0 0 None None             | ✔
# [125] | 2000 2000 MYR MONTHLY     | 2000 2000 MYR MONTHLY     | ✔
# [126] | 30000 35000 THB MONTHLY   | 30000 35000 THB MONTHLY   | ✔
# [127] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [128] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [129] | 44 50 HKD HOURLY          | 44 50 HKD HOURLY          | ✔
# [130] | 0 0 None None             | 0 0 None None             | ✔
# [131] | 0 0 None None             | 0 0 None None             | ✔
# [132] | 0 0 None None             | 0 0 None None             | ✔
# [133] | 0 0 None None             | 0 0 None None             | ✔
# [134] | 0 0 None None             | 0 0 None None             | ✔
# [135] | 0 0 None None             | 0 0 None None             | ✔
# [136] | 0 0 None None             | 0 0 None None             | ✔
# [137] | 83 88 HKD HOURLY          | 83 88 HKD HOURLY          | ✔
# [138] | 1250 1500 SGD WEEKLY      | 1250 1500 SGD WEEKLY      | ✔
# [139] | 13300 13300 HKD MONTHLY   | 13300 13300 HKD MONTHLY   | ✔
# [140] | 100 120 HKD HOURLY        | 100 100 HKD HOURLY        | ✘
# [141] | 500 667 PHP DAILY         | 500 667 HKD DAILY         | ✘
# [142] | 0 0 None None             | 0 0 None None             | ✔
# [143] | 0 0 None None             | 0 0 None None             | ✔
# [144] | 0 0 None None             | 0 0 None None             | ✔
# [145] | 4000 4500 SGD MONTHLY     | 4000 4500 SGD MONTHLY     | ✔
# [146] | 4000 6000 MYR MONTHLY     | 4000 6000 MYR MONTHLY     | ✔
# [147] | 0 0 None None             | 0 0 None None             | ✔
# [148] | 50000 80000 THB MONTHLY   | 50000 80000 THB MONTHLY   | ✔
# [149] | 78 90 AUD HOURLY          | 78 90 AUD HOURLY          | ✔
# [150] | 700 800 SGD DAILY         | 700 800 SGD WEEKLY        | ✘
# [151] | 0 0 None None             | 0 0 None None             | ✔
# [152] | 0 0 None None             | 0 0 None None             | ✔
# [153] | 20000 30000 THB MONTHLY   | 20000 30000 THB MONTHLY   | ✔
# [154] | 0 0 None None             | 0 0 None None             | ✔
# [155] | 0 0 None None             | 0 0 None None             | ✔
# [156] | 2400 3700 SGD MONTHLY     | 2400 3700 SGD MONTHLY     | ✔
# [157] | 28000 28000 PHP MONTHLY   | 28000 28000 PHP MONTHLY   | ✔
# [158] | 0 0 None None             | 0 0 None None             | ✔
# [159] | 5500 5500 SGD MONTHLY     | 5000 5500 SGD MONTHLY     | ✘
# [160] | 65 70 HKD HOURLY          | 65 70 HKD HOURLY          | ✔
# [161] | 0 0 None None             | 0 0 None None             | ✔
# [162] | 625 750 SGD DAILY         | 625 750 SGD WEEKLY        | ✘
# [163] | 100000 250000 AUD ANNUAL  | 225000 250000 AUD ANNUAL  | ✘
# [164] | 0 0 None None             | 0 0 None None             | ✔
# [165] | 0 0 None None             | 0 0 None None             | ✔
# [166] | 0 0 None None             | 0 0 None None             | ✔
# [167] | 0 0 None None             | 0 0 None None             | ✔
# [168] | 29 29 AUD HOURLY          | 29 30 AUD HOURLY          | ✘
# [169] | 31 32 AUD HOURLY          | 31 32 AUD HOURLY          | ✔
# [170] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [171] | 13 13 SGD HOURLY          | 13 13 SGD HOURLY          | ✔
# [172] | 25000 30000 THB MONTHLY   | 25000 30000 THB MONTHLY   | ✔
# [173] | 0 0 None None             | 0 0 None None             | ✔
# [174] | 25000 35000 THB MONTHLY   | 25000 35000 THB MONTHLY   | ✔
# [175] | 0 0 None None             | 0 0 None None             | ✔
# [176] | 0 0 None None             | 0 0 None None             | ✔
# [177] | 1500 1800 MYR MONTHLY     | 1500 1800 MYR MONTHLY     | ✔
# [178] | 32 32 AUD HOURLY          | 33 33 AUD HOURLY          | ✘
# [179] | 117544 1120393 AUD ANNUAL | 117544 120393 AUD ANNUAL  | ✘
# [180] | 52 52 AUD HOURLY          | 52 52 AUD HOURLY          | ✔
# [181] | 0 0 None None             | 0 0 None None             | ✔
# [182] | 70049 98351 AUD ANNUAL    | 70050 98351 AUD ANNUAL    | ✘
# [183] | 3500 10000 MYR MONTHLY    | 3500 10000 MYR MONTHLY    | ✔
# [184] | 12000 30000 THB MONTHLY   | 12000 30000 HKD MONTHLY   | ✘
# [185] | 89095 139187 AUD ANNUAL   | 89095 139187 AUD ANNUAL   | ✔
# [186] | 90 100 AUD HOURLY         | 90 100 AUD HOURLY         | ✔
# [187] | 0 0 None None             | 0 0 None None             | ✔
# [188] | 3000 5000 MYR MONTHLY     | 3000 5000 MYR MONTHLY     | ✔
# [189] | 0 0 None None             | 24 24 NZD HOURLY          | ✘
# [190] | 1500 3000 MYR MONTHLY     | 1500 3000 MYR MONTHLY     | ✔
# [191] | 200 300 HKD HOURLY        | 200 300 HKD HOURLY        | ✔
# [192] | 73 87 SGD DAILY           | 73 87 SGD DAILY           | ✔
# [193] | 9000 15000 THB MONTHLY    | 9000 15000 THB MONTHLY    | ✔
# [194] | 0 0 None None             | 0 0 None None             | ✔
# [195] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [196] | 60 70 AUD HOURLY          | 60 70 AUD HOURLY          | ✔
# [197] | 31 31 AUD HOURLY          | 31 31 AUD HOURLY          | ✔
# [198] | 0 0 None None             | 0 0 None None             | ✔
# [199] | 0 0 None None             | 0 0 None None             | ✔
# [200] | 0 0 None None             | 0 0 None None             | ✔
# [201] | 1500 1800 MYR MONTHLY     | 1500 1800 MYR MONTHLY     | ✔
# [202] | 0 0 None None             | 0 0 None None             | ✔
# [203] | 3000 5000 MYR MONTHLY     | 3000 5000 MYR MONTHLY     | ✔
# [204] | 17500 17500 PHP MONTHLY   | 17500 17500 PHP MONTHLY   | ✔
# [205] | 0 0 None None             | 0 0 None None             | ✔
# [206] | 70 70 HKD HOURLY          | 70 70 HKD HOURLY          | ✔
# [207] | 26 26 AUD HOURLY          | 26 26 NZD HOURLY          | ✘
# [208] | 132606 139914 AUD ANNUAL  | 132606 139914 AUD ANNUAL  | ✔
# [209] | 0 0 None None             | 0 0 None None             | ✔
# [210] | 37 37 AUD HOURLY          | 37 37 AUD HOURLY          | ✔
# [211] | 0 0 None None             | 0 0 None None             | ✔
# [212] | 0 0 None None             | 0 0 None None             | ✔
# [213] | 0 0 None None             | 36 36 NZD HOURLY          | ✘
# [214] | 4000 8000 SGD MONTHLY     | 4000 8000 SGD MONTHLY     | ✔
# [215] | 118197 126566 AUD ANNUAL  | 118197 126566 AUD ANNUAL  | ✔
# [216] | 1000 1000 THB HOURLY      | 1000 1000 THB HOURLY      | ✔
# [217] | 0 0 None None             | 0 0 None None             | ✔
# [218] | 0 0 None None             | 3500 3500 MYR MONTHLY     | ✘
# [219] | 0 0 None None             | 0 0 None None             | ✔
# [220] | 118197 126566 AUD ANNUAL  | 118197 126566 AUD ANNUAL  | ✔
# [221] | 0 0 None None             | 0 0 None None             | ✔
# [222] | 0 0 None None             | 0 0 None None             | ✔
# [223] | 0 0 None None             | 0 0 None None             | ✔
# [224] | 60 70 HKD HOURLY          | 60 70 HKD HOURLY          | ✔
# [225] | 0 0 None None             | 0 0 None None             | ✔
# [226] | 0 0 None None             | 0 0 None None             | ✔
# [227] | 0 0 None None             | 0 0 None None             | ✔
# [228] | 1500 1700 MYR MONTHLY     | 1500 2100 MYR MONTHLY     | ✘
# [229] | 28 31 AUD HOURLY          | 29 32 AUD HOURLY          | ✘
# [230] | 0 0 None None             | 0 0 None None             | ✔
# [231] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [232] | 0 0 None None             | 0 0 None None             | ✔
# [233] | 25000 30000 THB MONTHLY   | 25000 30000 THB MONTHLY   | ✔
# [234] | 0 0 None None             | 0 0 None None             | ✔
# [235] | 0 0 None None             | 0 0 None None             | ✔
# [236] | 0 0 None None             | 0 0 None None             | ✔
# [237] | 80 85 HKD HOURLY          | 80 80 HKD HOURLY          | ✘
# [238] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [239] | 40 60 HKD HOURLY          | 40 60 HKD HOURLY          | ✔
# [240] | 3000 5500 MYR MONTHLY     | 3800 5500 MYR MONTHLY     | ✘
# [241] | 17500 17500 PHP MONTHLY   | 17500 17500 PHP MONTHLY   | ✔
# [242] | 18000 18000 PHP MONTHLY   | 18000 18000 PHP MONTHLY   | ✔
# [243] | 17500 17500 PHP MONTHLY   | 17500 17500 PHP MONTHLY   | ✔
# [244] | 75000 75000 AUD ANNUAL    | 75000 75000 AUD ANNUAL    | ✔
# [245] | 65 65 HKD HOURLY          | 65 65 HKD HOURLY          | ✔
# [246] | 0 0 None None             | 0 0 None None             | ✔
# [247] | 0 0 None None             | 0 0 None None             | ✔
# [248] | 0 0 None None             | 3750 5000 HKD WEEKLY      | ✘
# [249] | 0 0 None None             | 0 0 None None             | ✔
# [250] | 0 0 None None             | 0 0 None None             | ✔
# [251] | 0 0 None None             | 0 0 None None             | ✔
# [252] | 2000 2800 MYR MONTHLY     | 2000 2800 MYR MONTHLY     | ✔
# [253] | 102051 125151 AUD ANNUAL  | 102051 125151 AUD ANNUAL  | ✔
# [254] | 100 250 THB HOURLY        | 100 250 THB HOURLY        | ✔
# [255] | 0 0 None None             | 0 0 None None             | ✔
# [256] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [257] | 100 120 HKD HOURLY        | 100 120 HKD HOURLY        | ✔
# [258] | 0 0 None None             | 0 0 None None             | ✔
# [259] | 500 600 SGD WEEKLY        | 500 600 SGD WEEKLY        | ✔
# [260] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [261] | 3000 4000 SGD MONTHLY     | 3000 4000 SGD MONTHLY     | ✔
# [262] | 500 667 PHP DAILY         | 500 667 PHP DAILY         | ✔
# [263] | 1500 1800 MYR MONTHLY     | 1500 1800 MYR MONTHLY     | ✔
# [264] | 108595 121114 AUD ANNUAL  | 108595 112114 AUD ANNUAL  | ✘
# [265] | 70 70 HKD HOURLY          | 70 70 HKD HOURLY          | ✔
# [266] | 2000 4000 SGD MONTHLY     | 2000 4000 SGD MONTHLY     | ✔
# [267] | 500 575 SGD DAILY         | 500 575 SGD WEEKLY        | ✘
# [268] | 60 60 HKD HOURLY          | 60 60 HKD HOURLY          | ✔
# [269] | 5300 9100 MYR MONTHLY     | 5300 9100 MYR MONTHLY     | ✔
# [270] | 0 0 None None             | 0 0 None None             | ✔
# [271] | 18000 20000 THB MONTHLY   | 18000 20000 THB MONTHLY   | ✔
# [272] | 31 31 AUD HOURLY          | 31 31 AUD HOURLY          | ✔
# [273] | 0 0 None None             | 0 0 None None             | ✔
# [274] | 0 0 None None             | 0 0 None None             | ✔
# [275] | 2700 3000 SGD MONTHLY     | 2700 3000 SGD MONTHLY     | ✔
# [276] | 0 0 None None             | 0 0 None None             | ✔
# [277] | 0 0 None None             | 0 0 None None             | ✔
# [278] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [279] | 14500 16000 THB MONTHLY   | 14500 16000 HKD MONTHLY   | ✘
# [280] | 0 0 None None             | 0 0 None None             | ✔
# [281] | 0 0 None None             | 0 0 None None             | ✔
# [282] | 1500 2200 MYR MONTHLY     | 1500 2200 MYR MONTHLY     | ✔
# [283] | 3500 4000 MYR MONTHLY     | 3500 4900 MYR MONTHLY     | ✘
# [284] | 40 40 AUD HOURLY          | 41 41 AUD HOURLY          | ✘
# [285] | 16000 16000 PHP MONTHLY   | 16000 16000 PHP MONTHLY   | ✔
# [286] | 0 0 None None             | 0 0 None None             | ✔
# [287] | 0 0 None None             | 0 0 None None             | ✔
# [288] | 0 0 None None             | 0 0 None None             | ✔
# [289] | 110000 110000 PHP MONTHLY | 110000 110000 PHP MONTHLY | ✔
# [290] | 60 75 HKD HOURLY          | 60 75 HKD HOURLY          | ✔
# [291] | 6000 8000 SGD MONTHLY     | 6000 8000 SGD MONTHLY     | ✔
# [292] | 60 70 HKD HOURLY          | 60 70 HKD HOURLY          | ✔
# [293] | 0 0 None None             | 0 0 None None             | ✔
# [294] | 0 0 None None             | 0 0 None None             | ✔
# [295] | 27 31 NZD HOURLY          | 27 31 NZD HOURLY          | ✔
# [296] | 63723 68073 AUD ANNUAL    | 63723 68073 AUD ANNUAL    | ✔
# [297] | 0 0 None None             | 0 0 None None             | ✔
# [298] | 0 0 None None             | 0 0 None None             | ✔
# [299] | 2800 3500 SGD MONTHLY     | 2800 3500 SGD MONTHLY     | ✔
# [300] | 0 0 None None             | 0 0 None None             | ✔
# [301] | 0 0 None None             | 0 0 None None             | ✔
# [302] | 0 0 None None             | 40000 40000 PHP MONTHLY   | ✘
# [303] | 2000 2300 MYR MONTHLY     | 2000 2300 MYR MONTHLY     | ✔
# [304] | 90000 90000 PHP MONTHLY   | 90000 90000 PHP MONTHLY   | ✔
# [305] | 29 29 AUD HOURLY          | 29 29 AUD HOURLY          | ✔
# [306] | 30000 40000 THB MONTHLY   | 30000 45000 THB MONTHLY   | ✘
# [307] | 0 0 None None             | 0 0 None None             | ✔
# [308] | 0 0 None None             | 0 0 None None             | ✔
# [309] | 40 40 NZD HOURLY          | 10 40 NZD HOURLY          | ✘
# [310] | 0 0 None None             | 0 0 None None             | ✔
# [311] | 0 0 None None             | 0 0 None None             | ✔
# [312] | 67 110 SGD DAILY          | 67 110 SGD DAILY          | ✔
# [313] | 27 31 HKD HOURLY          | 27 31 NZD HOURLY          | ✘
# [314] | 50 60 HKD HOURLY          | 50 60 HKD HOURLY          | ✔
# [315] | 0 0 None None             | 0 0 None None             | ✔
# [316] | 24 30 HKD HOURLY          | 24 30 NZD HOURLY          | ✘
# [317] | 1500 1800 MYR MONTHLY     | 1500 1800 MYR MONTHLY     | ✔
# [318] | 2300 2800 SGD MONTHLY     | 2300 2800 SGD MONTHLY     | ✔
# [319] | 24 24 AUD HOURLY          | 25 25 AUD HOURLY          | ✘
# [320] | 0 0 None None             | 0 0 None None             | ✔
# [321] | 0 0 None None             | 0 0 None None             | ✔
# [322] | 0 0 None None             | 0 0 None None             | ✔
# [323] | 18000 18000 PHP MONTHLY   | 18000 18000 PHP MONTHLY   | ✔
# [324] | 50 55 AUD HOURLY          | 50 55 AUD HOURLY          | ✔
# [325] | 0 0 None None             | 0 0 None None             | ✔
# [326] | 2500 3500 SGD MONTHLY     | 2500 3500 SGD MONTHLY     | ✔
# [327] | 43 50 AUD HOURLY          | 44 50 AUD HOURLY          | ✘
# [328] | 1500 2500 MYR MONTHLY     | 1500 2500 MYR MONTHLY     | ✔
# [329] | 0 0 None None             | 0 0 None None             | ✔
# [330] | 0 0 None None             | 0 0 None None             | ✔
# [331] | 23 28 NZD HOURLY          | 23 28 NZD HOURLY          | ✔
# [332] | 3500 4500 SGD MONTHLY     | 3500 4500 SGD MONTHLY     | ✔
# [333] | 22000 22000 PHP MONTHLY   | 22000 22000 PHP MONTHLY   | ✔
# [334] | 0 0 None None             | 0 0 None None             | ✔
# [335] | 2500 2800 SGD MONTHLY     | 2500 2800 SGD MONTHLY     | ✔
# [336] | 0 0 None None             | 85000 85000 NZD ANNUAL    | ✘
# [337] | 15000 20000 THB MONTHLY   | 15000 20000 THB MONTHLY   | ✔
# [338] | 18000 18000 PHP MONTHLY   | 18000 18000 PHP MONTHLY   | ✔
# [339] | 0 0 None None             | 0 0 None None             | ✔
# [340] | 35 45 AUD HOURLY          | 35 45 NZD HOURLY          | ✘
# [341] | 3000 3000 MYR MONTHLY     | 3000 3000 MYR MONTHLY     | ✔
# [342] | 0 0 None None             | 0 0 None None             | ✔
# [343] | 0 0 None None             | 0 0 None None             | ✔
# [344] | 10 10 SGD HOURLY          | 10 10 SGD HOURLY          | ✔
# [345] | 0 0 None None             | 40 43 AUD HOURLY          | ✘
# [346] | 57 66 HKD HOURLY          | 57 66 HKD HOURLY          | ✔
# [347] | 37 42 NZD HOURLY          | 37 42 NZD HOURLY          | ✔
# [348] | 0 0 None None             | 0 0 None None             | ✔
# [349] | 55 55 AUD HOURLY          | 55 55 AUD HOURLY          | ✔
# [350] | 130 130 THB HOURLY        | 130 130 THB HOURLY        | ✔
# [351] | 123 123 MYR DAILY         | 123 123 IDR HOURLY        | ✘
# [352] | 0 0 None None             | 0 0 None None             | ✔
# [353] | 0 0 None None             | 24 24 NZD HOURLY          | ✘
# [354] | 0 0 None None             | 0 0 None None             | ✔
# [355] | 0 0 None None             | 0 0 None None             | ✔
# [356] | 0 0 None None             | 0 0 None None             | ✔
# [357] | 0 0 None None             | 0 0 None None             | ✔
# [358] | 0 0 None None             | 0 0 None None             | ✔
# [359] | 13000 15000 THB MONTHLY   | 13000 15000 THB MONTHLY   | ✔
# [360] | 15000 20000 THB MONTHLY   | 15000 20000 THB MONTHLY   | ✔
# [361] | 50 55 AUD HOURLY          | 50 55 AUD HOURLY          | ✔
# [362] | 22 28 NZD HOURLY          | 23 28 NZD HOURLY          | ✘
# [363] | 0 0 None None             | 0 0 None None             | ✔
# [364] | 117 133 SGD DAILY         | 117 133 SGD DAILY         | ✔
# [365] | 40 50 AUD HOURLY          | 0 0 None None             | ✘
# [366] | 0 0 None None             | 0 0 None None             | ✔
# [367] | 2500 2700 SGD MONTHLY     | 2500 2700 SGD MONTHLY     | ✔
# [368] | 35000 35000 PHP MONTHLY   | 35000 35000 PHP MONTHLY   | ✔
# [369] | 60 73 HKD DAILY           | 60 73 SGD DAILY           | ✘
# [370] | 625 750 SGD DAILY         | 625 750 SGD WEEKLY        | ✘
# [371] | 35 45 NZD HOURLY          | 35 45 NZD HOURLY          | ✔
# [372] | 50 50 HKD HOURLY          | 50 50 HKD HOURLY          | ✔
# [373] | 0 0 None None             | 0 0 None None             | ✔
# [374] | 60 60 HKD HOURLY          | 60 60 HKD HOURLY          | ✔
# [375] | 0 0 None None             | 0 0 None None             | ✔
# [376] | 25000 25000 PHP MONTHLY   | 25000 25000 PHP MONTHLY   | ✔
# [377] | 70049 98351 AUD ANNUAL    | 70050 98351 AUD ANNUAL    | ✘
# [378] | 0 0 None None             | 0 0 None None             | ✔
# [379] | 62 123 SGD DAILY          | 62 123 SGD DAILY          | ✔
# [380] | 2500 4000 MYR MONTHLY     | 2500 4000 MYR MONTHLY     | ✔
# [381] | 0 0 None None             | 0 0 None None             | ✔
# [382] | 78000 90000 NZD MONTHLY   | 78000 90000 NZD ANNUAL    | ✘
# [383] | 0 0 None None             | 0 0 None None             | ✔
# [384] | 625 875 SGD WEEKLY        | 625 875 SGD WEEKLY        | ✔
# [385] | 117 150 SGD DAILY         | 117 150 SGD DAILY         | ✔
# [386] | 0 0 None None             | 0 0 None None             | ✔
# [387] | 0 0 None None             | 0 0 None None             | ✔
# [388] | 0 0 None None             | 0 0 None None             | ✔
# [389] | 0 0 None None             | 0 0 None None             | ✔
# [390] | 0 0 None None             | 0 0 None None             | ✔
# [391] | 400 30000 THB MONTHLY     | 30000 30000 THB MONTHLY   | ✘
# [392] | 1500 2345 MYR MONTHLY     | 1500 2345 MYR MONTHLY     | ✔
# [393] | 0 0 None None             | 0 0 None None             | ✔
# [394] | 0 0 None None             | 0 0 None None             | ✔
# [395] | 0 0 None None             | 0 0 None None             | ✔
# [396] | 0 0 None None             | 0 0 None None             | ✔
# [397] | 30 35 AUD HOURLY          | 30 35 AUD HOURLY          | ✔
# [398] | 0 0 None None             | 0 0 None None             | ✔
# [399] | 100 120 HKD HOURLY        | 100 120 HKD HOURLY        | ✔
# [400] | 25000 25000 PHP MONTHLY   | 25000 25000 PHP MONTHLY   | ✔
# [401] | 0 0 None None             | 0 0 None None             | ✔
# [402] | 34 48 AUD HOURLY          | 34 48 AUD HOURLY          | ✔
# [403] | 0 0 None None             | 0 0 None None             | ✔
# [404] | 0 0 None None             | 0 0 None None             | ✔
# [405] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [406] | 60 80 HKD HOURLY          | 60 80 HKD HOURLY          | ✔
# [407] | 0 0 None None             | 0 0 None None             | ✔
# [408] | 1500 1900 MYR MONTHLY     | 1500 1900 MYR MONTHLY     | ✔
# [409] | 0 0 None None             | 0 0 None None             | ✔
# [410] | 45 45 AUD HOURLY          | 45 45 AUD HOURLY          | ✔
# [411] | 2200 3000 MYR MONTHLY     | 2200 3000 MYR MONTHLY     | ✔
# [412] | 500 625 SGD WEEKLY        | 500 625 SGD WEEKLY        | ✔
# [413] | 0 0 None None             | 0 0 None None             | ✔
# [414] | 30 30 NZD HOURLY          | 25 30 NZD HOURLY          | ✘
# [415] | 0 0 None None             | 0 0 None None             | ✔
# [416] | 0 0 None None             | 0 0 None None             | ✔
# [417] | 0 0 None None             | 0 0 None None             | ✔
# [418] | 0 0 None None             | 27 27 NZD HOURLY          | ✘
# [419] | 0 0 None None             | 0 0 None None             | ✔
# [420] | 0 0 None None             | 0 0 None None             | ✔
# [421] | 2200 3200 SGD MONTHLY     | 2200 3200 SGD MONTHLY     | ✔
# [422] | 0 0 None None             | 0 0 None None             | ✔
# [423] | 0 0 None None             | 0 0 None None             | ✔
# [424] | 0 0 None None             | 0 0 None None             | ✔
# [425] | 0 0 None None             | 0 0 None None             | ✔
# [426] | 38 49 AUD HOURLY          | 38 49 AUD HOURLY          | ✔
# [427] | 85 85 HKD HOURLY          | 85 85 HKD HOURLY          | ✔
# [428] | 0 0 None None             | 0 0 None None             | ✔
# [429] | 6000 8000 SGD MONTHLY     | 6000 8000 SGD MONTHLY     | ✔
# [430] | 0 0 None None             | 0 0 None None             | ✔
# [431] | 60 77 SGD DAILY           | 60 77 HKD DAILY           | ✘
# [432] | 525 650 SGD DAILY         | 525 650 HKD WEEKLY        | ✘
# [433] | 2500 2500 MYR MONTHLY     | 2500 2500 MYR MONTHLY     | ✔
# [434] | 750 1000 SGD DAILY        | 750 1000 HKD WEEKLY       | ✘
# [435] | 18000 18000 PHP MONTHLY   | 18000 18000 PHP MONTHLY   | ✔
# [436] | 0 0 None None             | 0 0 None None             | ✔
# [437] | 0 0 None None             | 0 0 None None             | ✔
# [438] | 0 0 None None             | 0 0 None None             | ✔
# [439] | 0 0 None None             | 0 0 None None             | ✔
# [440] | 1500 1500 MYR MONTHLY     | 1300 2000 MYR MONTHLY     | ✘
# [441] | 2000 2600 SGD MONTHLY     | 2000 2600 SGD MONTHLY     | ✔
# [442] | 2200 2900 SGD MONTHLY     | 2200 2900 SGD MONTHLY     | ✔
# [443] | 0 0 None None             | 0 0 None None             | ✔
# [444] | 130 130 HKD HOURLY        | 130 130 HKD HOURLY        | ✔
# [445] | 73 107 SGD DAILY          | 73 107 PHP DAILY          | ✘
# [446] | 40 44 HKD HOURLY          | 40 44 HKD HOURLY          | ✔
# [447] | 32 32 AUD HOURLY          | 32 42 AUD HOURLY          | ✘
# [448] | 30 30 AUD HOURLY          | 30 30 AUD HOURLY          | ✔
# [449] | 750 1125 SGD MONTHLY      | 750 1125 SGD WEEKLY       | ✘
# [450] | 0 0 None None             | 0 0 None None             | ✔
# [451] | 0 0 None None             | 0 0 None None             | ✔
# [452] | 0 0 None None             | 0 0 None None             | ✔
# [453] | 33 33 AUD HOURLY          | 50 50 AUD HOURLY          | ✘
# [454] | 0 0 None None             | 0 0 None None             | ✔
# [455] | 0 0 None None             | 0 0 None None             | ✔
# [456] | 175 175 SGD WEEKLY        | 175 175 HKD WEEKLY        | ✘
# [457] | 0 0 None None             | 0 0 None None             | ✔
# [458] | 30 30 HKD HOURLY          | 40 100 MYR HOURLY         | ✘
# [459] | 30000 35000 THB MONTHLY   | 30000 35000 THB MONTHLY   | ✔
# [460] | 0 0 None None             | 0 0 None None             | ✔
# [461] | 0 0 None None             | 0 0 None None             | ✔
# [462] | 0 0 None None             | 0 0 None None             | ✔
# [463] | 0 0 None None             | 0 0 None None             | ✔
# [464] | 5500 5500 MYR MONTHLY     | 5500 5500 MYR MONTHLY     | ✔
# [465] | 18000 18000 PHP MONTHLY   | 18000 18000 PHP MONTHLY   | ✔
# [466] | 120 140 HKD HOURLY        | 120 140 HKD HOURLY        | ✔
# [467] | 15000 15000 PHP MONTHLY   | 15000 15000 PHP MONTHLY   | ✔
# [468] | 3750 5000 PHP MONTHLY     | 3750 5000 HKD WEEKLY      | ✘
# [469] | 40000 60000 THB MONTHLY   | 40000 60000 THB MONTHLY   | ✔
# [470] | 0 0 None None             | 0 0 None None             | ✔
# [471] | 78079 105030 AUD ANNUAL   | 78079 105030 AUD ANNUAL   | ✔
# [472] | 0 0 None None             | 0 0 None None             | ✔
# [473] | 3750 5000 HKD WEEKLY      | 3750 5000 HKD WEEKLY      | ✔
# [474] | 41 45 AUD HOURLY          | 41 45 AUD HOURLY          | ✔
# [475] | 100 100 HKD HOURLY        | 100 100 HKD HOURLY        | ✔
# [476] | 0 0 None None             | 0 0 None None             | ✔
# [477] | 50 55 HKD HOURLY          | 50 55 HKD HOURLY          | ✔
# [478] | 0 0 None None             | 0 0 None None             | ✔
# [479] | 124 124 HKD HOURLY        | 124 124 HKD HOURLY        | ✔
# [480] | 0 0 None None             | 358 358 THB HOURLY        | ✘
# [481] | 3000 4000 MYR MONTHLY     | 3000 4000 MYR MONTHLY     | ✔
# [482] | 40 45 AUD HOURLY          | 40 45 AUD HOURLY          | ✔
# [483] | 0 0 None None             | 0 0 None None             | ✔
# [484] | 2500 2500 MYR MONTHLY     | 2500 2500 MYR MONTHLY     | ✔
# [485] | 17500 17500 PHP MONTHLY   | 17500 17500 PHP MONTHLY   | ✔
# [486] | 0 0 None None             | 0 0 None None             | ✔
# [487] | 2000 2500 MYR MONTHLY     | 2000 2500 MYR MONTHLY     | ✔
# [488] | 0 0 None None             | 0 0 None None             | ✔
# [489] | 133 183 SGD DAILY         | 133 183 HKD DAILY         | ✘
# [490] | 100000 100000 THB MONTHLY | 100000 100000 THB MONTHLY | ✔
# [491] | 355 500 SGD WEEKLY        | 350 500 SGD WEEKLY        | ✘
# [492] | 0 0 None None             | 0 0 None None             | ✔
# [493] | 26 32 NZD HOURLY          | 26 32 NZD HOURLY          | ✔
# [494] | 0 0 None None             | 0 0 None None             | ✔
# [495] | 0 0 None None             | 0 0 None None             | ✔
# [496] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [497] | 2000 3000 MYR MONTHLY     | 2000 3000 MYR MONTHLY     | ✔
# [498] | 2500 3200 MYR MONTHLY     | 2500 3200 MYR MONTHLY     | ✔
# [499] | 0 0 None None             | 63 67 AUD HOURLY          | ✘
# [500] | 34 37 AUD HOURLY          | 34 37 AUD HOURLY          | ✔
# [501] | 0 0 None None             | 412 412 THB HOURLY        | ✘
# [502] | 3500 4000 SGD MONTHLY     | 3500 4000 SGD MONTHLY     | ✔
# [503] | 0 0 None None             | 24 26 NZD HOURLY          | ✘
# [504] | 34 34 AUD HOURLY          | 34 34 AUD HOURLY          | ✔
# [505] | 24 26 NZD HOURLY          | 24 26 NZD HOURLY          | ✔
# [506] | 12000 12000 THB MONTHLY   | 12000 12000 THB MONTHLY   | ✔
# [507] | 0 0 None None             | 0 0 None None             | ✔
# [508] | 70 80 HKD HOURLY          | 70 80 HKD HOURLY          | ✔
# [509] | 0 0 None None             | 0 0 None None             | ✔
# [510] | 85000 85000 AUD ANNUAL    | 85000 85000 AUD ANNUAL    | ✔
# [511] | 0 0 None None             | 0 0 None None             | ✔
# [512] | 0 0 None None             | 0 0 None None             | ✔
# [513] | 1800 2100 MYR MONTHLY     | 1800 2100 MYR MONTHLY     | ✔
# [514] | 0 0 None None             | 0 0 None None             | ✔
# [515] | 75 75 HKD HOURLY          | 75 75 HKD HOURLY          | ✔
# [516] | 0 0 None None             | 0 0 None None             | ✔
# [517] | 6000 7000 MYR MONTHLY     | 6000 7000 MYR MONTHLY     | ✔
# [518] | 30 40 AUD HOURLY          | 30 30 NZD HOURLY          | ✘
# [519] | 3500 4500 MYR MONTHLY     | 3000 4500 MYR MONTHLY     | ✘
# [520] | 2500 3500 MYR MONTHLY     | 2500 3500 MYR MONTHLY     | ✔
# [521] | 25 25 NZD HOURLY          | 26 26 NZD HOURLY          | ✘
# [522] | 70049 98351 AUD ANNUAL    | 70049 98351 AUD ANNUAL    | ✔
# [523] | 16000 20000 THB MONTHLY   | 16000 20000 THB MONTHLY   | ✔
# [524] | 67357 94568 AUD ANNUAL    | 67357 94568 AUD ANNUAL    | ✔
# [525] | 2200 2800 SGD MONTHLY     | 2200 2800 SGD MONTHLY     | ✔
# [526] | 0 0 None None             | 0 0 None None             | ✔
# [527] | 1800 2500 MYR MONTHLY     | 1800 2500 MYR MONTHLY     | ✔
# [528] | 3000 4000 MYR MONTHLY     | 3000 3000 MYR MONTHLY     | ✘
# [529] | 1500 1500 MYR MONTHLY     | 1500 1500 MYR MONTHLY     | ✔
# [530] | 0 0 None None             | 0 0 None None             | ✔
# [531] | 0 0 None None             | 0 0 None None             | ✔
# [532] | 25000 35000 THB MONTHLY   | 25000 35000 THB MONTHLY   | ✔
# [533] | 0 0 None None             | 0 0 None None             | ✔
# [534] | 0 0 None None             | 0 0 None None             | ✔
# [535] | 0 0 None None             | 0 0 None None             | ✔
# [536] | 0 0 None None             | 0 0 None None             | ✔
# [537] | 0 0 None None             | 0 0 None None             | ✔
# [538] | 0 0 None None             | 0 0 None None             | ✔
# [539] | 0 0 None None             | 0 0 None None             | ✔
# [540] | 137173 163431 AUD ANNUAL  | 137173 163431 AUD ANNUAL  | ✔
# [541] | 60 70 AUD HOURLY          | 60 70 AUD HOURLY          | ✔
# [542] | 2000 3000 SGD MONTHLY     | 2000 3000 SGD MONTHLY     | ✔
# [543] | 90 100 AUD HOURLY         | 90 100 AUD HOURLY         | ✔
# [544] | 50 50 HKD HOURLY          | 50 50 HKD HOURLY          | ✔
# [545] | 57 57 AUD HOURLY          | 58 58 AUD HOURLY          | ✘
# [546] | 33 38 AUD HOURLY          | 33 38 AUD HOURLY          | ✔
# [547] | 0 0 None None             | 0 0 None None             | ✔
# [548] | 17500 17500 PHP MONTHLY   | 17500 17500 PHP MONTHLY   | ✔
# [549] | 0 0 None None             | 28 40 NZD HOURLY          | ✘
# [550] | 0 0 None None             | 0 0 None None             | ✔
# [551] | 18000 18000 PHP MONTHLY   | 18000 18000 PHP MONTHLY   | ✔
# [552] | 0 0 None None             | 0 0 None None             | ✔
# [553] | 0 0 None None             | 0 0 None None             | ✔
# [554] | 40 51 AUD HOURLY          | 40 51 AUD HOURLY          | ✔
# [555] | 0 0 None None             | 20 30 NZD HOURLY          | ✘
# [556] | 0 0 None None             | 0 0 None None             | ✔
# [557] | 50 65 HKD HOURLY          | 50 65 HKD HOURLY          | ✔
# [558] | 50 55 AUD HOURLY          | 50 55 AUD HOURLY          | ✔
# [559] | 0 0 None None             | 0 0 None None             | ✔
# [560] | 0 0 None None             | 0 0 None None             | ✔
# [561] | 0 0 None None             | 0 0 None None             | ✔
# [562] | 26 26 NZD HOURLY          | 26 26 NZD HOURLY          | ✔
# [563] | 0 0 None None             | 0 0 None None             | ✔
# [564] | 0 0 None None             | 0 0 None None             | ✔
# [565] | 1500 2500 MYR MONTHLY     | 1500 2500 MYR MONTHLY     | ✔
# [566] | 0 0 None None             | 0 0 None None             | ✔
#
# 🔢 TP: 237   FP: 72   FN: 21   TN: 237
#
# 📊 Precision: 0.7670
#     Recall:    0.9186
#     F1 Score:  0.8360
#     Accuracy:  0.8360
