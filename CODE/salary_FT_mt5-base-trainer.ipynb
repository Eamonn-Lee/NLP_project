# %%
# %pip install protobuf
import transformers
from transformers import pipeline
from transformers import BertTokenizerFast, BertForQuestionAnswering, TrainingArguments, Trainer
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainer, Seq2SeqTrainingArguments
from transformers import MT5ForConditionalGeneration, MT5Tokenizer
import pandas as pd
import numpy as np
import torch
from bs4 import BeautifulSoup
from datasets import Dataset
from nltk.tokenize import word_tokenize

print(torch.backends.mps.is_available())

import sys
sys.path.append("../CODE-Baseline")  
import warnings
warnings.filterwarnings('ignore')


from salary_baseline import extract_salary_with_inference


file_path = '../DATASETS/salary_labelled_development_set.csv'
test_file_path = '../DATASETS/salary_labelled_test_set.csv'
ignore_id_path = '../DATASETS/err_salary_develpment.csv'

df = pd.read_csv(file_path)
df_ignore = pd.read_csv(ignore_id_path)
# some y_true is impossible
df = df[~df['job_id'].isin(df_ignore['job_id'])]


model_name = "google/mt5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# qa_pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer, device=-1)
# Out:
# Requirement already satisfied: protobuf in /Users/garry/vs_code/6713/venv/lib/python3.11/site-packages (6.30.2)
# Note: you may need to restart the kernel to use updated packages.
# True
# Development dataset:
# Precision: 0.8357
# Recall: 0.9524
# F1 Score: 0.8902
# Accuracy: 0.8889
#
# Test dataset:
# Precision: 0.7412
# Recall: 0.9206
# F1 Score: 0.8212
# Accuracy: 0.8219
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
# Function to remove HTML tags from job ad text
def clean_html_tags(html_text):
    soup = BeautifulSoup(html_text, 'html.parser')
    # Remove <script> and <style> tags completely
    for tag in soup(["script", "style"]):
        tag.decompose()
    # Return clean text with line breaks between blocks
    return soup.get_text(separator="\n", strip=True)

# Function to convert a DataFrame row into input-output format
def row_to_input_output(row):
    # Clean and concatenate job title and ad details as context
    context = clean_html_tags(f"{row['job_title']} {row['job_ad_details']}")
    # Define the instruction prompt
    prompt = (
        "Extract the salary info from the job ad below and return it as: "
        "\"MinimumSalary MaximumSalary Currency PayPeriod\"\n\n"
    )
    input_text = prompt + context
    # Normalize the label by converting to string and replacing dashes with spaces
    output_text = str(row["y_true"]).strip().replace("-", " ")
    return {"input": input_text, "output": output_text}

# Function to tokenize input-output pairs for training
def preprocess(example):
    # Tokenize the input with padding and truncation (max 512 tokens)
    model_inputs = tokenizer(example["input"], max_length=512, truncation=True, padding="max_length")
    
    # Tokenize the target output sequence (label)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(example["output"], max_length=64, truncation=True, padding="max_length")["input_ids"]
    
    # Replace padding token IDs with -100 so they are ignored in the loss computation
    labels = [token if token != tokenizer.pad_token_id else -100 for token in labels]
    
    # Add the labels to the model input dictionary
    model_inputs["labels"] = labels
    return model_inputs

# %%
# tokenized_dataset = squad_dataset
squad_dataset = Dataset.from_list([row_to_input_output(row) for _, row in df.iterrows()])
tokenized_dataset = squad_dataset.map(preprocess)
final_dataset = tokenized_dataset.train_test_split(test_size=0.2, seed=24)
print("training data size：", len(final_dataset['train']))
print("testing data size：", len(final_dataset['test']))
# Out:
# Map:   0%|          | 0/2133 [00:00<?, ? examples/s]
# training data size： 1706
# testing data size： 427

# %%
# # 查看训练集中的两个样本
# for i in range(10):
#     print(f"\nExample {i+1}:")
#     print("Input:", final_dataset["train"][i])
#     print("Input:", final_dataset["train"][i]["input"])
#     print("Output:", final_dataset["train"][i]["output"])

# %%
# print(transformers.__version__)
def compute_metrics(p):
    preds, labels = p

    # 有些模型的 preds 是 tuple，取第一个元素
    if isinstance(preds, tuple):
        preds = preds[0]

    # 转成 list 并移除 -100
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    # 对于 labels，要先把 -100 替换为 pad_token_id，防止 decode 出错
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # 计算 F1 分数
    f1_scores = []
    for pred, label in zip(decoded_preds, decoded_labels):
        pred_tokens = word_tokenize(pred.lower())
        label_tokens = word_tokenize(label.lower())

        common = set(pred_tokens) & set(label_tokens)
        if len(pred_tokens) == 0 or len(label_tokens) == 0:
            f1 = 0
        else:
            precision = len(common) / len(pred_tokens)
            recall = len(common) / len(label_tokens)
            f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        f1_scores.append(f1)

    return {
        "f1": np.mean(f1_scores)
    }
    
training_args = Seq2SeqTrainingArguments(
    output_dir="./mt5-base-salary",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=35,
    weight_decay=0.01,
    logging_dir="./logs",
    predict_with_generate=True,
    save_total_limit=20,
    save_strategy="epoch",
    load_best_model_at_end=True,  
    metric_for_best_model="f1",  
    greater_is_better=True,  
)


trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=final_dataset["train"],
    eval_dataset=final_dataset["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics  
)

trainer.train()
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='14945' max='14945' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14945/14945 5:18:13, Epoch 35/35]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.975163</td>
#       <td>0.213115</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.100700</td>
#       <td>0.349029</td>
#       <td>0.590192</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.101100</td>
#       <td>0.296242</td>
#       <td>0.632430</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.665100</td>
#       <td>0.235849</td>
#       <td>0.645199</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.429100</td>
#       <td>0.234190</td>
#       <td>0.656295</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.329800</td>
#       <td>0.245269</td>
#       <td>0.661760</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.329800</td>
#       <td>0.236968</td>
#       <td>0.669204</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.257200</td>
#       <td>0.233077</td>
#       <td>0.670542</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.224700</td>
#       <td>0.215025</td>
#       <td>0.675096</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.200600</td>
#       <td>0.211215</td>
#       <td>0.675096</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.183200</td>
#       <td>0.197895</td>
#       <td>0.681248</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.163100</td>
#       <td>0.197706</td>
#       <td>0.679324</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.147600</td>
#       <td>0.211687</td>
#       <td>0.681081</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.147600</td>
#       <td>0.204195</td>
#       <td>0.679742</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.143900</td>
#       <td>0.204688</td>
#       <td>0.682084</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.137700</td>
#       <td>0.215352</td>
#       <td>0.683255</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.114000</td>
#       <td>0.207756</td>
#       <td>0.682670</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.117200</td>
#       <td>0.199015</td>
#       <td>0.684426</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.117200</td>
#       <td>0.208116</td>
#       <td>0.683841</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.098300</td>
#       <td>0.201925</td>
#       <td>0.685012</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.098300</td>
#       <td>0.207672</td>
#       <td>0.683841</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.094500</td>
#       <td>0.207326</td>
#       <td>0.683255</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.094700</td>
#       <td>0.205771</td>
#       <td>0.685597</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.086800</td>
#       <td>0.206139</td>
#       <td>0.684426</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.086100</td>
#       <td>0.213711</td>
#       <td>0.682084</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.087400</td>
#       <td>0.212749</td>
#       <td>0.683841</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.089100</td>
#       <td>0.214727</td>
#       <td>0.682670</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.089100</td>
#       <td>0.215763</td>
#       <td>0.682670</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.082000</td>
#       <td>0.216829</td>
#       <td>0.684426</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.077200</td>
#       <td>0.219444</td>
#       <td>0.684426</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.070100</td>
#       <td>0.218035</td>
#       <td>0.686183</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.080000</td>
#       <td>0.221012</td>
#       <td>0.684426</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.068000</td>
#       <td>0.218895</td>
#       <td>0.685597</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.069800</td>
#       <td>0.218391</td>
#       <td>0.686183</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.069800</td>
#       <td>0.218342</td>
#       <td>0.686183</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight'].
# TrainOutput(global_step=14945, training_loss=0.4210079449640544, metrics={'train_runtime': 19096.5779, 'train_samples_per_second': 3.127, 'train_steps_per_second': 0.783, 'total_flos': 7.159504452452352e+16, 'train_loss': 0.4210079449640544, 'epoch': 35.0})

# %%
trainer.save_model("./mt5-base-salary")
model.eval()
# Out:
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=250112, bias=False)
# )

# %%
model_name = "./mt5-base-salary"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# model.to('cpu')
qa_pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer)

test_samples = [final_dataset["test"][i] for i in range(100)]

# # 生成并打印结果
for i, example in enumerate(test_samples):
    sample = example['input']
    print(f"Test Sample {i + 1}: {sample}")
    output = qa_pipeline(sample)
    print(f"Prediction: {output[0]['generated_text']}")
    print(f"Answer: {example['output']}\n")
# Out:
# Device set to use mps:0
# Test Sample 1: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# ADMIN SECRETARY
# Full time administrative secretary
# Position Monthly Salary : RM3000-RM4000
# JOIN OUR TEAM NOW.
# Job Requirements:
# • Got experience in used cars (If not, training will be provided)
# • With knowledge of MS Office and Website communication software
# • Responsible and Self-motivated
# • Willing to learn, Active and Hardworking
# • Can start immediately
# Working Hour : Monday to Friday (9: 30am - 6: 00pm)
# Saturday (9: 30am - 1: 00pm)
# Working Location: 7-G, Multilevel Car Park, Jalan Equine 10E, Taman
# Equine, 43300 Seri Kembangan Selangor Malaysia
# Prediction: 3000 4000 MYR MONTHLY
# Answer: 3000 4000 MYR MONTHLY
#
# Test Sample 2: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# IT Engineers - Software, Apps and SQL Support / OJT Provided
# Information
# $2600 to $3400 +Bonuses
# SGX Listed Establishment
# No Experience Welcomed
# On the Job Training Provided
# Responsibilities
# Responsible for Collection, Analysis, Uploading and Rectification of Data
# Assist in trouble shooting ERP / APP system & participate in system upgrade projects
# Support and coordinate with internal stakeholders on data related requests
# Build and Maintain effective communication with various parties to achieve meeting work requests timely
# Perform daily troubleshooting of errors encountered during data uploading or extraction
# General application support and basic troubleshooting
# Requirements
# Diploma in IT or relevant disciplines
# Keen interest in IT Data Base Systems and ERP / APP system experience
# EA: 17C8660
# CEI: R1104442 (Wong Zi Ming Shawn)
# www.sourcesolutionshr.com
# Prediction: 2600 3400 SGD MONTHLY
# Answer: 2600 3400 SGD MONTHLY
#
# Test Sample 3: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Data Engineer
# Mandai Wildlife Group is dedicated to caring for the planet and protecting animals and nature. Conservation education is intrinsic in all interactions with the Group, to inspire action for a healthier world.
# Mandai Wildlife Group is the steward of Mandai Wildlife Reserve, a unique wildlife and nature destination in Singapore that is home to world-renown wildlife parks which connect visitors to the fascinating world of wildlife. The Group is driving an exciting rejuvenation plan at Mandai Wildlife Reserve, adjacent to Singapore's Central Catchment Nature Reserve, that will integrate five wildlife parks with distinctive nature-based experiences, green public spaces and an eco-friendly resort.
# Mandai Wildlife Group advocates for biodiversity, contributes leading wildlife research, develops innovative solutions to promote living sustainably, and collaborates with conservation partners in Singapore and Southeast Asia.
# The Group provides funding and in-kind support to Mandai Nature for conservation work across Southeast Asia.
# Mandai Global, an entity that is part of the Group, will establish and operate new lines of business anchored in creating positive outcomes for nature and wildlife.
# In our efforts to ensure a safe workplace, Mandai Wildlife Group implements the Vaccinate or Regular Test (VoRT) regime for team members who are not yet fully vaccinated. This is aligned to guidelines from the Ministry of Manpower and more information can be found here: https://www.mom.gov.sg/covid-19/advisory-on-covid-19-vaccination-in-employment-settings
# Reporting to the Data Transformation Lead, you will be one of the early team members to help define, orchestrate and deliver upon Mandai Wildlife Group's long term data strategy.
# As a savvy Data Engineer joining our newly formed team of analytics experts, you will be responsible for optimizing our data and data pipeline architecture, data flow and collection for cross functional teams. Ideally you are an experienced data pipeline builder and enjoys optimizing and building data systems from the ground up.  You are excited by the prospect of optimizing or even re-designing our company's data architecture to support our next generation of products and data initiatives.
# You will support the database architects, data analysts and data scientists on data initiatives and will ensure optimal data delivery architecture is consistent throughout ongoing projects. You are a self-starter and comfortable in supporting the data needs of multiple teams, systems and products.
# Key Responsibilities:
# ·       Create and maintain optimal data pipeline architecture,
# ·       Assemble large, complex data sets across various data stores that meet functional / non-functional business requirements.
# ·       Identify, design, and implement internal process improvements: automating manual processes, optimizing data delivery, re-designing infrastructure for greater scalability, etc.
# ·       Build the infrastructure required for optimal extraction, transformation, and loading of data from a wide variety of data sources.
# ·       Build analytics tools that utilize the data pipeline to provide actionable insights into customer acquisition, operational efficiency and other key business performance metrics.
# ·       Work with stakeholders including the Executive, Product, Data and Design teams to assist with data-related technical issues and support their data infrastructure needs.
# ·       Create data tools for analytics and data scientist team members that assist them in building and optimizing our product into an innovative industry leader.
# ·       Work with data and analytics experts to strive for greater functionality in our data systems.
# Skills/ Experience:
# ·       We are looking for a candidate with 5+ years of experience in a Data Engineer role, who has attained a Graduate degree in Computer Science, Statistics, Informatics, Information Systems or another quantitative field.
# ·       Strong project management and organizational skills.
# ·       Experience supporting and working with cross-functional teams in a dynamic environment.
# ·       Advanced working SQL knowledge and experience working with relational databases, query authoring (SQL) as well as working familiarity with a variety of databases.
# ·       A successful history of manipulating, processing and extracting value from large, disconnected datasets.
# ·       Experience building and optimizing 'big data' data pipelines, architectures, and data sets.
# ·       Experience performing root cause analysis on internal and external data and processes to answer specific business questions and identify opportunities for improvement.
# ·       Strong analytic skills related to working with unstructured datasets.
# ·       Build processes supporting data transformation, data structures, metadata, dependency and workload management.
# ·       Experience in data architecture frameworks, data asset management, data modelling, data services, taxonomy creation, business intelligence & analytics.
# ·       Relevant hands-on experience in delivering end-to-end on-premise and Azure cloud data warehousing and data analytics solutions using Microsoft technologies from conceptualization, implementation, optimization and support
# ·       Experienced in using the following software/tools:
# ·       Experience with big data tools: Hadoop, Spark, Kafka, etc.
# ·       Experience with object-oriented/object function scripting languages: C#, Python, Java, C++, Scala, etc.
# ·       Experience in relational and NoSQL database and data warehouse: MS SQL Server, MS SSAS, Azure Data Lake, Azure SQL database, Azure Synapse Cosmo DB, MongoDB, PostgresSQL etc.
# ·       Hands-on experience in ETL technologies for data transformation, cleansing, deduplication and merging: SSIS, Azure Data Factory, Azure Databricks
# ·       Experience in data services, data streaming and analysis services: Denodo, Azure Stream Analytics, Azure Analysis Services, etc.
# ·       Hands-on experience in designing and implementation of MS Power BI reporting and dashboards
# ·       Experience in implementing Enterprise Data Dictionary to harmonise data definition for whole of organisation.
# ·       Clear understanding of data security protocols and enabling data governance access controls.
# ·       Demonstrated experience in handling sensitive, confidential, PII information in large data systems.
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 4: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# .NET Developer / Senior .NET Developer
# Key Responsibilities:
# ● Design, develop, test, and deploy high-performance applications using
# Microsoft .NET technologies.
# ● Perform code reviews, and enforce quality standards and best practices
# around source management and releases.
# ● Participate in the entire software development lifecycle, including software
# architecture, design, coding, testing, deployment, and maintenance.
# ● Mentor junior developers.
# ● Write clean, efficient, and well-documented code, adhering to best practices
# and coding standards.
# ● Troubleshoot, debug, and optimize applications to ensure optimal
# performance and reliability.
# ● Stay current with industry trends and new technologies to enhance your skills
# and contribute to the team.
# Requirements:
# ● 2 - 7 years of professional experience in software development including
# Microsoft .NET, ASP.NET and .NET Core.
# ● Bachelor's degree in Computer Science, Engineering, Software Development,
# or a related field.
# ● Preferable experience mentoring a small team of developers.
# ● Decent English language proficiency.
# ● Strong proficiency in C#.
# ● Solid understanding of web development technologies, including HTML, CSS,
# JavaScript, and related frameworks (e.g., React, Angular, Blazor).
# ● Experience with database design and SQL (e.g., SQL Server, MySQL).
# ● Familiarity with version control systems (e.g., Git).
# ● Experience with Agile/Scrum methodologies.
# ● Excellent problem-solving and analytical skills.
# ● Strong communication and teamwork abilities.
# Nice to Have:
# ● Experience with Razor pages or Blazor for building interactive web UIs.
# ● Proficiency in using SQL Server.
# ● Familiarity with Redis for caching and data storage.
# ● Knowledge of AJAX for asynchronous web applications.
# ● Web design skills to create visually appealing and user-friendly interfaces.
# ● Experience with cloud platforms (e.g., Azure, AWS).
# ● Familiarity with microservices architecture.
# ● Experience with automated testing frameworks like NUnit.
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 5: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Hiring Agents for Hotel Reservation Account
# Job Opening
# Hiring Agents for Hotel Reservation Account
# Job Industry
# Telecommunications
# Job Type
# Full-Time
# Experience Level
# Entry Level
# Date Posted
# 2023-02-14
# Job Location
# Quezon CityQuezon City1550Metro ManilaPhilippines
# Company Information
# Metacom Jobs
#
#  Website: https://metacombpo.net/jumpstart
# Join our team today
# We are in need of Customer Service Representative to Start ASAP
# Apply now!
# Job Responsibilities :
# • Using a computerized system, responds to customer questions in a call center environment.
# • May carry out one or more of the following: Responds to telephone inquiries and complaints using standard scripts and procedures.
# • Gathers information, researches/resolves inquiries and logs customer calls.
# • Communicates appropriate options for resolution in a timely manner.
# • Informs clients about services available and assesses customer needs.
# Job Qualifications
# Minimum Qualifications:
# - BPO experience is a plus but not necessary
# - High School / SHS Graduate
# - Excellent to above average English communication skills
# Compensation
# 25000
# Compensation Range
# ₱20,000 - ₱30,000
# Prediction: 25000 25000 PHP MONTHLY
# Answer: 25000 25000 PHP MONTHLY
#
# Test Sample 6: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# 奢侈品牌店舖主管 Luxury Brand Store Supervisor
# 工作職責 :
# 維持店舖日常運作
# 設定團隊銷售目標、個人KPI
# 確保前線同事達到KPI及銷售目標
# 貨場及倉存管理以確保存貨充足
# 員工更表安排
# 入職要求 :
# 2年或以上管理店鋪經驗
# 流利廣東話、英文及普通話
# 對零售及奢侈品行業充滿熱誠
# 有意者可WhatsApp
# +852 5169 2497
# 聯絡Kristy Chan了解更多詳情
# Click "
# Apply
# Now
# " to apply for this position or call Kristy Chan
# at
# +852 3180 4956
# for a confidential discussion. All information collected will be kept in strict confidence and will be used for recruitment purpose only.
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 7: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# FRUIT MARKET SHOP ASSISTANT
# Fruit Market Position Vacant in a large modern store. All applicants must have worked 3 years or more in a Fruit Market and must have experience in vegetable display's
# Please apply.
# Please call after 12noon:Tony: 0405 105 105 or Susan 9642 5613
# OFFERTA DI LAVORO IN UN NEGOZIO DI FRUTTA E VERDURA A BELFIELDCercasi personale per lavorare in un negozio di frutta e verdura a Belfield. Esperienza nonrichiesta...per chi fosse interessato chiami il numero qui sotto Tony: +61(0) 405 105 105 Inviato da iPhone
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 8: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Operations Manager - Data Center
# We are seeking a highly skilled Operations Manager with a background in Mechanical, Electrical, and Plumbing (MEP) to oversee the operation and maintenance of our data center facilities. The Operations Manager will be responsible for ensuring the optimal performance of all MEP systems, managing facility operations, and implementing strategies to maximize efficiency and reliability.
# Client Details
# We are currently partnering with one of the leading Data Center company in Indonesia who is looking for a Operations Manager to help them in this time of growth.
# Description
# Manage the day-to-day operations of the data center facility, including monitoring and maintenance of MEP systems to ensure uninterrupted service.
# Develop and implement preventive maintenance programs for all critical MEP equipment, including generators, UPS systems, HVAC, fire suppression systems, and electrical distribution systems.
# Conduct regular inspections and audits of MEP systems to identify potential issues or areas for improvement, and develop action plans to address them.
# Coordinate with vendors, contractors, and service providers to schedule maintenance activities, repairs, and upgrades, ensuring minimal impact on data center operations.
# Oversee compliance with relevant regulations, codes, and industry standards related to MEP systems, safety, and environmental requirements.
# Manage the facility budget, including forecasting and tracking expenses related to maintenance, repairs, and upgrades of MEP systems.
# Develop and implement energy conservation initiatives to optimize energy efficiency and reduce operating costs.
# Lead emergency response procedures and protocols, ensuring readiness to address any incidents or failures affecting MEP systems.
# Collaborate with other departments, including engineering, operations, and security, to support the overall goals and objectives of the data center company.
# Stay informed about advancements in MEP technology and best practices in facility management, and make recommendations for improvements or enhancements as needed.
# Profile
# Bachelor's degree in Mechanical Engineering, Electrical Engineering, Facilities Management, or related field.
# Minimum of 8 years of experience in facility management, with a focus on MEP systems, preferably in a data center or mission-critical environment.
# Strong technical knowledge of MEP systems, including HVAC, electrical distribution, fire protection, and plumbing.
# Experience with building automation systems (BAS) and monitoring tools for MEP systems.
# Familiarity with regulatory requirements and industry standards related to MEP systems, safety, and environmental compliance.
# Excellent leadership, communication, and interpersonal skills, with the ability to work effectively with cross-functional teams and external partners.
# Strong problem-solving skills and the ability to make sound decisions under pressure.
# Job Offer
# High impact, high visibility management role
# Great career prospects as the growth opportunity in the company is tremendous
# To apply online please click the 'Apply' button below.
# For a confidential discussion about this role please contact Veny Adilia on +62 21 2958 8846.
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 9: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Customer Service Representative - No Experience Required
# Job Opening
# Customer Service Representative - No Experience Required
# Job Industry
# Telecommunications
# Job Type
# Full-Time
# Experience Level
# Entry Level
# Date Posted
# 2023-09-14
# Job Location
# -
# Bacolod
# 6100
# Negros Occidental
# Philippines
# Company Information
# Neksjob Corporation
# -
# We are driven by the innate desire to bring about change by encouraging out of the box solutions to well-worn path
# challenges at a cost-effective rate. We aim to bridge the gap between countries and cultures, distance and time zones,
# to bring the world closer through the help of emerging technology.
# Job Description
# Duties/Responsibilities:
# Responsibility Includes responding to incoming calls from the customers, answering questions and inquiries, troubleshooting problems, providing information and handling complaints regarding the organization's products or services.
# Job Qualifications
# QUALIFICATIONS:
# Excellent communication skills
# Amenable to WORK ON SITE
# Must be residing within Negros Occidental
# Not currently employed/enrolled
# Fully Vaccinated
# Why pick us?
# Competitive Salary
# Exciting Performance Bonuses & Account Specific Allowances
# Career Advancement Opportunities
# Promote Within the Company
# Comprehensive Healthcare Benefits
# Compensation
# 16000
# Compensation Range
# ₱15,000 - ₱20,000
# Prediction: 16000 16000 PHP MONTHLY
# Answer: 16000 16000 PHP MONTHLY
#
# Test Sample 10: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# 【新人獎金可達$2,000】顧客服務/廚房組員_石籬邨麥當勞_無需經驗! 彈性排班!
# 【新人獎金可達$2,000】顧客服務/廚房組員_石籬邨麥當勞_無需經驗! 彈性排班!
# [新人獎金可達$2,000】
# 不限年齡，歡迎學生，家庭主婦，退休人士申請
# 福利:
# 📅彈性上班時間
# 無需經驗，有薪培訓
# 🍔免費膳食，麥友介紹獎金
# 🛍員工購物優惠
# 員工活動，寄工作於娛樂
# 良好晉升機會📈
# 現招聘:
# 收銀員/廚房職位
# 收銀員職責:
# 積極與顧客互動，為顧客提供需要
# 協助顧客使用自助點餐機
# 保持工作地方清潔
# 準備及補給配料
# 協助甜品站工作崗位(如需)
# 廚房職責:
# 準備食材
# 製作食品
# 保持廚房清潔
# 團體合作
# 專責煎炸產品
# 工作地點: 葵涌石籬邨麥當勞
# 時薪: 每小時$50起
# 😊歡迎致電/Whatsapp 6398 9201 查詢 或
# 可按以下Whatsapp 短連結
# https://api.whatsapp.com/send?phone=85263989201
# Prediction: 50 50 HKD HOURLY
# Answer: 50 50 HKD HOURLY
#
# Test Sample 11: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Pastry Baker
# We are looking for Pastry Baker
# Salary: $1900 to $2400 depend on experience
# Working in a Central kitchen environment
# Rotation between baking & frosting department and get to learn different skillsets
# • On the job training provided
# • Making of sauces & fillings
# • Production of sponges, cakes
# • Production of desserts such as macarons and cupcakes
# • Finishing and piping of desserts
# • Layering of cakes
# • Frosting of cakes
# • Decoration of cakes using different ingredients and methods
# Roles & Responsibilities
# · Prepare, bake and present pastry effectively and efficiently, meeting the company operations standards.
# · Assist in the preparation, garnishing and presentation of pastry.
# · Keep up to date with the current promotions and new items.
# · Ensure that procedures for suppliers, equipment, and work areas
# are in compliance to the established standards.
# · Assist in keeping food wastage to minimum, through correct product measurement.
# · Maintain good knowledge on standard pastry preparation through training by immediate superior/ manual provided by the company.
# · Maintain the kitchen cleanliness.
# · Ensure that food hygiene and safety standards are maintained
# and comply.
# · To adhere to kitchen SOPs.
# · Report on time, in proper uniform and grooming standard.
# · Maintain good personal hygiene as well as high work and safety standards in the workplace.
# · Assist in dishwashing duties as and when required.
# · Execute any other duties as assigned.
# Skills
# · Pastry preparation or baking
# Education
# · At least PSLE, technical certificate or any related fields
# Experience
# · No experience/ At least 1 year of experience working in kitchen as pastry preparation or/& baking.
# Prediction: 1900 2400 SGD MONTHLY
# Answer: 1900 2400 SGD MONTHLY
#
# Test Sample 12: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# PEMANDU LORI
# Description
# Tugas/Tanggungjawab:
# Menghantar barang-barang ke stor atau tapak kerja projek.
# Membantu memuatkan dan memunggahkan barang
# Membantu dalam pemasangan dan lain- lain perkara yang berkaitan dengan tugas/kerja
# Bertanggungjawab untuk menjaga kenderaan termasuk kebersihan dan kekemasan.
# Memeriksa lori untuk tujuan keselamatan.
# Kelayakan :
# Mesti mempunyai lesen memandu dan GDL yang sah
# Kelebihan :
# Gaji : RM1800 - RM 2500
# Jawatan - Pemandu Lori Dan Despatch
# Waktu kerja - 9am -6pm
# Ot - Lebih 8 Jam
# KEMASUKAN SEGERA!!
# Sekiranya berminat boleh menghubungi : HR - 0162444937
# Company
# SETIA TRAFIK SDN BHD Selangor-based private limited company in the business of Traffic Management works especially in Traffic Management Plan and Traffic Management Works.
# In Setia Trafik, we focus on providing traffic management plans in an effective and efficient way to manage traffic for clients as well as to utilize recourses given effectively to optimize output.
# Prediction: 1800 2500 MYR MONTHLY
# Answer: 1800 2500 MYR MONTHLY
#
# Test Sample 13: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# 40716 it-full Stack Web Developer - Intermediate
# Location
# Sathon
# Job type
# Contract
# Job reference
# BBBH32477_1666235603
# Salary
# Up to THB120000.00 per month-
# - Full-Stack Developer on Azure Platform develop API, and functional features to communicate to Cloud Systems and On-Premise Systems.
# - Main focus on coding and debugging.
# - Responsible to develop / Maintain / Troubleshooting, Fix the code as given by functional team member.
# - Collaborate with Process functional people
# - Define and communicate technical and design requirement.
# - Team player, help and support to other team members.
# - Build high-quality reusable code, and could be modular, reusable and scalable.
# - Conduct testing in various level from Unit testing, Integrate Testing and Support User Testing.
# **Qualifications**
# - ** 3-5 year experience**
# - API Development
# - Azure
# - JAVA Script
# - C#
# - .NET core
# - ** At least 1 year experience in Front end development**
# - Angular
# - REACT
# - JAVA Spring (Primary)
# - HTML
# - CSS
# - Experience working in Agile team
# - Willingness to learn
# **Soft skill sets**
# - Collaboration
# - Open for discussion
# - Fast learner
# - Good interpersonal skill
# Prediction: 12000 12000 THB MONTHLY
# Answer: 120000 120000 THB MONTHLY
#
# Test Sample 14: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# System Analyst - Java & Financial System 2
# PCCW Solutions is looking for amazing talents!
# What you'll be empowered to do:-
# Report to team leader in a sizeable project team
# Lead and coach local/off-shore development team members
# Be responsible for SDLC related tasks including system design, prepare program specifications, code review, system and user testing, implementation and deployment of applications and software products
# What we'll need from you:-
# Degree holder in IT or related fields
# Minimum 5 years of experience in software development
# Proficiency in Java & ReactJS software development are essential
# Experience in Springboot, Microservices and Oracle are also desirable
# System analysis or development experience in financial systems and/or working experience in financial institutions will be an added advantage
# Immediate availability will be an added advantage
# Effective verbal and written communication in English and Chinese
# Good team player with strong interpersonal and communication skills
# Positive attitude, fast-learning, energetic, able to perform in challenging environment
# If you would like to be part of the journey with us, please click the "Apply" button and we look forward to getting to know you!
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 15: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Project Engineer (HVAC/ E&M)
# Project Engineer (HVAC/ E&M)
# Our client is one of the world's leaders in high-technology heating, air conditioners, and refrigeration solutions. They are currently looking for a Project Engineer with experience in project management and maintenance work to join the organization.
# Responsibilities
# Manage HVAC retrofit projects are successfully completed within schedule with proven track record
# Assist Project Manager in handling of fitting out and retrofit works of MVAC system, including site coordination with sub-contractor and client
# To supervise and monitor on site for HVAC retrofit projects
# To prepare submission works such as tendering and quotation for HVAC retrofit projects
# To manage on the performance of technical staffs and outside contractors
# To manage the selection, ordering and delivery schedule of materials to be procured for the projects assigned
# To perform associated cost estimates, prepares proposals for customer acceptance
# Requirements
# Degree holder in Electrical / Mechanical / Building Service Engineering or related studies
# 3 years' experience on E&M project / Maintenance work with proven track record
# Experience in managing HVAC retrofit projects in Hong Kong will be an advantage
# Proficiency in using MS applications such as Excel, Word, Power Point & AutoCAD drawing software
# Able to work independently, mature with good problem-solving skills
# Good communication, negotiation and interpersonal skills
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 16: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# 採購員(兼職)(EA)
# 22-23-0072208 ME 兼職
#  Unh2N1kxRE00R0Jwc1lKZy9yc1lydHBiRWpEd1IrbFl2dVl5K2p6U2F3Yz0=
# 04/12/2023
# 採購員(兼職)(EA)
# 寶薦館職業介紹所
# 荔枝角
# 紡織業
# 每小時$100.00, 星期一至五: 上午9時至下午6時, 每週工作3天至4天, 每天工作 5 - 9 小時
# Prediction: 100 100 HKD HOURLY
# Answer: 100 100 HKD HOURLY
#
# Test Sample 17: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Night Front Office (Gsa) พนักงานต้อนรับกะกลางคืน
# Salary (12000-15000)
# Requirement:
# - Basic Ms Office.
# - English Speaking and writing
# - Handle calmly when the pressure hits
# **Salary**: ฿12,000.00 - ฿15,000.00 per month
# **Language**:
# - English (preferred)
# Prediction: 12000 15000 THB MONTHLY
# Answer: 12000 15000 THB MONTHLY
#
# Test Sample 18: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Senior Auditor
# Overview of Position
# Experienced audit professional with excellent communication skills requiring moderate to low supervision from Senior Manager/Senior Director. The Senior Auditor will work directly with Internal Audit management in the development and execution of audit, analytics and advisory programs including risk-based audits, continuous monitoring, investigations, and other advisory projects.
# What will be my duties and responsibilities in this job?
# Supports Internal Audit projects and deliverables as needed, including risk-based audit work, advisory projects, data analysis and continuous monitoring projects, ad hoc investigations and integrated audits aligned with the IT audit team.
# Plans and executes projects under general supervision including audit discovery, planning, client coordination, fieldwork, data analysis, workpaper documentation, review of staff work, and reporting/remediation efforts for noted findings
# Must have thorough knowledge of audit objectives in order to prepare the audit plan and understands the specific risks/ issues to be evaluated
# Directs, counsels, and instructs other auditors and reviews their work for sufficiency of scope and accuracy; responsible for delegating work and tasks to other team members and has the authority to do so
# Begins to demonstrate the ability to multitask responsibilities outside the bounds of traditional audit work
# Must be able to plan, execute, deliver and effectively collaborate on integrated audits with IT audit team
# Ensures that audit issues are complete and accurate and associated root causes are understood, well defined, and presented to audit and client management
# Assists in the development of formal written reports to communicate audit results to management and makes recommendations as appropriate; facilitates obtaining action plans for issues noted
# Maintains key stakeholder relationships and acts as a liaison between the department and key business partners/business executives across the company; supports and consistently represents the internal audit brand of providing risk-based and objective assurance, advice and insight
# Responsible for drafting audit reports and representing quality of work performed
# Utilizes problem solving skills to add value to areas audited
# Utilizes data analytic capabilities to drive efficiency and effectiveness
# Leads post engagement issue follow up and resolution
# What are the requirements needed for this position?
# Typically requires a Bachelor’s degree and minimum of 3 years of Public Accounting or 5 years of related corporate experience, or a combination of the two
# Or 3 years experience and a Master's degree.
# Possesses a CPA, CIA, or equivalent designation
# Critical thinker with strong communication skills
# What critical skills are needed for you to consider someone for this position?
# Critical thinker with strong communication skills
# Successful track record of working in a dynamic, fast-paced and changing environment that is results oriented and collaborative.
# Must be able to quickly understand existing processes and associated risks.
# Project management skills and ability to prioritize and handle multiple issues and projects concurrently.
# Maintains key stakeholder relationships and acts as a liaison between the department and key business partners/business executives across the company; supports and consistently represents the internal audit brand of providing risk-based and objective assurance, advice and insight
# What other skills/experience would be helpful to have?
# Certified Information Systems Auditor (CISA) designation or similar IT designation such as the Certified Information Systems Security Professional (CISSP) or Project Management Professional (PMP), Six Sigma Certifications considered a plus
# Experience with enterprise risk management and risk assessments considered a plus
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 19: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Lead QA Engineer
# At LSEG, we consider on providing opportunities equally as priority, we strive to establish teams that are diverse and encourage coordinated working and sharing of ideas!
# We (QA team) are working on WMX product which provide an exchange rate service that publish Spot, Forward and Non-Deliverable Forward (NDF) benchark rates at fixed times throughout the global trading day
# Role Responsibilities & Key Accountabilities:
# Leads all aspects of technical implementation of quality, testing and analysis, providing guidance where issues arise.
# Assigns required tests to Associate Engineer, Engineer and Senior Engineer.
# Develops technical testing programmes throughout the entire technologies’ lifecycles that address areas such as functionality, compatibility, reliability and usability.
# Leads a wide range of quality control planning and execution activities in alignment with the organisation's standards and strategy to ensure that software meets or exceeds specified business and customer needs.
# Brings together testing requirements by evaluating the product requirement specifications (functional / non-functional) and raise clarifications with product owners, business analysts and customers.
# Reviews and approves test plans and scripts to ensure alignment with standards and technology strategy.
# Coordinates the maintenance of all customer technology solutions, ensuring all issues are resolved on time. Recommends and implements, as assigned, improvements to quality control frameworks, processes and standard methodologies.
# Qualifications & Experience:
# Degree or equivalent experience in Computer Science, Software Engineering or other related fields
# ISTQB Core Advanced/Specialist Certified
# Exhibits validated understanding in software quality assurance processes and methodologies
# Proven experience in manual, test automation or performance testing
# Understanding in the SDLC and one programming language, preferably in multi-tiered applications.
# We believe that creating a diverse and inclusive organisation is fundamental to the way we deliver on our promise of creating essential partnerships and open opportunities. Our open culture is central to how we deliver our purpose - driving financial stability, empowering economies and enabling customers to create sustainable growth - in everything we do.
# Working with us means that you will be part of a dynamic organisation of 25,000 people across 70 countries. However, we will value your individuality and enable you to bring your true self to work so you can help enrich our diverse workforce. You will be part of a collaborative and creative culture where we encourage new ideas and are committed to sustainability across our global business. You will experience the critical role we have in helping to re-engineer the financial ecosystem to support and drive sustainable economic growth. Together, we are aiming to achieve this growth by accelerating the just transition to net zero, enabling growth of the green economy and creating inclusive economic opportunity.
# We offer a range of tailored benefits and support, including healthcare, retirement planning, paid volunteering days and wellbeing initiatives.
# We are proud to be an equal opportunities employer. This means that we do not discriminate on the basis of anyone's race, religion, colour, national origin, gender, sexual orientation, gender identity, gender expression, age, marital status, veteran status, pregnancy or disability, or any other basis protected under applicable law. Conforming with applicable law, we can reasonably accommodate applicants' and employees' religious practices and beliefs, as well as any mental health or physical disability needs.
# Please take a moment to read this privacy notice carefully, as it describes what personal information we may hold about you, what it's used for, and how it's obtained, your rights and how to contact us as a data subject.
# If you are submitting as a Recruitment Agency Partner, it is essential and your responsibility to ensure that candidates applying to us are aware of this privacy notice.
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 20: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Station Hands - Aroona Station NT
# Station Hands – Aroona NT
# Two Full-Time Positions
# About Hancock Agriculture
# A world-class agribusiness, Hancock Agriculture, incorporating S. Kidman & Co Pty Ltd and Hancock Prospecting Pty Ltd Services, has 2 positions available for Station Hands to join our operations at Aroona Station, NT.
# Hancock Agriculture has a long history in Agriculture. With over 30 properties across Australia, spanning 10 million hectares, we are one of the country’s largest producers of beef with a herd of over 320,000 head.
# Hancock Agriculture provides you a career in an exceptional organisation you can be proud of, whose culture includes, “happy healthy cattle are the best cattle”. Using practical technology, we are leaders in responsible safety.
# About the Property
# Aroona Station, situated in the Katherine Region of the Northern Territory, encompasses 147,510 hectares of Northern Savannah landscapes and is home to a predominantly Brahman herd of cattle. The Aroona Homestead is welcoming with expansive lawns, shady trees and air-conditioned accommodation. Our team enjoys a friendly and supportive workplace where career and personal growth is encouraged. Industry professionals conduct various training activities during the course of the year, ensuring everyone receives the best opportunity to develop their skills and further their career in the industry.
# About the Role
# Reporting to the Station Manager, your key duties will include, but not be limited to, the following:
# Mustering cattle using horses and motorbikes;
# Attending to all facets of cattle husbandry and processing;
# Carrying out general station maintenance and repairs, including fencing & welding;
# Undertaking general vehicle & machinery operation and basic maintenance;
# Assisting with land and environmental management practices.
# To be successful in this role, you will have:
# Experience in the movement, handling and processing of cattle, using calm methods with the advantage of digitalised communication and vastly-improved cattle-handling facilities;
# Sound horsemanship and motorbike skills;
# Sounding fencing, stock water and general maintenance skills;
# Competent operation of various station machinery/equipment and its basic maintenance;
# A strong work ethic and commitment to working safely;
# A good understanding of animal welfare practices;
# A strong ability to record information and communicate effectively in the workplace;
# Hold a current Class C Drivers Licence (truck licence an advantage, or be willing to obtain);
# Hold a Motorbike Licence (preferred or be willing to obtain); and
# A genuine passion for Agriculture.
# What we offer you
# Air-conditioned, single room accommodation;
# Quality home-cooked meals;
# Certainty of remuneration commensurate with experience;
# Training, career development and advancement opportunities in our widespread organisation;
# Friendly, supportive team & community environment;
# A great opportunity to join an exciting, industry leading Agribusiness, with scope for advancement after training and experience.
# To apply for this exciting and special job experience, please email your current resume with references to careers@hancockagriculture.com.au quoting SK-ARO-2SH-JUN21
# Please note: You must have the right to live and work in Australia to apply for positions with Hancock Agriculture or S. Kidman & Co.
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 21: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Quantity Surveyor (M&E) - SD
# ☑ Well Established MNC Company
# ☑ Location: Commonwealth (will require to go to site)
# ☑ Working Timing: Mon – Friday, 8.30am – 5.30pm
# ☑ Salary: $140 - $167
# ☑ Minimum 2 years of relevant Commercial, M&E, Infrastructure Projects QS experience.
# Responsibilities:
# Follows up on the pre and post-contract administration of the project assigned to.
# Reviews work specifications, take-off quantity, costing and including liaise with Client, Sub-Contractors and Suppliers.
# Possess strong knowledge of Contractual terms and works to ensure that Project Team adheres to Contractural Terms and Conditions.
# Provides effective support to Project Team and establishes good working relationships with Project Managers, Clients, Contractors and sub-contractors.
# Assists in resolving contractual and commercial issues with Clients, Contractors and Suppliers.
# Co-ordinates the procurement of materials and suppliers for the projects and ensures expenses within budget.
# Attends to all contract administration matters and maintains proper documentation of the project.
# Responsible for the Valuation of progress monthly payments, claims, and final account settlement with Clients, Subcontractors, and Suppliers.
# Attends site and other meetings as required.
# Requirements:
# Diploma or Degree in Quantity Surveying / Electrical / Mechanical or its equivalent.
# Minimum 2 years of relevant Commercial, M&E, Infrastructure Projects QS experience.
# Experience in both Pre and Post Contracts.
# Experience in handling LTA projects will be an added advantage.
# Candidates are encouraged to apply this position via
# Apply Now
# button with the following information in the resume:
# Work experiences and job responsibilities
# Current and Expected salary
# Reason for leaving
# Date of availability
# Education background
# Ding Shi Li , Sherly
# (Reg No : R23112767)
# Prediction: 140 167 SGD DAILY
# Answer: 140 167 SGD DAILY
#
# Test Sample 22: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Production Assistant Manager - 307
# Production Assistant Manager - 307
# Responsibilities:
# Drive the implementation of production plans to meet delivery deadlines, enhance efficiency, and maintain quality standards.
# Core developer of process improvement strategies, working diligently towards achieving company objectives.
# Proactively identify and address quality issues, actively seeking out effective solutions.
# Lead efforts to enhance production efficiency, elevate product quality, and drive cost reduction initiatives.
# Execute factory and departmental work plans, aligning activities with performance goals to ensure seamless operations.
# Collaborate with specialized education and training programs, as well as departmental plans, to foster skill development and operational excellence.
# Uphold environmental regulations and promote a culture of safety in all production activities.
# Foster effective communication and coordination across various departments, ensuring smooth workflow and synergy.
# Oversee departmental affairs, meticulously reviewing documents and reports to maintain organizational efficiency.
# Demonstrate accountability by completing tasks assigned by supervisors with precision and diligence.
# Qualification:
# Bachelor's Degree or higher in Industrial Engineering or related field.
# 5-10 years in Production, process or manufacturing management.
# Process improvement background.
# Skilled in lean production management
# Strong reporting skills and team leadership.
# Proficiency in Chinese, English, and Thai languages.
# Interested candidates please send your update resume, current and expected salary with contact details to:
# ManpowerGroup Thailand - Eastern Seaboard Branch
# 44/59 Room no.302 Moo 11, T.Nong-prue, A.Banglamung Chonburi 20150
# Contact Khun Natkrita Taweerachanon (Recruitment Consultant)
# Telephone no. 033-135014 ext.2405 or 081 104 9290
# Natkrita.t @ manpower.co.th
# Manpower recruitment license No.Chobor.03/2554
# Ref: BH46234
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 23: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Commodity Trader Excutive/Manager 大宗商品业务员/经理
# Responsibilities:
# 1. According to the demand and the company's operating strategy, select and maintain foreign suppliers and complete the commodity purchasing tasks. The products including Thermal coal, Coking coal, Iron ore, Copper ore, Lithium ore, Agricultural products, Corn, Soybean, Oil and Gas.
# 2. Assist Trading Director to maintain the relationship between suppliers and customers. Tracking supply dynamics, providing information and evidence related to purchasing.
# 3. Pay attention to domestic and foreign market dynamic information time to time. Grasp the price direction, analyze relevant policies, and provide suggestions and support for decision-making.
# 4. Responsible for the development and maintenance of company's overseas suppliers, and the integration of the international supply chain.
# 主要岗位职责：
# 1、根据需求和公司运营策略，对国外供货商进行甄选和维护、完成大宗采购任务，涉及产品主要有动力煤、焦煤、铁矿石、铜矿、锂矿、农产品玉米大豆、石油天然气；
# 2、协助贸易总监维护供货商客情关系、跟踪供货动态，提供采买相关迅息和依据；
# 3、实时关注国内外市场动态资讯，掌握价格走向，分析相关政策，为决策提供建议和支持；
# 4、负责公司海外产品供应商的开发与维护，进行国际供应链的整合。
# Job requirements:
# 1. Bachelor’s degree or above, major in international trade, marketing, supply chain management, English, etc.
# 2. Understand the import operation process with experience in purchasing or importing commodity products, especially experience in Coal, Iron ore, Non-ferrous metals, Agricultural products, Oil and Gas.
# 3. Proficient in business negotiation skills and procurement skills, familiar with business management, have good sense of cost control.
# 4. Possess certain industry knowledge, data analysis ability, and international supply chain resources.
# 5. Possess a strong sense of responsibility and learning ability, able to be rigorous and practical in doing things, strong in execution and pressure resistance.
# 6. Salary: SGD4000-6000
# 任职要求：
# 1、大学本科及以上学历，国际贸易、市场营销、供应链管理、英语等相关专业；
# 2、精通英语和中文；
# 3、懂进口操作流程，有采购或进口大宗货相关产品工作经验，尤其有相关煤炭、铁矿石、有色、农产品及石油天然气相关工作经验者优先；
# 4、精通商务谈判技巧及采购技巧，熟悉商务管理，具备良好的成本控制意识；
# 5、具有一定的行业知识，数据分析能力，以及国际化供应链资源；
# 6、具备较强的工作责任心及学习能力，做事严谨、踏实，执行力、抗压能力强；
# 7、薪水：SGD4000-6000
# Prediction: 4000 6000 SGD MONTHLY
# Answer: 4000 6000 SGD MONTHLY
#
# Test Sample 24: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Senior Finance Analyst - FP&A & Financial Modelling/ Listed MNC)
# Information
# $8200 to $9200 + AWS + VB
# SGX Listed Company
# Responsibilities:
# Take ownership and ensure the integrity and quality for the financial planning and analysis processes including annual budgeting, monthly reforecasting and sensitivity analysis.
# Contribute as finance business partner, participate, and provide comprehensive review and analysis to decision makers including, but not limited to:
# analysis of revenue performance and growth, profit and losses, variances, revenue reports and key performance indicators
# performance reports for Audit Committee and/or Board
# initiatives including process review and system implementation projects as required by C-Suites and or other department HoDs
# Plan and manage cash flow liquidity. Ensure compliance with bank-related matters including
# documentation, compliance certificates and other notices.
# Build and maintain driver-based forecasts, back test and analyze drivers, and concisely communicate findings to relevant stakeholders.
# Work closely with the finance team and relevant stakeholders to ensure accurate financial information is being used in the budgeting and forecasting process.
# Ensure alignment between monthly and quarterly forecast and annual budget. Track forecast accuracy and manage/escalate risks to the forecast.
# Drive forward dashboards and enhancements to the planning system to support a robust financial and funding plan that is consistent with the management plan.
# Support financial reporting including impairment testing and hedging documentation.
# Responsibility for debt management including monitoring for compliance with financing agreements and preparation of notices for bank-related procedures and processes.
# Develop financial models, tools and methodology to make key business decisions.
# Advising relevant
# business units on the financial feasibility of any proposed strategies.
# Requirements
# At least 8 -10 years’ experience in Accounting, Finance or Financial services, and a Degree in Accountancy, Finance or related disciplines
# Experience in a similar FP&A and/or finance related role, and building/maintaining a budgeting &
# forecasting system.
# EA: 17C8660
# CEI: R1104442(Wong Zi Ming Shawn)
# www.sourcesolutionshr.com
# Prediction: 8200 9200 SGD MONTHLY
# Answer: 8200 9200 SGD MONTHLY
#
# Test Sample 25: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# PHP Laravel Developer
# CAREER GROWTH OPPORTUNITY FOR PHP DEVELOPERS!
# about the company
# ...
# KEY RESULT AREAS / RESPONSIBILITIES
# Grow
# Enrolment
# Responsible for Taylor's Higher Education (New Local, International, Transfer, Progression, Sponsored and Postgraduate) outbound and inbound digital engagement to all prospect students and parents, and to also assist in enrolment-related activities if needed.
# Accountable for managing own performance in achieving team and individual Appointment and Visitation Target and Growth by annual and cycle.
# Provide basic counseling advice and relevant information to prospective and existing students and parents of Taylor's University and Taylor's College through all digital engagement channels.
# Follow up with prospective students and parents for sales conversion via all digital engagement channels.
# Wow
# Student Experience
# Ensure that excellent customer service is provided at all times to new prospective students and parents through all digital engagement channels.
# Ensure timely responses to all enrolment-related requests by prospective students and parents through all digital engagement channels.
# Cost Leadership
# Perform outbound and inbound digital engagement through improving individual Appointment and Visitations conversion, efficiency and productivity.
# Assist in producing relevant report as requested by the Assistant Manager.
# High Performance Organization
# Ensure that all prospective students' information are accurately maintained and updated in Taylor's CRM system.
# *
# The role may be required to undertake other projects / evolve according to function's needs or organization's direction upon the discretion of the Head.
# JOB SPECIFICATIONS
# Minimum Qualifications
# Diploma in Business Management / Marketing / Communications or other management-related discipline.
# Degree is preferred.
# Related Experience
# At least two (2) years of working experience in any forms of sales.
# Telesales / Telemarketing experience is preferred.
# Fresh Graduate is encouraged to apply.
# Competencies (Knowledge, Skills and Abilities)
# Profession-Related
# Foundational Competencies
# Strong Selling and Counseling capabilities.
# Strong Customer Service experience.
# Digital / Telesales management & processes.
# Familiar with Sales Tools, Processes and Technologies.
# Familiar with Higher Education products customer profiling and competitor profiling.
# Proficient in English, Bahasa Malaysia and/ or Mandarin.
# Knowledge and skills in using computer software. E.g. Microsoft software applications.
# Strong AMP
# Attitude
# - Value driven & good work ethics.
# Motivation
# - Highly self-motivated in achieving results.
# Passion
# - Highly interested in the broader purpose of Higher Education and impact towards society.
# Sales Driven
# - passionate in delivering results through effective sales methodologies.
# Data Driven
# and analytical in planning and decision making.
# Excellent
# presentation
# ,
# communication
# and people
# management
# skills, inclusive counseling skills.
# Team Player.
# Experience in working across levels in broad and complex organizations and believes in achieving results through collaboration.
# Conflict Management
# - Ability to manage by identifying and handling conflicts in a sensible, fair and efficient manner.
# Willing to work beyond normal working hours and during weekends.
# Possess own transportation.
# The company reserves the rights to amend or include additional details towards your job description at any point of time in any form of communication.
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 94: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Content Developer ( ArcGIS/GIS)
# Position : Content Writer/Developer
# Tenure : 2 years contract renewable basis
# Working Hours : For 2 weeks training ( 6PM - 3AM), After 2 weeks ( 7AM-4.30PM)
# Working Location : Shah Alam
# Salary : RM 2800 – RM 3200
# Job Responsibilities
# Research, write, and update technical articles for products across platforms and operating systems, adhering to industry and organizational standards.
# Manage Knowledge Base by revising existing articles for new software releases, incorporating service packs and patches, optimizing for SEO, and identifying content for archiving.
# Cross-link Defect-related articles with relevant resources and create index articles for consolidating similar content.
# Address user feedback and ArcGIS Ideas, collaborating with the ESS – OSR Documentation team to initiate document remediation.
# Produce instructive videos based on technical articles to enhance user understanding.
# Job Requirement
# Adherence to organizational standard operating procedures and processes while maintaining a high degree of efficiency is required.
# Candidate must possess at least a Bachelor's Degree, Professional Degree, or
# Master's Degree in one of the following fields:Computer Science/Information Technology, Geographical Science Geology/Geophysics, Journalism Linguistics/Languages or equivalent.
# Required language(s): Proficiency in English is COMPULSORY
# Prediction: 2800 3200 MYR MONTHLY
# Answer: 2800 3200 MYR MONTHLY
#
# Test Sample 95: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Construction Coordinator/ Site Enginner
# Job Title
# : Construction Coordinator / Site Engineer
# Salary Package
# : RM4000- RM5600
# Job Responsibility
# :
# Managing the quality of work and budget costs.
# Communicating with stakeholder, developers, architects, and engineers.
# Review work schedules from contractors and laborers.
# Identifying, developing, and utilizing the talent pool to maximize productivity and quality of work.
# Visiting and inspecting building sites.
# Review and enforce quality control programs execution.
# Reporting on progress and challenges.
# Learning and applying the latest relevant knowledge to the work.
# Requirement
# :
# Candidate must possess at least a Bachelor's Degree in Engineering (Electrical/Electronic), Engineering (Mechanical), Engineering (Mechatronic/Electromechanical) or construction management, engineering, or building science is preferred.
# Min 3 year(s) of working experience in the related field is required for this position.
# Required to support night shift.
# Have good interpersonal and negotiation skills.
# Strong communication skills.
# Working knowledge of project management software is advantage.
# Ready to join immediately! Short notice can be considered.
# Prediction: 4000 5600 MYR MONTHLY
# Answer: 4000 5600 MYR MONTHLY
#
# Test Sample 96: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Field Service HD Fitters
# Iron Mine Contracting (IMC) was formed to provide Civil, Mining, Crushing and Screening and Indigenous partnering opportunities to the West Australian market.
# Opportunities are available for experienced and qualified
# Field Service HD Fitters with Mining and Heavy Earthmoving Equipment experience
# to join our Maintenance team on a permanent full-time basis.
# These are autonomous positions where you will be required to service equipment at our various project sites. Successful candidates will have good diagnostic skills across a wide range of equipment.
# What we offer:
# Full time position in a commercially stable environment
# Own your own Cruiser Ute worth $100K!
# $3000.00 Sign on Bonus + $2000.00 Tool Voucher
# Competitive hourly rate up to $75.00 per hour
# Support with internal career development and any desirable training
# Retail discount across large number of stores
# Opportunity for professional growth
# Wellbeing support for you and your family for personal and professional matters
# Key Duties & Responsibilities:
# Full machine rebuilds
# Diagnostic fault finding on mechanical, hydraulic, electrical and air systems
# Major repairs and major component rebuild along with servicing of a variety of equipment including large wheel loaders, dozers, excavators and trucks
# Undertake necessary risk and pre-task assessments
# Role Requirements:
# Trade Qualified Heavy-Duty Fitter
# Air con ticket highly regarded
# Forklift ticket highly regarded
# Strong communication and interpersonal skills
# Demonstrated ability to work safely
# HR drivers licence
# Able to successfully complete pre-employment medical including drug screen
# Provide a police clearance
# This is a great opportunity to develop a rewarding career within an organisation experiencing a substantial period of growth.
# To be considered please submit a current CV along with a cover letter outlining your skills and experience.
# We are an equal opportunity employer and strongly encourage female and indigenous candidates to apply.
# Please note, only shortlisted candidates will be contacted.
# Prediction: 100 100 AUD HOURLY
# Answer: 75 75 AUD HOURLY
#
# Test Sample 97: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# เจ้าหน้าที่ฝ่ายบัญชี (Accounting Officer)
# Enrich Gold Co.,Ltd.
# กรุงเทพมหานคร
# Location
# True Digital Park 101, BTS บางจาก, กรุงเทพมหานคร
# อัตราค่าจ้าง 20000 – 25000 (ขึ้นอยู่กับความสามารถและประสบการณ์)
# รูปแบบงาน งานประจำ (Full Time)
# อัตรา 1 อัตรา
# รายละเอียดงาน
# จัดทำเอกสารบัญชี ข้อมูลที่เกี่ยวกับงานบัญชีทั้งหมด โดยประสานงานกับสำนักงานบัญชีภายนอกในการปิดงบการเงิน
# จัดทำและตรวจสอบภาษีรายเดือนต่างๆ เพื่อนำส่งสำนักงานบัญชีให้ถูกต้องและตรงตามเวลา เช่น จัดทำเอกสาร ภงด.1 ภงด.3 , ภงด.53 และ ภพ.30สรุปรายงานภาษีซื้อ – ภาษีขายในแต่ละเดือน
# จัดทำบันทึกรายการค่าใช้จ่ายของบริษัท ในแต่ละเดือน และตรวจสอบรายละเอียดค่าใช้จ่ายให้ถูกต้อง
# ตรวจสอบบิลการขายให้ถูกต้องตามยอดขายที่มีการส่งมาในแต่ละวัน
# ทำงานร่วมกับฝ่ายบุคคล ตรวจสอบค่าคอมมิชชั่น และตรวจสอบความถูกต้องอย่างละเอียด
# จัดทำใบแจ้งหนี้ ใบกำกับภาษี และใบเสร็จรับเงิน
# จัดทำใบสั่งซื้อสินค้า / Purchase Order (PO)
# จัดทำใบวางบิล รับเช็ค ทำจ่ายเช็ค ของลูกค้าและเจ้าหนี้หรือผู้ให้บริการ
# รับชำระหนี้ของลูกค้า ในระบบบัญชี
# ประสานงานกับหน่วยงานข้าราชการที่เกี่ยวข้องและฝ่ายอื่นๆที่เกี่ยวข้อง
# รับผิดชอบงานอื่นๆ ที่เกี่ยวข้อง และงานที่ได้รับมอบหมายจากผู้บริหาร เช่นทำรายงานสรุปยอดรายรับประจำสัปดาห์ เป็นต้น
# คุณสมบัติผู้สมัคร
# 1.วุฒิการศึกษาระดับปริญญาตรี สาขาการบัญชี
# 2. มีความรู้เกี่ยวกับหลักการบัญชีและภาษี
# 3. มีประสบการณ์ทำงานเกี่ยวกับงานบัญชีอย่างน้อย 3 ปี
# 4. มีความรอบคอบ ซื่อสัตย์ และมีมนุษยสัมพันธ์ที่ดี มีความขยัน อดทน และสามารถทำงานภายใต้แรงกดดันได้ดี สามารถทำงานร่วมงานกับผู้อื่นได้ดี
# 5. สามารถแก้ไขปัญหาเฉพาะหน้าได้
# 6. มีพื้นฐานสามารถใช้งานโปรแกรม Microsoft Word และ Excel เป็นอย่างดี ใช้ Pivot Table และ Vlookup ได้
# 7. สามารถใช้ภาษาอังกฤษ ในการอ่านและทำความเข้าใจเอกสาร ได้เป็นอย่างดี
# เวลาทำงาน : วันจันทร์ – วันศุกร์ เวลา 9.00 - 18.00 น.
# สวัสดิการ
# ประกันสังคม , วันหยุดพักร้อนประจำปี , งานเลี้ยงสังสรรค์ประจำปี, ตัดผมฟรีทุกเดือน
# Prediction: 20000 25000 THB MONTHLY
# Answer: 20000 25000 THB MONTHLY
#
# Test Sample 98: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Adult Mental Health Residential Team leader
# Te Rūnanga o Kirikiriroa is a Kaupapa Maori organisation based on the philosophies of manaakitanga, whanaungatanga, rangatiratanga and arohatanga.  These values are integral to our practice and service.
# Ngā Whare Tūhono is one of our adult mental health residential services. We are looking for a Kaiwānanga Team Leader who is passionate about kaupapa Māori practices, a unique blend of cultural knowledge, mental health experience and supporting our whānau towards a pathway of wellbeing and independent living.
# Experience required:
# Qualified and registered as either a Nurse, Social Worker, AOD Clinician or an Allied Health Professional
# Full drivers licence
# least three to five years’ management experience
# excellent interpersonal skills
# established relationships in the mental health sector
# solutions-based and strengths-based management style
# excellent report writing and data management skills to ensure we document the journey of our whānau well.
# Maturity to handle a range of situations
# An ability to work to tight deadlines
# Available on call
# Applicants for this position should have NZ residency or a valid NZ work VISA.
# Applications close Monday 15 February 2021, 12pm.
# Apply Now!
# Prediction: 0 0 None None
# Answer: 0 0 None None
#
# Test Sample 99: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Lorry Driver GDL
# Jawatan: Pemandu Lori Menghantar Barang (Sayur) ke Supermarket di seluruh Malaysia
# Penerangan Pekerjaan:
# Kami mencari seorang pemandu lori yang berpengalaman dan bertanggungjawab untuk menghantar barang (sayur, dan mengangkat sayur) ke supermarket di seluruh Malaysia. Pemandu lori akan bertanggungjawab memastikan penghantaran barang berjalan dengan lancar, tepat pada masanya, dan dalam keadaan yang baik. Ini termasuk memuat dan memunggah sayur-sayuran dengan berhati-hati serta mematuhi undang-undang jalan raya semasa menjalankan tugas harian.
# Tanggungjawab Utama:
# Menghantar sayur-sayuran ke supermarket-supermarket yang ditetapkan di seluruh Malaysia.
# Memastikan penghantaran barang dilakukan dengan tepat pada masanya dan dalam keadaan yang baik.
# Memuat dan memunggah sayur-sayuran ke dalam lori dengan berhati-hati dan cermat.
# Menjaga kebersihan dan kemasan lori serta memeriksa keadaan kenderaan sebelum dan selepas setiap penghantaran.
# Mematuhi semua peraturan lalu lintas jalan raya semasa menjalankan tugas harian.
# Menjaga hubungan yang baik dengan pelanggan dan pengurus supermarket.
# Kelayakan:
# Mempunyai lesen memandu yang sah (kelas D) dan rekod pemanduan yang baik.
# Berpengalaman dalam mengendalikan lori penghantaran dan memuat/memunggah barang.
# Memahami undang-undang jalan raya dan peraturan pengangkutan barang.
# Memiliki keupayaan untuk bekerja dengan baik di bawah tekanan dan menjaga kualiti penghantaran walaupun dalam jadual yang ketat.
# Kemahiran komunikasi yang baik dan dapat bekerjasama dengan baik dengan pelanggan dan pengurus supermarket.
# Memiliki pengetahuan geografi Malaysia yang baik dan boleh mengendalikan perjalanan jarak jauh.
# Rajin, cekap, dan berdisiplin dalam melaksanakan tugas harian.
# Manfaat:
# Gaji yang kompetitif berdasarkan pengalaman dan prestasi kerja (RM2200 ke atas, boleh mencapai RM4000+ dengan insentif dan gaji kerja lebih masa).
# Faedah Kumpulan Wang Simpanan Pekerja (KWSP) dan Skim Perlindungan Sosial (SOCSO).
# Tempoh notis pemberhentian kerja selama 1 bulan.
# Sila hantar resume anda yang terkini serta rekod pemanduan untuk pertimbangan kami. Hanya pemohon yang disenarai pendek akan dipanggil untuk temuduga.
# Terima kasih kerana berminat dengan jawatan ini.
# Prediction: 2200 4000 MYR MONTHLY
# Answer: 2200 4000 MYR MONTHLY
#
# Test Sample 100: Extract the salary info from the job ad below and return it as: "MinimumSalary MaximumSalary Currency PayPeriod"
#
# Multi Strategy Hedge Fund -  Operations Associate
# This is a global, multi-strategy investment management firm. The fund has offices across the globe
# They are looking to hire an Operations Associate. The successful candidate will be an enthusiastic, motivated team player with strong attention to detail.
# Responsibilities
# * Perform trade booking/re-bookings, trade matching and affirmations
# * Monitor P&L movements and reconcile difference in real time
# * Acknowledge, book and monitor corporate action events
# * Liaise with prime brokers, fund administrators and system vendors on trade-related issues and break resolution
# * Work closely with PMs and traders on resolving position and trade inquiries globally
# *Work closely with operations team across the regions
# Required Background & Skills
# * 2-7 years of experience in Operations, preferably from sell-side and/or buy-side hedge funds
# * Good functional knowledge of front-to-back processes related to trade capture, trade affirmations, lifecycle events, settlement, corporate actions, reconciliations
# * Team player with proactive can-do attitude
# * Attention to detail and ability to multi-task in a busy environment
# * Coding skills (VBA, SQL, Python) would be a plus
# * Strong interpersonal and communication skills
# * Keen to learn and 'hungry' individual who will be a force for change
# Prediction: 0 0 None None
# Answer: 0 0 None None
