# %%
import pandas as pd
from bs4 import BeautifulSoup
import re

# %%
# Read data
data = pd.read_csv('../DATASETS/salary_labelled_development_set.csv')

# Mapping from nation codes to currency codes
nation_currency = {
    "PH": "PHP",   # Philippines -> Philippine Peso
    "NZ": "NZD",   # New Zealand -> New Zealand Dollar
    "AUS": "AUD",  # Australia -> Australian Dollar
    "HK": "HKD",   # Hong Kong -> Hong Kong Dollar
    "ID": "IDR",   # Indonesia -> Indonesian Rupiah
    "MY": "MYR",   # Malaysia -> Malaysian Ringgit
    "SG": "SGD",   # Singapore -> Singapore Dollar
    "TH": "THB"    # Thailand -> Thai Baht
}

# %%
salary_info = data.iloc[:, 2]
data['currency'] = data.iloc[:, 3].map(nation_currency)
actual_info_series = data.iloc[:, 5]

# %%
def clean_html_tags(html_text):
    soup = BeautifulSoup(html_text, 'html.parser')
    return soup.get_text()

# %%
def detect_unit_extended(window_text):
    """
    Detect the unit information within the given text window.
    Supports five cases: hourly, daily, weekly, monthly, and annual.
    The function searches for all possible matches using regular expressions
    and returns the unit corresponding to the earliest match.
    If no match is found, it defaults to "monthly".
    """
    unit_patterns = {
        "hourly": r'(per\s+hour|hourly|時薪|每小時|每小時薪資)',
        "daily":  r'(per\s+day|daily|日薪|每天|每日薪資)',
        "weekly": r'(per\s+week|weekly|週薪|每週|周薪|每周薪資)',
        "monthly": r'(per\s+month|monthly|月薪|每月|每月薪資)',
        "annual": r'(per\s+year|yearly|annually|remuneration|super|年薪|每年|每年薪資|年度薪資)'
    }
    matches = []
    for unit, pattern in unit_patterns.items():
        m = re.search(pattern, window_text, re.IGNORECASE)
        if m:
            matches.append((m.start(), unit))
    if matches:
        matches.sort(key=lambda x: x[0])
        return matches[0][1]
    else:
        return "monthly"  # Default unit

# %%
def extract_salary_with_unit(text):
    """
    Extract salary values and the unit from the given text.
    - If a salary range is found (e.g., "$50 - $60" or "50 to 60"), return (min, max, unit);
    - If only one value is found, return (value, value, unit);
    - If extraction fails, return None.
    """
    clean_text = clean_html_tags(text)
    tokens = clean_text.split()

    # Iterate over tokens to find salary-related keywords
    for i, token in enumerate(tokens):
        token_lower = token.lower().strip(":")
        if (token_lower in ['待遇', 'salary', 'wage', 'compensation', 'remuneration']
                or "薪" in token or "$" in token or "¥" in token or "₱" in token):
            # Define a window (using the next 6 tokens as context)
            end = min(i + 6, len(tokens))
            window = tokens[i:end]
            window_text = " ".join(window)
            # Check for a salary range pattern (e.g., "$50 - $60" or "50 to 60")
            range_match = re.search(r'[¥$₱]?\s*(\d+(?:,\d+)*(?:\.\d+)?)\s*(?:to|-)\s*[¥$₱]?\s*(\d+(?:,\d+)*(?:\.\d+)?)', window_text)
            if range_match:
                value1 = float(range_match.group(1).replace(',', ''))
                value2 = float(range_match.group(2).replace(',', ''))
                unit = detect_unit_extended(window_text)
                return (value1, value2, unit)
            # Otherwise, check for a single value pattern
            for word in window:
                word_clean = word.strip(",.:;!()")
                word_clean = re.sub(r'^[¥$₱]', '', word_clean)
                match = re.search(r'\d+(?:,\d+)*(?:\.\d+)?', word_clean)
                if match:
                    value = float(match.group(0).replace(',', ''))
                    unit = detect_unit_extended(window_text)
                    return (value, value, unit)
    return None

# %%
# Function to parse the actual information string
def parse_actual_info(info_str):
    """
    Parse the actual information string (format: "min-max-currency-unit")
    and return a tuple (min, max, currency, unit).
    """
    try:
        parts = info_str.split('-')
        if len(parts) != 4 or parts == ['0', '0', 'None', 'None']:
            return None
        actual_min = float(parts[0])
        actual_max = float(parts[1])
        actual_currency = parts[2]
        actual_unit = parts[3].lower()  # Convert to lowercase for comparison
        return (actual_min, actual_max, actual_currency, actual_unit)
    except Exception as e:
        return None

# %%
total_count = 0        # Total number of samples with actual labels
correct_count = 0      # Count of exact matches

# Process each row
for idx, row in data.iterrows():
    raw_text = row.iloc[2]  # Column containing the raw salary information
    predicted = extract_salary_with_unit(raw_text)  # Returns (min, max, unit) or None

    # If a value is successfully extracted, combine it with the mapped currency to form the prediction result
    if predicted is not None:
        pred_min, pred_max, pred_unit = predicted
        # Get the predicted currency from the existing 'currency' column
        pred_currency = row['currency']
        predicted = (pred_min, pred_max, pred_currency, pred_unit.lower())

    # Parse the actual information
    actual_info = row.iloc[5]  # Assume the sixth column contains the actual information
    actual = parse_actual_info(actual_info)

    # Increase total count for every sample with an actual label
    total_count += 1
    if actual is not None:
        # If a prediction exists and all four elements match exactly, count it as correct
        if predicted is not None:
            if predicted == actual:
                correct_count += 1
                print(f"[{idx}] ❌ Predicted: {predicted} | Expected: {actual}")
            else:
                print(f"[{idx}] ✅ Matched:   {predicted}")
    else:
        if predicted is None:
            correct_count += 1
            print(f"[{idx}] ✅ Matched:   {predicted}")
        else:
            print(f"[{idx}] ❌ Predicted: {predicted} | Expected: {actual}")

accuracy = correct_count / total_count if total_count > 0 else None

print("Total samples with actual info:", total_count)
print("Number of correct predictions:", correct_count)
print("Accuracy:", accuracy)
# Out:
# [0] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [1] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [2] ✅ Matched:   None
# [3] ✅ Matched:   None
# [4] ✅ Matched:   None
# [5] ❌ Predicted: (50.0, 60.0, 'HKD', 'hourly') | Expected: (50.0, 60.0, 'HKD', 'hourly')
# [6] ✅ Matched:   None
# [7] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [8] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [9] ❌ Predicted: (32.0, 32.0, 'NZD', 'hourly') | Expected: (32.0, 32.0, 'NZD', 'hourly')
# [11] ❌ Predicted: (65.0, 65.0, 'HKD', 'hourly') | Expected: (65.0, 65.0, 'HKD', 'hourly')
# [12] ✅ Matched:   (28.0, 30.0, 'NZD', 'monthly')
# [13] ✅ Matched:   None
# [14] ✅ Matched:   None
# [15] ✅ Matched:   None
# [16] ✅ Matched:   (35.0, 35.0, 'AUD', 'annual')
# [17] ❌ Predicted: (6000.0, 6000.0, 'MYR', 'monthly') | Expected: (6000.0, 6000.0, 'MYR', 'monthly')
# [18] ❌ Predicted: (65.0, 75.0, 'HKD', 'hourly') | Expected: (65.0, 75.0, 'HKD', 'hourly')
# [19] ✅ Matched:   None
# [20] ✅ Matched:   None
# [21] ✅ Matched:   None
# [22] ❌ Predicted: (100.0, 100.0, 'HKD', 'hourly') | Expected: (100.0, 100.0, 'HKD', 'hourly')
# [23] ✅ Matched:   None
# [24] ✅ Matched:   None
# [25] ✅ Matched:   (1700.0, 1700.0, 'MYR', 'monthly')
# [26] ✅ Matched:   None
# [27] ✅ Matched:   None
# [28] ✅ Matched:   (67357.32, 94568.44, 'AUD', 'annual')
# [29] ✅ Matched:   None
# [30] ❌ Predicted: (4000.0, 6000.0, 'SGD', 'monthly') | Expected: (4000.0, 6000.0, 'SGD', 'monthly')
# [31] ✅ Matched:   None
# [32] ✅ Matched:   None
# [33] ✅ Matched:   (32.31, 32.31, 'AUD', 'monthly')
# [34] ✅ Matched:   (100.0, 100.0, 'AUD', 'annual')
# [35] ✅ Matched:   None
# [36] ✅ Matched:   None
# [37] ✅ Matched:   None
# [39] ✅ Matched:   None
# [40] ✅ Matched:   None
# [41] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [42] ✅ Matched:   (67.0, 133.0, 'HKD', 'monthly')
# [43] ✅ Matched:   None
# [44] ✅ Matched:   None
# [45] ✅ Matched:   None
# [46] ✅ Matched:   None
# [47] ❌ Predicted: (1.0, 1.0, 'PHP', 'monthly') | Expected: None
# [48] ✅ Matched:   (950.0, 1125.0, 'HKD', 'monthly')
# [49] ✅ Matched:   None
# [50] ✅ Matched:   None
# [51] ✅ Matched:   (1000.0, 1375.0, 'SGD', 'weekly')
# [52] ✅ Matched:   None
# [53] ✅ Matched:   None
# [54] ✅ Matched:   None
# [55] ✅ Matched:   None
# [56] ❌ Predicted: (65.0, 80.0, 'HKD', 'hourly') | Expected: (65.0, 80.0, 'HKD', 'hourly')
# [57] ✅ Matched:   None
# [59] ✅ Matched:   None
# [60] ❌ Predicted: (50.0, 60.0, 'HKD', 'hourly') | Expected: (50.0, 60.0, 'HKD', 'hourly')
# [62] ✅ Matched:   (12.0, 12.0, 'SGD', 'monthly')
# [63] ✅ Matched:   None
# [66] ❌ Predicted: (85000.0, 100000.0, 'AUD', 'annual') | Expected: (85000.0, 100000.0, 'AUD', 'annual')
# [67] ✅ Matched:   (2000.0, 2000.0, 'HKD', 'monthly')
# [68] ✅ Matched:   None
# [69] ❌ Predicted: (88.0, 88.0, 'HKD', 'hourly') | Expected: (88.0, 88.0, 'HKD', 'hourly')
# [70] ✅ Matched:   (41.5, 41.5, 'AUD', 'hourly')
# [71] ✅ Matched:   None
# [72] ✅ Matched:   None
# [73] ❌ Predicted: (60.0, 70.0, 'HKD', 'hourly') | Expected: (60.0, 70.0, 'HKD', 'hourly')
# [74] ✅ Matched:   None
# [75] ✅ Matched:   None
# [76] ✅ Matched:   None
# [77] ✅ Matched:   None
# [78] ✅ Matched:   (37.24, 83.97, 'AUD', 'hourly')
# [79] ✅ Matched:   None
# [81] ✅ Matched:   None
# [82] ✅ Matched:   None
# [83] ✅ Matched:   None
# [84] ❌ Predicted: (17.0, 17.0, 'HKD', 'monthly') | Expected: None
# [85] ✅ Matched:   (32.21, 32.21, 'AUD', 'monthly')
# [86] ✅ Matched:   None
# [87] ❌ Predicted: (60.0, 75.0, 'HKD', 'hourly') | Expected: (60.0, 75.0, 'HKD', 'hourly')
# [88] ❌ Predicted: (40.0, 40.0, 'AUD', 'hourly') | Expected: (40.0, 40.0, 'AUD', 'hourly')
# [90] ❌ Predicted: (30.0, 35.0, 'NZD', 'hourly') | Expected: (30.0, 35.0, 'NZD', 'hourly')
# [92] ❌ Predicted: (3010.0, 3010.0, 'SGD', 'monthly') | Expected: (3010.0, 3010.0, 'SGD', 'monthly')
# [93] ✅ Matched:   None
# [94] ✅ Matched:   None
# [95] ❌ Predicted: (18.0, 25.0, 'AUD', 'hourly') | Expected: (18.0, 25.0, 'AUD', 'hourly')
# [96] ✅ Matched:   None
# [97] ✅ Matched:   None
# [98] ✅ Matched:   None
# [99] ❌ Predicted: (65.0, 75.0, 'HKD', 'hourly') | Expected: (65.0, 75.0, 'HKD', 'hourly')
# [100] ❌ Predicted: (1500.0, 1500.0, 'MYR', 'monthly') | Expected: (1500.0, 1500.0, 'MYR', 'monthly')
# [101] ✅ Matched:   (567.0, 567.0, 'PHP', 'monthly')
# [102] ✅ Matched:   (45.0, 65.0, 'HKD', 'monthly')
# [104] ❌ Predicted: (70.0, 75.0, 'HKD', 'hourly') | Expected: (70.0, 75.0, 'HKD', 'hourly')
# [105] ✅ Matched:   (2500.0, 2500.0, 'MYR', 'monthly')
# [106] ❌ Predicted: (17.0, 17.0, 'HKD', 'monthly') | Expected: None
# [107] ✅ Matched:   None
# [108] ✅ Matched:   (14000.0, 14000.0, 'HKD', 'monthly')
# [109] ✅ Matched:   None
# [112] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [113] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [114] ✅ Matched:   None
# [115] ✅ Matched:   (77623.75, 79458.87, 'AUD', 'annual')
# [116] ❌ Predicted: (3400.0, 3400.0, 'SGD', 'monthly') | Expected: (3400.0, 3400.0, 'SGD', 'monthly')
# [117] ✅ Matched:   (5000.0, 5000.0, 'AUD', 'monthly')
# [118] ✅ Matched:   None
# [119] ❌ Predicted: (2000.0, 2000.0, 'MYR', 'monthly') | Expected: (2000.0, 2000.0, 'MYR', 'monthly')
# [120] ✅ Matched:   None
# [122] ✅ Matched:   None
# [123] ✅ Matched:   None
# [124] ❌ Predicted: (16822.0, 17618.0, 'HKD', 'monthly') | Expected: (16822.0, 17618.0, 'HKD', 'monthly')
# [126] ❌ Predicted: (55.0, 70.0, 'HKD', 'hourly') | Expected: (55.0, 70.0, 'HKD', 'hourly')
# [127] ❌ Predicted: (13000.0, 13000.0, 'PHP', 'monthly') | Expected: (13000.0, 13000.0, 'PHP', 'monthly')
# [129] ✅ Matched:   None
# [130] ✅ Matched:   (57000.0, 62000.0, 'AUD', 'monthly')
# [131] ✅ Matched:   None
# [133] ❌ Predicted: (1500.0, 1500.0, 'MYR', 'monthly') | Expected: (1500.0, 1500.0, 'MYR', 'monthly')
# [134] ❌ Predicted: (2000.0, 2000.0, 'MYR', 'monthly') | Expected: (2000.0, 2000.0, 'MYR', 'monthly')
# [136] ✅ Matched:   (10000.0, 10000.0, 'AUD', 'monthly')
# [137] ✅ Matched:   None
# [138] ❌ Predicted: (18.0, 18.0, 'PHP', 'monthly') | Expected: None
# [139] ❌ Predicted: (625.0, 725.0, 'HKD', 'weekly') | Expected: (625.0, 725.0, 'HKD', 'weekly')
# [140] ✅ Matched:   None
# [141] ✅ Matched:   None
# [142] ✅ Matched:   None
# [143] ❌ Predicted: (65.0, 95.0, 'HKD', 'hourly') | Expected: (65.0, 95.0, 'HKD', 'hourly')
# [144] ❌ Predicted: (120.0, 200.0, 'HKD', 'hourly') | Expected: (120.0, 200.0, 'HKD', 'hourly')
# [145] ✅ Matched:   None
# [146] ✅ Matched:   (28.25, 28.25, 'NZD', 'hourly')
# [147] ✅ Matched:   None
# [148] ❌ Predicted: (2500.0, 3200.0, 'SGD', 'monthly') | Expected: (2500.0, 3200.0, 'SGD', 'monthly')
# [150] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [151] ✅ Matched:   None
# [153] ✅ Matched:   (10000.0, 10000.0, 'AUD', 'monthly')
# [154] ✅ Matched:   (62525.58, 64583.5, 'AUD', 'annual')
# [155] ✅ Matched:   None
# [156] ✅ Matched:   (3.0, 3.0, 'PHP', 'monthly')
# [157] ✅ Matched:   (30.0, 30.0, 'NZD', 'monthly')
# [158] ❌ Predicted: (2400.0, 2600.0, 'SGD', 'monthly') | Expected: (2400.0, 2600.0, 'SGD', 'monthly')
# [159] ❌ Predicted: (70.0, 70.0, 'HKD', 'hourly') | Expected: (70.0, 70.0, 'HKD', 'hourly')
# [160] ✅ Matched:   (30.0, 30.0, 'AUD', 'monthly')
# [162] ✅ Matched:   (15990.0, 15990.0, 'AUD', 'monthly')
# [163] ✅ Matched:   None
# [164] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [165] ✅ Matched:   None
# [166] ✅ Matched:   (90000.0, 130000.0, 'AUD', 'monthly')
# [167] ❌ Predicted: (2200.0, 2500.0, 'SGD', 'monthly') | Expected: (2200.0, 2500.0, 'SGD', 'monthly')
# [168] ✅ Matched:   None
# [169] ✅ Matched:   (1148.7, 1148.7, 'AUD', 'weekly')
# [170] ✅ Matched:   None
# [171] ✅ Matched:   None
# [172] ✅ Matched:   None
# [173] ❌ Predicted: (65.0, 80.0, 'HKD', 'hourly') | Expected: (65.0, 80.0, 'HKD', 'hourly')
# [174] ✅ Matched:   None
# [175] ✅ Matched:   (24.47, 24.47, 'AUD', 'annual')
# [176] ✅ Matched:   None
# [177] ✅ Matched:   None
# [178] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [179] ❌ Predicted: (2000.0, 2000.0, 'MYR', 'monthly') | Expected: (2000.0, 2000.0, 'MYR', 'monthly')
# [180] ✅ Matched:   None
# [181] ✅ Matched:   None
# [182] ❌ Predicted: (36.0, 41.0, 'AUD', 'hourly') | Expected: (36.0, 41.0, 'AUD', 'hourly')
# [183] ✅ Matched:   (1.0, 2.0, 'THB', 'monthly')
# [184] ❌ Predicted: (2500.0, 3200.0, 'SGD', 'monthly') | Expected: (2500.0, 3200.0, 'SGD', 'monthly')
# [185] ✅ Matched:   (50.0, 50.0, 'AUD', 'monthly')
# [186] ✅ Matched:   (1023.0, 1023.0, 'PHP', 'monthly')
# [187] ✅ Matched:   (44.92, 44.92, 'AUD', 'hourly')
# [188] ✅ Matched:   (47.5, 47.5, 'AUD', 'hourly')
# [189] ✅ Matched:   None
# [190] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [191] ✅ Matched:   None
# [192] ✅ Matched:   None
# [193] ✅ Matched:   (70000.0, 70000.0, 'AUD', 'monthly')
# [194] ✅ Matched:   (50336.67, 55225.8, 'AUD', 'monthly')
# [195] ✅ Matched:   None
# [196] ✅ Matched:   None
# [197] ✅ Matched:   None
# [198] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [199] ✅ Matched:   None
# [200] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [201] ✅ Matched:   (59113.0, 62794.0, 'AUD', 'monthly')
# [202] ✅ Matched:   (5000.0, 5000.0, 'AUD', 'monthly')
# [203] ✅ Matched:   (77.0, 93.0, 'HKD', 'monthly')
# [204] ✅ Matched:   (40.72, 40.72, 'AUD', 'monthly')
# [205] ✅ Matched:   None
# [206] ✅ Matched:   None
# [207] ✅ Matched:   None
# [208] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [209] ✅ Matched:   (2500.0, 2500.0, 'SGD', 'monthly')
# [210] ❌ Predicted: (22000.0, 22000.0, 'PHP', 'monthly') | Expected: (22000.0, 22000.0, 'PHP', 'monthly')
# [211] ✅ Matched:   (29.1, 30.11, 'AUD', 'hourly')
# [212] ❌ Predicted: (28.0, 30.0, 'NZD', 'hourly') | Expected: (28.0, 30.0, 'NZD', 'hourly')
# [213] ✅ Matched:   None
# [214] ✅ Matched:   (35.33, 49.6, 'AUD', 'hourly')
# [215] ✅ Matched:   None
# [216] ✅ Matched:   None
# [217] ❌ Predicted: (105.0, 105.0, 'AUD', 'hourly') | Expected: (105.0, 105.0, 'AUD', 'hourly')
# [218] ❌ Predicted: (17000.0, 17000.0, 'PHP', 'monthly') | Expected: (17000.0, 17000.0, 'PHP', 'monthly')
# [219] ✅ Matched:   (35.0, 45.0, 'NZD', 'annual')
# [220] ✅ Matched:   None
# [222] ✅ Matched:   (41.0, 41.0, 'AUD', 'annual')
# [223] ❌ Predicted: (2300.0, 3500.0, 'SGD', 'monthly') | Expected: (2300.0, 3500.0, 'SGD', 'monthly')
# [224] ✅ Matched:   None
# [225] ✅ Matched:   None
# [226] ✅ Matched:   (5000.0, 5000.0, 'AUD', 'monthly')
# [229] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [230] ✅ Matched:   None
# [231] ❌ Predicted: (77.0, 110.0, 'HKD', 'hourly') | Expected: (77.0, 110.0, 'HKD', 'hourly')
# [232] ✅ Matched:   None
# [233] ❌ Predicted: (2000.0, 2000.0, 'MYR', 'monthly') | Expected: (2000.0, 2000.0, 'MYR', 'monthly')
# [234] ✅ Matched:   None
# [235] ✅ Matched:   (1500.0, 1500.0, 'MYR', 'monthly')
# [236] ✅ Matched:   (3000.0, 35005.0, 'SGD', 'monthly')
# [237] ✅ Matched:   (54.5, 54.5, 'AUD', 'hourly')
# [238] ✅ Matched:   (34.04, 34.04, 'AUD', 'hourly')
# [239] ✅ Matched:   None
# [240] ✅ Matched:   None
# [241] ✅ Matched:   None
# [242] ✅ Matched:   (71838.4, 83487.12, 'AUD', 'monthly')
# [243] ✅ Matched:   None
# [244] ❌ Predicted: (4000.0, 5000.0, 'MYR', 'monthly') | Expected: (4000.0, 5000.0, 'MYR', 'monthly')
# [246] ✅ Matched:   (0.0, 18.0, 'HKD', 'hourly')
# [247] ✅ Matched:   None
# [248] ✅ Matched:   (1600.0, 1600.0, 'MYR', 'monthly')
# [249] ❌ Predicted: (63.0, 63.0, 'HKD', 'hourly') | Expected: (63.0, 63.0, 'HKD', 'hourly')
# [250] ❌ Predicted: (1900.0, 1900.0, 'MYR', 'monthly') | Expected: (1900.0, 1900.0, 'MYR', 'monthly')
# [251] ✅ Matched:   None
# [252] ✅ Matched:   (63.0, 63.0, 'MYR', 'monthly')
# [253] ✅ Matched:   None
# [254] ✅ Matched:   None
# [255] ✅ Matched:   None
# [256] ✅ Matched:   None
# [257] ✅ Matched:   None
# [258] ✅ Matched:   None
# [259] ✅ Matched:   None
# [260] ✅ Matched:   None
# [261] ✅ Matched:   None
# [262] ✅ Matched:   (123870.36, 127316.75, 'AUD', 'annual')
# [263] ❌ Predicted: (60000.0, 60000.0, 'AUD', 'annual') | Expected: (60000.0, 60000.0, 'AUD', 'annual')
# [265] ❌ Predicted: (12500.0, 12500.0, 'PHP', 'monthly') | Expected: (12500.0, 12500.0, 'PHP', 'monthly')
# [266] ✅ Matched:   (26.73, 26.73, 'AUD', 'monthly')
# [267] ✅ Matched:   (2000.0, 2000.0, 'HKD', 'monthly')
# [268] ❌ Predicted: (3.0, 3.0, 'HKD', 'monthly') | Expected: None
# [269] ❌ Predicted: (30.0, 42.0, 'AUD', 'hourly') | Expected: (30.0, 42.0, 'AUD', 'hourly')
# [270] ❌ Predicted: (1.0, 1.0, 'PHP', 'monthly') | Expected: None
# [271] ✅ Matched:   (2800.0, 30005.0, 'SGD', 'monthly')
# [272] ❌ Predicted: (70.0, 75.0, 'HKD', 'hourly') | Expected: (70.0, 75.0, 'HKD', 'hourly')
# [273] ✅ Matched:   None
# [274] ✅ Matched:   None
# [275] ✅ Matched:   None
# [276] ✅ Matched:   None
# [277] ✅ Matched:   None
# [278] ❌ Predicted: (1250.0, 1875.0, 'SGD', 'weekly') | Expected: (1250.0, 1875.0, 'SGD', 'weekly')
# [279] ✅ Matched:   (103915.0, 113267.0, 'AUD', 'monthly')
# [280] ❌ Predicted: (14.0, 14.0, 'SGD', 'hourly') | Expected: (14.0, 14.0, 'SGD', 'hourly')
# [281] ❌ Predicted: (21000.0, 21000.0, 'PHP', 'monthly') | Expected: (21000.0, 21000.0, 'PHP', 'monthly')
# [282] ✅ Matched:   (47.5, 49.65, 'AUD', 'hourly')
# [283] ❌ Predicted: (18.0, 18.0, 'HKD', 'monthly') | Expected: None
# [284] ✅ Matched:   None
# [285] ❌ Predicted: (30.0, 30.0, 'AUD', 'hourly') | Expected: (30.0, 30.0, 'AUD', 'hourly')
# [286] ❌ Predicted: (65.0, 65.0, 'HKD', 'hourly') | Expected: (65.0, 65.0, 'HKD', 'hourly')
# [287] ❌ Predicted: (133671.0, 133671.0, 'AUD', 'annual') | Expected: (133671.0, 133671.0, 'AUD', 'annual')
# [288] ✅ Matched:   (37.21, 53.92, 'AUD', 'monthly')
# [289] ✅ Matched:   None
# [290] ✅ Matched:   (30.79, 30.79, 'AUD', 'hourly')
# [291] ✅ Matched:   None
# [292] ❌ Predicted: (270.0, 270.0, 'HKD', 'hourly') | Expected: (270.0, 270.0, 'HKD', 'hourly')
# [293] ❌ Predicted: (133671.0, 159929.0, 'AUD', 'annual') | Expected: (133671.0, 159929.0, 'AUD', 'annual')
# [294] ✅ Matched:   (200.0, 267.0, 'SGD', 'monthly')
# [295] ✅ Matched:   (600.0, 600.0, 'PHP', 'monthly')
# [296] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [297] ✅ Matched:   None
# [298] ✅ Matched:   None
# [299] ✅ Matched:   None
# [300] ✅ Matched:   None
# [301] ❌ Predicted: (12.0, 15.0, 'SGD', 'hourly') | Expected: (12.0, 15.0, 'SGD', 'hourly')
# [302] ✅ Matched:   (9.0, 9.0, 'MYR', 'hourly')
# [303] ❌ Predicted: (100.0, 100.0, 'HKD', 'hourly') | Expected: (100.0, 100.0, 'HKD', 'hourly')
# [304] ✅ Matched:   None
# [305] ✅ Matched:   None
# [307] ✅ Matched:   None
# [308] ✅ Matched:   None
# [309] ✅ Matched:   (24.08, 54.18, 'AUD', 'hourly')
# [310] ✅ Matched:   None
# [311] ❌ Predicted: (5000.0, 7000.0, 'SGD', 'monthly') | Expected: (5000.0, 7000.0, 'SGD', 'monthly')
# [312] ✅ Matched:   None
# [313] ✅ Matched:   (73000.0, 80000.0, 'AUD', 'monthly')
# [314] ✅ Matched:   None
# [315] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [316] ✅ Matched:   (100.0, 100.0, 'HKD', 'monthly')
# [317] ✅ Matched:   None
# [318] ✅ Matched:   (1800.0, 1800.0, 'SGD', 'monthly')
# [319] ❌ Predicted: (7000.0, 7000.0, 'MYR', 'monthly') | Expected: (7000.0, 7000.0, 'MYR', 'monthly')
# [320] ❌ Predicted: (3000.0, 4000.0, 'SGD', 'monthly') | Expected: (3000.0, 4000.0, 'SGD', 'monthly')
# [321] ❌ Predicted: (2000.0, 3000.0, 'SGD', 'monthly') | Expected: (2000.0, 3000.0, 'SGD', 'monthly')
# [322] ❌ Predicted: (8200.0, 9200.0, 'SGD', 'monthly') | Expected: (8200.0, 9200.0, 'SGD', 'monthly')
# [323] ✅ Matched:   (42.5, 42.5, 'AUD', 'hourly')
# [325] ✅ Matched:   None
# [326] ✅ Matched:   (33.28, 33.28, 'AUD', 'hourly')
# [327] ✅ Matched:   None
# [328] ✅ Matched:   (5000.0, 5000.0, 'AUD', 'annual')
# [329] ❌ Predicted: (25.0, 27.0, 'NZD', 'hourly') | Expected: (25.0, 27.0, 'NZD', 'hourly')
# [330] ✅ Matched:   None
# [331] ✅ Matched:   (4250.0, 4250.0, 'HKD', 'monthly')
# [332] ✅ Matched:   None
# [333] ✅ Matched:   (45.0, 45.0, 'AUD', 'hourly')
# [334] ✅ Matched:   None
# [335] ✅ Matched:   (20.0, 20.0, 'SGD', 'monthly')
# [336] ❌ Predicted: (100.0, 100.0, 'HKD', 'hourly') | Expected: (100.0, 100.0, 'HKD', 'hourly')
# [337] ✅ Matched:   None
# [338] ✅ Matched:   None
# [339] ❌ Predicted: (83988.0, 83988.0, 'AUD', 'annual') | Expected: (83988.0, 83988.0, 'AUD', 'annual')
# [340] ✅ Matched:   (45.0, 50.0, 'AUD', 'annual')
# [342] ✅ Matched:   None
# [343] ✅ Matched:   None
# [344] ✅ Matched:   None
# [345] ✅ Matched:   (10000.0, 10000.0, 'AUD', 'monthly')
# [347] ✅ Matched:   None
# [348] ❌ Predicted: (3800.0, 5000.0, 'SGD', 'monthly') | Expected: (3800.0, 5000.0, 'SGD', 'monthly')
# [349] ✅ Matched:   None
# [350] ✅ Matched:   None
# [351] ✅ Matched:   None
# [352] ✅ Matched:   (84.69, 84.69, 'AUD', 'hourly')
# [353] ✅ Matched:   None
# [354] ✅ Matched:   None
# [356] ✅ Matched:   None
# [357] ✅ Matched:   None
# [358] ✅ Matched:   None
# [359] ✅ Matched:   None
# [360] ✅ Matched:   None
# [361] ✅ Matched:   (700.0, 700.0, 'SGD', 'weekly')
# [362] ✅ Matched:   None
# [363] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [364] ❌ Predicted: (119348.0, 136057.0, 'AUD', 'annual') | Expected: (119348.0, 136057.0, 'AUD', 'annual')
# [365] ❌ Predicted: (10000000.0, 15000000.0, 'IDR', 'monthly') | Expected: (10000000.0, 15000000.0, 'IDR', 'monthly')
# [366] ❌ Predicted: (2500.0, 3500.0, 'SGD', 'monthly') | Expected: (2500.0, 3500.0, 'SGD', 'monthly')
# [367] ✅ Matched:   None
# [368] ✅ Matched:   (120.0, 120.0, 'HKD', 'monthly')
# [369] ✅ Matched:   None
# [370] ❌ Predicted: (25000.0, 37000.0, 'THB', 'monthly') | Expected: (25000.0, 37000.0, 'THB', 'monthly')
# [371] ✅ Matched:   (62525.58, 64583.5, 'AUD', 'annual')
# [373] ❌ Predicted: (46.0, 62.0, 'HKD', 'hourly') | Expected: (46.0, 62.0, 'HKD', 'hourly')
# [374] ✅ Matched:   None
# [375] ✅ Matched:   None
# [376] ✅ Matched:   None
# [377] ❌ Predicted: (110000.0, 140000.0, 'AUD', 'annual') | Expected: (110000.0, 140000.0, 'AUD', 'annual')
# [378] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [379] ✅ Matched:   None
# [381] ✅ Matched:   None
# [382] ✅ Matched:   None
# [383] ✅ Matched:   None
# [384] ✅ Matched:   None
# [385] ❌ Predicted: (1500.0, 1500.0, 'MYR', 'monthly') | Expected: (1500.0, 1500.0, 'MYR', 'monthly')
# [386] ✅ Matched:   None
# [387] ✅ Matched:   None
# [388] ✅ Matched:   (400.0, 600.0, 'HKD', 'monthly')
# [389] ✅ Matched:   None
# [390] ✅ Matched:   (100000.0, 140000.0, 'AUD', 'monthly')
# [392] ✅ Matched:   None
# [393] ✅ Matched:   None
# [394] ✅ Matched:   None
# [395] ❌ Predicted: (1.0, 1.0, 'HKD', 'monthly') | Expected: None
# [397] ✅ Matched:   None
# [398] ✅ Matched:   None
# [400] ✅ Matched:   None
# [401] ✅ Matched:   None
# [403] ✅ Matched:   None
# [404] ✅ Matched:   None
# [405] ✅ Matched:   None
# [407] ✅ Matched:   (22.49, 28.25, 'NZD', 'hourly')
# [408] ❌ Predicted: (110.0, 110.0, 'HKD', 'hourly') | Expected: (110.0, 110.0, 'HKD', 'hourly')
# [409] ✅ Matched:   None
# [410] ✅ Matched:   None
# [412] ✅ Matched:   None
# [413] ❌ Predicted: (8.0, 13.0, 'SGD', 'hourly') | Expected: (8.0, 13.0, 'SGD', 'hourly')
# [414] ❌ Predicted: (2500.0, 3400.0, 'SGD', 'monthly') | Expected: (2500.0, 3400.0, 'SGD', 'monthly')
# [415] ✅ Matched:   (3300.0, 3300.0, 'MYR', 'monthly')
# [416] ✅ Matched:   None
# [417] ✅ Matched:   None
# [418] ✅ Matched:   None
# [420] ✅ Matched:   None
# [421] ✅ Matched:   None
# [422] ✅ Matched:   (67.0, 100.0, 'SGD', 'monthly')
# [423] ✅ Matched:   None
# [424] ❌ Predicted: (102051.0, 125151.0, 'AUD', 'annual') | Expected: (102051.0, 125151.0, 'AUD', 'annual')
# [425] ❌ Predicted: (12.0, 12.0, 'SGD', 'hourly') | Expected: (12.0, 12.0, 'SGD', 'hourly')
# [426] ✅ Matched:   None
# [427] ✅ Matched:   None
# [428] ✅ Matched:   (117.0, 143.0, 'PHP', 'monthly')
# [431] ✅ Matched:   (700.0, 875.0, 'SGD', 'monthly')
# [432] ✅ Matched:   None
# [433] ✅ Matched:   None
# [434] ✅ Matched:   None
# [436] ✅ Matched:   None
# [437] ✅ Matched:   (200.0, 200.0, 'HKD', 'monthly')
# [439] ✅ Matched:   (30000.0, 30000.0, 'THB', 'monthly')
# [440] ✅ Matched:   None
# [441] ✅ Matched:   None
# [442] ✅ Matched:   None
# [443] ❌ Predicted: (12500.0, 12500.0, 'PHP', 'monthly') | Expected: (12500.0, 12500.0, 'PHP', 'monthly')
# [444] ✅ Matched:   (27.76, 27.76, 'NZD', 'monthly')
# [445] ✅ Matched:   None
# [447] ✅ Matched:   None
# [448] ❌ Predicted: (27.0, 27.0, 'AUD', 'hourly') | Expected: (27.0, 27.0, 'AUD', 'hourly')
# [449] ✅ Matched:   None
# [450] ❌ Predicted: (40.0, 40.0, 'AUD', 'hourly') | Expected: (40.0, 40.0, 'AUD', 'hourly')
# [451] ❌ Predicted: (80.0, 95.0, 'HKD', 'hourly') | Expected: (80.0, 95.0, 'HKD', 'hourly')
# [452] ✅ Matched:   (6.0, 12.0, 'AUD', 'monthly')
# [453] ✅ Matched:   None
# [454] ✅ Matched:   None
# [455] ✅ Matched:   (20.0, 20.0, 'NZD', 'hourly')
# [456] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [457] ✅ Matched:   None
# [458] ✅ Matched:   (15000.0, 15000.0, 'THB', 'monthly')
# [459] ❌ Predicted: (60.0, 70.0, 'HKD', 'hourly') | Expected: (60.0, 70.0, 'HKD', 'hourly')
# [460] ✅ Matched:   None
# [461] ✅ Matched:   None
# [462] ❌ Predicted: (52.0, 60.0, 'HKD', 'hourly') | Expected: (52.0, 60.0, 'HKD', 'hourly')
# [463] ❌ Predicted: (60.0, 80.0, 'HKD', 'hourly') | Expected: (60.0, 80.0, 'HKD', 'hourly')
# [464] ✅ Matched:   None
# [465] ✅ Matched:   None
# [466] ✅ Matched:   (8500.0, 8500.0, 'MYR', 'monthly')
# [467] ✅ Matched:   None
# [468] ✅ Matched:   None
# [470] ❌ Predicted: (53.0, 53.0, 'HKD', 'hourly') | Expected: (53.0, 53.0, 'HKD', 'hourly')
# [471] ✅ Matched:   None
# [472] ✅ Matched:   (37.13, 37.13, 'AUD', 'hourly')
# [473] ✅ Matched:   (62000.0, 72000.0, 'AUD', 'monthly')
# [474] ❌ Predicted: (100.0, 120.0, 'HKD', 'hourly') | Expected: (100.0, 120.0, 'HKD', 'hourly')
# [475] ❌ Predicted: (21000.0, 21000.0, 'PHP', 'monthly') | Expected: (21000.0, 21000.0, 'PHP', 'monthly')
# [478] ✅ Matched:   None
# [479] ✅ Matched:   (30.45, 30.45, 'AUD', 'hourly')
# [480] ✅ Matched:   (4250.0, 4250.0, 'HKD', 'monthly')
# [481] ✅ Matched:   (63.0, 131.25, 'AUD', 'annual')
# [482] ✅ Matched:   None
# [483] ✅ Matched:   None
# [484] ✅ Matched:   (875.0, 950.0, 'SGD', 'monthly')
# [485] ✅ Matched:   (26.87, 26.87, 'AUD', 'hourly')
# [486] ❌ Predicted: (2000.0, 2700.0, 'SGD', 'monthly') | Expected: (2000.0, 2700.0, 'SGD', 'monthly')
# [487] ✅ Matched:   None
# [488] ✅ Matched:   (22.8, 22.8, 'NZD', 'hourly')
# [489] ✅ Matched:   None
# [490] ✅ Matched:   None
# [491] ❌ Predicted: (45.0, 60.0, 'HKD', 'hourly') | Expected: (45.0, 60.0, 'HKD', 'hourly')
# [492] ❌ Predicted: (50.0, 80.0, 'HKD', 'hourly') | Expected: (50.0, 80.0, 'HKD', 'hourly')
# [493] ❌ Predicted: (2000.0, 3000.0, 'SGD', 'monthly') | Expected: (2000.0, 3000.0, 'SGD', 'monthly')
# [494] ✅ Matched:   (10.0, 12.0, 'SGD', 'monthly')
# [495] ✅ Matched:   None
# [496] ❌ Predicted: (65.0, 75.0, 'HKD', 'hourly') | Expected: (65.0, 75.0, 'HKD', 'hourly')
# [497] ✅ Matched:   (30.0, 34.99, 'NZD', 'hourly')
# [498] ✅ Matched:   None
# [499] ✅ Matched:   (35.0, 35.0, 'SGD', 'monthly')
# [500] ❌ Predicted: (125000.0, 125000.0, 'PHP', 'monthly') | Expected: (125000.0, 125000.0, 'PHP', 'monthly')
# [501] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [503] ❌ Predicted: (80.0, 80.0, 'HKD', 'hourly') | Expected: (80.0, 80.0, 'HKD', 'hourly')
# [504] ✅ Matched:   (20.0, 20.0, 'SGD', 'monthly')
# [505] ✅ Matched:   None
# [507] ✅ Matched:   None
# [508] ✅ Matched:   (30.11, 30.11, 'AUD', 'hourly')
# [509] ✅ Matched:   None
# [510] ✅ Matched:   None
# [511] ✅ Matched:   None
# [512] ✅ Matched:   None
# [513] ❌ Predicted: (63.0, 63.0, 'HKD', 'hourly') | Expected: (63.0, 63.0, 'HKD', 'hourly')
# [514] ✅ Matched:   None
# [515] ✅ Matched:   None
# [516] ❌ Predicted: (65.0, 70.0, 'HKD', 'hourly') | Expected: (65.0, 70.0, 'HKD', 'hourly')
# [517] ❌ Predicted: (70.0, 77.0, 'HKD', 'hourly') | Expected: (70.0, 77.0, 'HKD', 'hourly')
# [518] ✅ Matched:   None
# [519] ✅ Matched:   (118643.63, 118643.63, 'AUD', 'annual')
# [520] ✅ Matched:   (36.0, 36.0, 'AUD', 'monthly')
# [521] ✅ Matched:   None
# [522] ✅ Matched:   None
# [523] ✅ Matched:   None
# [524] ✅ Matched:   (10000.0, 10000.0, 'AUD', 'annual')
# [525] ✅ Matched:   (85000.0, 85000.0, 'AUD', 'annual')
# [526] ✅ Matched:   (5000.0, 5000.0, 'AUD', 'annual')
# [528] ✅ Matched:   (22.49, 28.25, 'NZD', 'monthly')
# [529] ✅ Matched:   None
# [530] ❌ Predicted: (55.0, 65.0, 'HKD', 'hourly') | Expected: (55.0, 65.0, 'HKD', 'hourly')
# [531] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [532] ✅ Matched:   None
# [533] ✅ Matched:   None
# [534] ✅ Matched:   None
# [535] ✅ Matched:   None
# [537] ✅ Matched:   (25.0, 16.0, 'HKD', 'monthly')
# [538] ✅ Matched:   None
# [539] ✅ Matched:   (36.58, 36.58, 'AUD', 'hourly')
# [540] ❌ Predicted: (34.0, 50.0, 'AUD', 'hourly') | Expected: (34.0, 50.0, 'AUD', 'hourly')
# [541] ✅ Matched:   None
# [542] ✅ Matched:   (33.56, 33.56, 'AUD', 'annual')
# [543] ✅ Matched:   (67357.32, 94568.44, 'AUD', 'annual')
# [544] ❌ Predicted: (90.0, 100.0, 'HKD', 'hourly') | Expected: (90.0, 100.0, 'HKD', 'hourly')
# [545] ✅ Matched:   None
# [546] ✅ Matched:   None
# [547] ❌ Predicted: (500.0, 650.0, 'SGD', 'weekly') | Expected: (500.0, 650.0, 'SGD', 'weekly')
# [548] ✅ Matched:   None
# [549] ✅ Matched:   (49.28, 49.28, 'AUD', 'annual')
# [550] ✅ Matched:   None
# [551] ✅ Matched:   None
# [552] ✅ Matched:   None
# [553] ❌ Predicted: (575.0, 875.0, 'SGD', 'weekly') | Expected: (575.0, 875.0, 'SGD', 'weekly')
# [554] ✅ Matched:   None
# [555] ❌ Predicted: (2500.0, 2500.0, 'MYR', 'monthly') | Expected: (2500.0, 2500.0, 'MYR', 'monthly')
# [556] ✅ Matched:   None
# [557] ❌ Predicted: (625.0, 800.0, 'SGD', 'weekly') | Expected: (625.0, 800.0, 'SGD', 'weekly')
# [558] ✅ Matched:   (375.0, 375.0, 'MYR', 'monthly')
# [559] ✅ Matched:   None
# [560] ✅ Matched:   (100.0, 127.0, 'SGD', 'monthly')
# [561] ❌ Predicted: (70.0, 107.0, 'HKD', 'hourly') | Expected: (70.0, 107.0, 'HKD', 'hourly')
# [562] ❌ Predicted: (3000.0, 4000.0, 'SGD', 'monthly') | Expected: (3000.0, 4000.0, 'SGD', 'monthly')
# [563] ✅ Matched:   None
# [564] ✅ Matched:   (533.0, 533.0, 'PHP', 'monthly')
# [565] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [566] ✅ Matched:   None
# [567] ❌ Predicted: (2000.0, 2400.0, 'SGD', 'monthly') | Expected: (2000.0, 2400.0, 'SGD', 'monthly')
# [568] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [569] ✅ Matched:   (50.0, 60.0, 'AUD', 'annual')
# [570] ✅ Matched:   (51.67, 59.03, 'AUD', 'monthly')
# [572] ❌ Predicted: (75.0, 75.0, 'HKD', 'hourly') | Expected: (75.0, 75.0, 'HKD', 'hourly')
# [573] ✅ Matched:   None
# [574] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [576] ❌ Predicted: (65000.0, 80000.0, 'AUD', 'annual') | Expected: (65000.0, 80000.0, 'AUD', 'annual')
# [577] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [578] ❌ Predicted: (78.0, 78.0, 'HKD', 'hourly') | Expected: (78.0, 78.0, 'HKD', 'hourly')
# [579] ❌ Predicted: (9.0, 10.0, 'SGD', 'hourly') | Expected: (9.0, 10.0, 'SGD', 'hourly')
# [581] ✅ Matched:   None
# [582] ✅ Matched:   None
# [583] ✅ Matched:   None
# [584] ✅ Matched:   (850.0, 850.0, 'HKD', 'annual')
# [585] ✅ Matched:   None
# [586] ✅ Matched:   None
# [587] ❌ Predicted: (40.0, 50.0, 'SGD', 'hourly') | Expected: (40.0, 50.0, 'SGD', 'hourly')
# [588] ❌ Predicted: (37.0, 45.0, 'NZD', 'hourly') | Expected: (37.0, 45.0, 'NZD', 'hourly')
# [589] ✅ Matched:   None
# [591] ✅ Matched:   None
# [593] ❌ Predicted: (50.0, 68.0, 'HKD', 'hourly') | Expected: (50.0, 68.0, 'HKD', 'hourly')
# [594] ❌ Predicted: (3500.0, 4000.0, 'SGD', 'monthly') | Expected: (3500.0, 4000.0, 'SGD', 'monthly')
# [595] ❌ Predicted: (1500.0, 2200.0, 'SGD', 'monthly') | Expected: (1500.0, 2200.0, 'SGD', 'monthly')
# [596] ✅ Matched:   (40.26, 40.26, 'AUD', 'hourly')
# [597] ✅ Matched:   None
# [598] ❌ Predicted: (65.0, 75.0, 'HKD', 'hourly') | Expected: (65.0, 75.0, 'HKD', 'hourly')
# [600] ❌ Predicted: (2000.0, 2800.0, 'SGD', 'monthly') | Expected: (2000.0, 2800.0, 'SGD', 'monthly')
# [601] ❌ Predicted: (50.0, 80.0, 'HKD', 'hourly') | Expected: (50.0, 80.0, 'HKD', 'hourly')
# [602] ✅ Matched:   None
# [604] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [605] ✅ Matched:   None
# [606] ✅ Matched:   None
# [607] ✅ Matched:   None
# [608] ✅ Matched:   (26.0, 26.0, 'NZD', 'monthly')
# [609] ✅ Matched:   (1000.0, 1500.0, 'SGD', 'annual')
# [611] ✅ Matched:   None
# [612] ✅ Matched:   None
# [613] ✅ Matched:   None
# [614] ✅ Matched:   None
# [617] ✅ Matched:   None
# [618] ❌ Predicted: (34.0, 34.0, 'AUD', 'hourly') | Expected: (34.0, 34.0, 'AUD', 'hourly')
# [619] ✅ Matched:   None
# [620] ✅ Matched:   None
# [621] ✅ Matched:   (28.0, 28.0, 'AUD', 'hourly')
# [622] ✅ Matched:   None
# [623] ✅ Matched:   None
# [624] ✅ Matched:   None
# [625] ✅ Matched:   (7000.0, 7000.0, 'SGD', 'monthly')
# [626] ❌ Predicted: (117544.0, 120393.0, 'AUD', 'annual') | Expected: (117544.0, 120393.0, 'AUD', 'annual')
# [627] ❌ Predicted: (2600.0, 3400.0, 'SGD', 'monthly') | Expected: (2600.0, 3400.0, 'SGD', 'monthly')
# [628] ✅ Matched:   None
# [629] ✅ Matched:   None
# [630] ✅ Matched:   (55.24, 55.24, 'AUD', 'hourly')
# [631] ✅ Matched:   None
# [632] ❌ Predicted: (17.0, 25.0, 'PHP', 'daily') | Expected: (17.0, 25.0, 'PHP', 'daily')
# [633] ✅ Matched:   (127.0, 150.0, 'SGD', 'monthly')
# [634] ✅ Matched:   (85000.0, 85000.0, 'AUD', 'annual')
# [635] ✅ Matched:   None
# [636] ✅ Matched:   None
# [637] ❌ Predicted: (19000.0, 19000.0, 'PHP', 'monthly') | Expected: (19000.0, 19000.0, 'PHP', 'monthly')
# [638] ✅ Matched:   (43.82, 43.82, 'AUD', 'annual')
# [642] ✅ Matched:   None
# [643] ❌ Predicted: (83.0, 100.0, 'MYR', 'daily') | Expected: (83.0, 100.0, 'MYR', 'daily')
# [644] ✅ Matched:   (30000.0, 30000.0, 'THB', 'monthly')
# [646] ✅ Matched:   (41.77, 51.72, 'AUD', 'hourly')
# [647] ✅ Matched:   None
# [649] ✅ Matched:   (27.65, 40.0, 'AUD', 'hourly')
# [650] ✅ Matched:   (34.05, 34.05, 'AUD', 'monthly')
# [651] ✅ Matched:   (70.0, 80.0, 'HKD', 'monthly')
# [652] ✅ Matched:   (2.0, 2.0, 'MYR', 'monthly')
# [653] ✅ Matched:   None
# [654] ✅ Matched:   None
# [655] ✅ Matched:   None
# [656] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [657] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [658] ✅ Matched:   None
# [659] ❌ Predicted: (50.0, 65.0, 'HKD', 'hourly') | Expected: (50.0, 65.0, 'HKD', 'hourly')
# [660] ✅ Matched:   None
# [661] ✅ Matched:   None
# [662] ✅ Matched:   None
# [665] ❌ Predicted: (70.0, 70.0, 'HKD', 'hourly') | Expected: (70.0, 70.0, 'HKD', 'hourly')
# [666] ❌ Predicted: (55.0, 80.0, 'HKD', 'hourly') | Expected: (55.0, 80.0, 'HKD', 'hourly')
# [667] ✅ Matched:   (37.31, 37.31, 'AUD', 'hourly')
# [668] ✅ Matched:   None
# [669] ✅ Matched:   (1600.0, 1600.0, 'MYR', 'monthly')
# [670] ✅ Matched:   (24.36, 29.23, 'AUD', 'annual')
# [671] ✅ Matched:   None
# [672] ✅ Matched:   None
# [673] ❌ Predicted: (48.0, 55.0, 'AUD', 'hourly') | Expected: (48.0, 55.0, 'AUD', 'hourly')
# [674] ✅ Matched:   None
# [675] ✅ Matched:   None
# [676] ✅ Matched:   (36.0, 36.0, 'AUD', 'monthly')
# [677] ✅ Matched:   None
# [678] ✅ Matched:   (170.0, 170.0, 'AUD', 'annual')
# [679] ❌ Predicted: (83.0, 83.0, 'SGD', 'daily') | Expected: (83.0, 83.0, 'SGD', 'daily')
# [681] ✅ Matched:   (64265.74, 64265.74, 'AUD', 'annual')
# [682] ✅ Matched:   None
# [683] ✅ Matched:   (31.53, 32.57, 'AUD', 'annual')
# [684] ✅ Matched:   (67.0, 80.0, 'HKD', 'monthly')
# [685] ❌ Predicted: (2600.0, 3500.0, 'SGD', 'monthly') | Expected: (2600.0, 3500.0, 'SGD', 'monthly')
# [687] ❌ Predicted: (65.0, 65.0, 'HKD', 'hourly') | Expected: (65.0, 65.0, 'HKD', 'hourly')
# [688] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [689] ✅ Matched:   (100.0, 1335.0, 'PHP', 'monthly')
# [690] ✅ Matched:   None
# [691] ✅ Matched:   None
# [693] ❌ Predicted: (1800.0, 3000.0, 'SGD', 'monthly') | Expected: (1800.0, 3000.0, 'SGD', 'monthly')
# [694] ✅ Matched:   (29.06, 32.56, 'AUD', 'monthly')
# [695] ✅ Matched:   None
# [696] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [697] ✅ Matched:   (68.2, 68.2, 'HKD', 'hourly')
# [698] ❌ Predicted: (50.0, 55.0, 'HKD', 'hourly') | Expected: (50.0, 55.0, 'HKD', 'hourly')
# [699] ✅ Matched:   None
# [700] ✅ Matched:   (48.12, 48.12, 'AUD', 'hourly')
# [701] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [702] ✅ Matched:   None
# [703] ❌ Predicted: (2600.0, 3400.0, 'SGD', 'monthly') | Expected: (2600.0, 3400.0, 'SGD', 'monthly')
# [704] ✅ Matched:   (3100.0, 3100.0, 'SGD', 'monthly')
# [705] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [706] ❌ Predicted: (2800.0, 3050.0, 'SGD', 'monthly') | Expected: (2800.0, 3050.0, 'SGD', 'monthly')
# [707] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [708] ✅ Matched:   None
# [709] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [710] ✅ Matched:   (21.3, 21.3, 'NZD', 'hourly')
# [711] ✅ Matched:   None
# [712] ✅ Matched:   None
# [713] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [714] ✅ Matched:   None
# [716] ✅ Matched:   (40.9, 48.05, 'AUD', 'monthly')
# [717] ✅ Matched:   None
# [719] ❌ Predicted: (3000.0, 3300.0, 'SGD', 'monthly') | Expected: (3000.0, 3300.0, 'SGD', 'monthly')
# [720] ❌ Predicted: (2000.0, 2000.0, 'MYR', 'monthly') | Expected: (2000.0, 2000.0, 'MYR', 'monthly')
# [721] ✅ Matched:   None
# [722] ❌ Predicted: (23000.0, 23000.0, 'PHP', 'monthly') | Expected: (23000.0, 23000.0, 'PHP', 'monthly')
# [723] ❌ Predicted: (90.0, 90.0, 'HKD', 'hourly') | Expected: (90.0, 90.0, 'HKD', 'hourly')
# [725] ✅ Matched:   None
# [726] ✅ Matched:   None
# [727] ✅ Matched:   None
# [728] ✅ Matched:   None
# [729] ✅ Matched:   None
# [730] ✅ Matched:   (65000.0, 75000.0, 'AUD', 'monthly')
# [732] ❌ Predicted: (2200.0, 3400.0, 'SGD', 'monthly') | Expected: (2200.0, 3400.0, 'SGD', 'monthly')
# [733] ❌ Predicted: (77.0, 87.0, 'SGD', 'daily') | Expected: (77.0, 87.0, 'SGD', 'daily')
# [734] ❌ Predicted: (100.0, 117.0, 'SGD', 'daily') | Expected: (100.0, 117.0, 'SGD', 'daily')
# [735] ❌ Predicted: (2500.0, 3800.0, 'SGD', 'monthly') | Expected: (2500.0, 3800.0, 'SGD', 'monthly')
# [736] ✅ Matched:   None
# [737] ✅ Matched:   None
# [738] ✅ Matched:   (680.0, 1020.0, 'HKD', 'hourly')
# [739] ✅ Matched:   None
# [740] ❌ Predicted: (17000.0, 17000.0, 'PHP', 'monthly') | Expected: (17000.0, 17000.0, 'PHP', 'monthly')
# [741] ✅ Matched:   None
# [742] ✅ Matched:   None
# [745] ✅ Matched:   None
# [746] ✅ Matched:   None
# [747] ❌ Predicted: (10000.0, 15000.0, 'MYR', 'monthly') | Expected: (10000.0, 15000.0, 'MYR', 'monthly')
# [748] ✅ Matched:   None
# [749] ✅ Matched:   None
# [750] ✅ Matched:   (1125.0, 1500.0, 'HKD', 'monthly')
# [751] ✅ Matched:   None
# [752] ✅ Matched:   None
# [753] ✅ Matched:   (80.0, 117.0, 'PHP', 'monthly')
# [754] ✅ Matched:   None
# [755] ✅ Matched:   (32.29, 33.75, 'AUD', 'monthly')
# [756] ✅ Matched:   None
# [757] ✅ Matched:   (25.0, 25.0, 'NZD', 'hourly')
# [758] ✅ Matched:   None
# [759] ✅ Matched:   None
# [760] ✅ Matched:   None
# [762] ❌ Predicted: (150.0, 200.0, 'HKD', 'hourly') | Expected: (150.0, 200.0, 'HKD', 'hourly')
# [763] ❌ Predicted: (50.0, 65.0, 'HKD', 'hourly') | Expected: (50.0, 65.0, 'HKD', 'hourly')
# [764] ✅ Matched:   None
# [765] ✅ Matched:   None
# [767] ✅ Matched:   None
# [768] ❌ Predicted: (13000.0, 14900.0, 'HKD', 'monthly') | Expected: (13000.0, 14900.0, 'HKD', 'monthly')
# [769] ✅ Matched:   (2500.0, 2500.0, 'SGD', 'monthly')
# [770] ✅ Matched:   (83.0, 100.0, 'SGD', 'monthly')
# [771] ✅ Matched:   None
# [772] ✅ Matched:   (35.32, 49.6, 'AUD', 'annual')
# [773] ✅ Matched:   (83.0, 100.0, 'HKD', 'monthly')
# [774] ✅ Matched:   None
# [775] ✅ Matched:   (51.32, 52.82, 'NZD', 'monthly')
# [776] ✅ Matched:   (89598.0, 94514.0, 'AUD', 'monthly')
# [777] ✅ Matched:   (35.32, 49.6, 'AUD', 'annual')
# [779] ✅ Matched:   None
# [780] ✅ Matched:   None
# [781] ❌ Predicted: (27000.0, 27000.0, 'PHP', 'monthly') | Expected: (27000.0, 27000.0, 'PHP', 'monthly')
# [782] ❌ Predicted: (65.0, 75.0, 'HKD', 'hourly') | Expected: (65.0, 75.0, 'HKD', 'hourly')
# [785] ✅ Matched:   None
# [787] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [788] ✅ Matched:   None
# [789] ✅ Matched:   None
# [790] ✅ Matched:   (80000.0, 80000.0, 'THB', 'monthly')
# [791] ✅ Matched:   (123031.85, 125546.86, 'AUD', 'annual')
# [792] ✅ Matched:   None
# [793] ❌ Predicted: (30.0, 35.0, 'AUD', 'hourly') | Expected: (30.0, 35.0, 'AUD', 'hourly')
# [794] ❌ Predicted: (26.0, 26.0, 'NZD', 'hourly') | Expected: (26.0, 26.0, 'NZD', 'hourly')
# [795] ❌ Predicted: (89095.0, 139187.0, 'AUD', 'annual') | Expected: (89095.0, 139187.0, 'AUD', 'annual')
# [796] ❌ Predicted: (50.0, 60.0, 'HKD', 'hourly') | Expected: (50.0, 60.0, 'HKD', 'hourly')
# [797] ✅ Matched:   (3750.0, 3750.0, 'AUD', 'monthly')
# [798] ✅ Matched:   (100.0, 100.0, 'SGD', 'daily')
# [799] ✅ Matched:   (18550.0, 18550.0, 'AUD', 'monthly')
# [800] ✅ Matched:   None
# [801] ❌ Predicted: (65000.0, 75000.0, 'AUD', 'annual') | Expected: (65000.0, 75000.0, 'AUD', 'annual')
# [802] ✅ Matched:   (4500.0, 5750.0, 'HKD', 'monthly')
# [803] ❌ Predicted: (70.0, 100.0, 'AUD', 'hourly') | Expected: (70.0, 100.0, 'AUD', 'hourly')
# [804] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [805] ✅ Matched:   None
# [806] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [807] ✅ Matched:   None
# [808] ❌ Predicted: (67.0, 83.0, 'SGD', 'daily') | Expected: (67.0, 83.0, 'SGD', 'daily')
# [809] ✅ Matched:   (533.0, 533.0, 'HKD', 'monthly')
# [810] ✅ Matched:   (25.0, 25.0, 'AUD', 'monthly')
# [812] ✅ Matched:   None
# [813] ✅ Matched:   None
# [814] ✅ Matched:   (33.3, 34.34, 'AUD', 'hourly')
# [815] ❌ Predicted: (3000.0, 4500.0, 'SGD', 'monthly') | Expected: (3000.0, 4500.0, 'SGD', 'monthly')
# [816] ✅ Matched:   None
# [817] ❌ Predicted: (17000.0, 17000.0, 'PHP', 'monthly') | Expected: (17000.0, 17000.0, 'PHP', 'monthly')
# [818] ✅ Matched:   (31.84, 34.6, 'AUD', 'hourly')
# [819] ✅ Matched:   None
# [820] ✅ Matched:   (600.0, 600.0, 'SGD', 'monthly')
# [821] ❌ Predicted: (12.0, 12.0, 'SGD', 'hourly') | Expected: (12.0, 12.0, 'SGD', 'hourly')
# [822] ❌ Predicted: (2200.0, 2900.0, 'SGD', 'monthly') | Expected: (2200.0, 2900.0, 'SGD', 'monthly')
# [823] ✅ Matched:   None
# [824] ✅ Matched:   None
# [825] ✅ Matched:   (27.76, 27.76, 'NZD', 'hourly')
# [826] ✅ Matched:   None
# [827] ❌ Predicted: (3000.0, 3000.0, 'MYR', 'monthly') | Expected: (3000.0, 3000.0, 'MYR', 'monthly')
# [828] ✅ Matched:   (600.0, 900.0, 'SGD', 'annual')
# [829] ✅ Matched:   (103540.79, 107010.39, 'AUD', 'monthly')
# [830] ❌ Predicted: (2800.0, 3100.0, 'SGD', 'monthly') | Expected: (2800.0, 3100.0, 'SGD', 'monthly')
# [831] ✅ Matched:   (70.0, 80.0, 'HKD', 'monthly')
# [832] ✅ Matched:   None
# [835] ✅ Matched:   None
# [836] ✅ Matched:   None
# [837] ✅ Matched:   None
# [838] ✅ Matched:   None
# [839] ✅ Matched:   None
# [840] ❌ Predicted: (4500.0, 7200.0, 'SGD', 'monthly') | Expected: (4500.0, 7200.0, 'SGD', 'monthly')
# [841] ❌ Predicted: (55.0, 80.0, 'HKD', 'hourly') | Expected: (55.0, 80.0, 'HKD', 'hourly')
# [842] ✅ Matched:   None
# [843] ❌ Predicted: (60.0, 70.0, 'HKD', 'hourly') | Expected: (60.0, 70.0, 'HKD', 'hourly')
# [844] ✅ Matched:   None
# [845] ✅ Matched:   (83.0, 113.0, 'HKD', 'monthly')
# [846] ❌ Predicted: (19000.0, 19000.0, 'PHP', 'monthly') | Expected: (19000.0, 19000.0, 'PHP', 'monthly')
# [848] ✅ Matched:   (26.54, 26.54, 'AUD', 'hourly')
# [849] ❌ Predicted: (63.0, 73.0, 'HKD', 'hourly') | Expected: (63.0, 73.0, 'HKD', 'hourly')
# [850] ✅ Matched:   None
# [851] ❌ Predicted: (8.0, 8.0, 'HKD', 'monthly') | Expected: None
# [852] ✅ Matched:   None
# [853] ✅ Matched:   None
# [854] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [855] ✅ Matched:   None
# [856] ✅ Matched:   (1.0, 1.0, 'HKD', 'monthly')
# [857] ✅ Matched:   None
# [858] ✅ Matched:   (26.18, 26.18, 'AUD', 'hourly')
# [859] ✅ Matched:   None
# [861] ✅ Matched:   (93838.49, 93838.49, 'AUD', 'monthly')
# [862] ✅ Matched:   (60.0, 60.0, 'HKD', 'hourly')
# [863] ❌ Predicted: (18400.0, 18400.0, 'PHP', 'monthly') | Expected: (18400.0, 18400.0, 'PHP', 'monthly')
# [866] ✅ Matched:   (24.87, 24.87, 'AUD', 'monthly')
# [867] ✅ Matched:   None
# [868] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [869] ✅ Matched:   None
# [870] ✅ Matched:   None
# [871] ✅ Matched:   None
# [872] ✅ Matched:   None
# [874] ✅ Matched:   None
# [875] ✅ Matched:   None
# [876] ✅ Matched:   (3.51, 3.51, 'AUD', 'monthly')
# [877] ✅ Matched:   (100.0, 100.0, 'AUD', 'monthly')
# [878] ✅ Matched:   None
# [879] ✅ Matched:   None
# [880] ❌ Predicted: (3250.0, 4050.0, 'SGD', 'monthly') | Expected: (3250.0, 4050.0, 'SGD', 'monthly')
# [881] ✅ Matched:   None
# [882] ✅ Matched:   None
# [883] ✅ Matched:   None
# [884] ✅ Matched:   None
# [885] ❌ Predicted: (2600.0, 3600.0, 'SGD', 'monthly') | Expected: (2600.0, 3600.0, 'SGD', 'monthly')
# [886] ✅ Matched:   None
# [887] ❌ Predicted: (30.0, 35.0, 'AUD', 'hourly') | Expected: (30.0, 35.0, 'AUD', 'hourly')
# [888] ✅ Matched:   (9.0, 9.0, 'HKD', 'monthly')
# [889] ✅ Matched:   None
# [890] ✅ Matched:   None
# [892] ❌ Predicted: (1700.0, 2300.0, 'SGD', 'monthly') | Expected: (1700.0, 2300.0, 'SGD', 'monthly')
# [893] ❌ Predicted: (24000.0, 24000.0, 'PHP', 'monthly') | Expected: (24000.0, 24000.0, 'PHP', 'monthly')
# [894] ❌ Predicted: (50.0, 100.0, 'SGD', 'hourly') | Expected: (50.0, 100.0, 'SGD', 'hourly')
# [895] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [898] ✅ Matched:   (625.0, 875.0, 'SGD', 'weekly')
# [899] ✅ Matched:   None
# [900] ✅ Matched:   None
# [901] ✅ Matched:   None
# [902] ✅ Matched:   None
# [903] ✅ Matched:   (1250.0, 1250.0, 'AUD', 'monthly')
# [904] ✅ Matched:   None
# [905] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [906] ✅ Matched:   (1.0, 2.0, 'HKD', 'hourly')
# [907] ✅ Matched:   None
# [908] ✅ Matched:   None
# [909] ✅ Matched:   None
# [910] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [911] ✅ Matched:   None
# [912] ✅ Matched:   None
# [913] ✅ Matched:   None
# [914] ✅ Matched:   (80000.0, 80000.0, 'THB', 'monthly')
# [915] ❌ Predicted: (55.0, 55.0, 'HKD', 'hourly') | Expected: (55.0, 55.0, 'HKD', 'hourly')
# [916] ❌ Predicted: (100.0, 100.0, 'HKD', 'hourly') | Expected: (100.0, 100.0, 'HKD', 'hourly')
# [917] ✅ Matched:   (38.15, 49.2, 'AUD', 'annual')
# [918] ✅ Matched:   None
# [919] ❌ Predicted: (1640.0, 1640.0, 'SGD', 'monthly') | Expected: (1640.0, 1640.0, 'SGD', 'monthly')
# [920] ✅ Matched:   None
# [921] ✅ Matched:   None
# [922] ✅ Matched:   None
# [923] ✅ Matched:   None
# [924] ❌ Predicted: (3200.0, 3800.0, 'SGD', 'monthly') | Expected: (3200.0, 3800.0, 'SGD', 'monthly')
# [925] ✅ Matched:   None
# [926] ✅ Matched:   None
# [927] ✅ Matched:   (58650.0, 58650.0, 'NZD', 'monthly')
# [928] ❌ Predicted: (3000.0, 3500.0, 'SGD', 'monthly') | Expected: (3000.0, 3500.0, 'SGD', 'monthly')
# [929] ✅ Matched:   None
# [930] ❌ Predicted: (65.0, 75.0, 'HKD', 'hourly') | Expected: (65.0, 75.0, 'HKD', 'hourly')
# [931] ❌ Predicted: (55000.0, 77000.0, 'AUD', 'annual') | Expected: (55000.0, 77000.0, 'AUD', 'annual')
# [932] ✅ Matched:   None
# [933] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [935] ✅ Matched:   None
# [936] ❌ Predicted: (67.0, 90.0, 'SGD', 'daily') | Expected: (67.0, 90.0, 'SGD', 'daily')
# [937] ❌ Predicted: (65.0, 75.0, 'HKD', 'hourly') | Expected: (65.0, 75.0, 'HKD', 'hourly')
# [938] ✅ Matched:   (2000.0, 2000.0, 'MYR', 'monthly')
# [939] ✅ Matched:   None
# [940] ✅ Matched:   (55.0, 55.0, 'AUD', 'hourly')
# [941] ✅ Matched:   (22.7, 28.25, 'NZD', 'hourly')
# [942] ❌ Predicted: (6240.0, 6240.0, 'HKD', 'monthly') | Expected: (6240.0, 6240.0, 'HKD', 'monthly')
# [943] ✅ Matched:   None
# [944] ✅ Matched:   (300.0, 300.0, 'AUD', 'monthly')
# [945] ✅ Matched:   None
# [946] ❌ Predicted: (125000.0, 125000.0, 'PHP', 'monthly') | Expected: (125000.0, 125000.0, 'PHP', 'monthly')
# [947] ✅ Matched:   None
# [948] ❌ Predicted: (8.0, 8.0, 'HKD', 'monthly') | Expected: None
# [949] ✅ Matched:   None
# [950] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [951] ✅ Matched:   None
# [952] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [953] ✅ Matched:   (62.47, 64.21, 'AUD', 'annual')
# [954] ✅ Matched:   None
# [955] ✅ Matched:   (12000.0, 12000.0, 'HKD', 'monthly')
# [956] ✅ Matched:   (43.82, 43.82, 'AUD', 'annual')
# [957] ✅ Matched:   None
# [958] ✅ Matched:   None
# [959] ✅ Matched:   None
# [961] ✅ Matched:   None
# [962] ✅ Matched:   None
# [963] ✅ Matched:   (123104.9, 125557.29, 'AUD', 'annual')
# [965] ✅ Matched:   (50000.0, 50000.0, 'THB', 'monthly')
# [966] ✅ Matched:   None
# [967] ✅ Matched:   None
# [969] ❌ Predicted: (100.0, 100.0, 'HKD', 'hourly') | Expected: (100.0, 100.0, 'HKD', 'hourly')
# [970] ❌ Predicted: (80.0, 100.0, 'HKD', 'hourly') | Expected: (80.0, 100.0, 'HKD', 'hourly')
# [972] ✅ Matched:   None
# [973] ❌ Predicted: (3000.0, 3500.0, 'SGD', 'monthly') | Expected: (3000.0, 3500.0, 'SGD', 'monthly')
# [974] ✅ Matched:   None
# [975] ❌ Predicted: (61.0, 61.0, 'HKD', 'hourly') | Expected: (61.0, 61.0, 'HKD', 'hourly')
# [976] ✅ Matched:   None
# [977] ❌ Predicted: (80.0, 80.0, 'HKD', 'hourly') | Expected: (80.0, 80.0, 'HKD', 'hourly')
# [978] ✅ Matched:   (26.75, 29.66, 'NZD', 'hourly')
# [979] ✅ Matched:   (140.0, 167.0, 'SGD', 'monthly')
# [980] ✅ Matched:   None
# [981] ✅ Matched:   None
# [982] ✅ Matched:   (1250.0, 2000.0, 'SGD', 'monthly')
# [983] ❌ Predicted: (68.0, 80.0, 'HKD', 'hourly') | Expected: (68.0, 80.0, 'HKD', 'hourly')
# [984] ✅ Matched:   (10000.0, 10000.0, 'AUD', 'monthly')
# [985] ❌ Predicted: (88.0, 88.0, 'HKD', 'hourly') | Expected: (88.0, 88.0, 'HKD', 'hourly')
# [986] ✅ Matched:   (45.0, 45.0, 'AUD', 'monthly')
# [987] ✅ Matched:   None
# [988] ✅ Matched:   None
# [989] ❌ Predicted: (2600.0, 2900.0, 'SGD', 'monthly') | Expected: (2600.0, 2900.0, 'SGD', 'monthly')
# [991] ✅ Matched:   None
# [992] ✅ Matched:   None
# [994] ✅ Matched:   (34.0, 38.0, 'AUD', 'monthly')
# [996] ✅ Matched:   None
# [997] ✅ Matched:   None
# [999] ✅ Matched:   (23.65, 23.65, 'NZD', 'hourly')
# [1000] ❌ Predicted: (90.0, 130.0, 'HKD', 'hourly') | Expected: (90.0, 130.0, 'HKD', 'hourly')
# [1001] ❌ Predicted: (26.0, 26.0, 'NZD', 'hourly') | Expected: (26.0, 26.0, 'NZD', 'hourly')
# [1002] ❌ Predicted: (1000.0, 1500.0, 'SGD', 'weekly') | Expected: (1000.0, 1500.0, 'SGD', 'weekly')
# [1003] ✅ Matched:   None
# [1004] ✅ Matched:   None
# [1005] ❌ Predicted: (1800.0, 1800.0, 'MYR', 'monthly') | Expected: (1800.0, 1800.0, 'MYR', 'monthly')
# [1006] ❌ Predicted: (50.0, 50.0, 'AUD', 'hourly') | Expected: (50.0, 50.0, 'AUD', 'hourly')
# [1007] ✅ Matched:   None
# [1008] ✅ Matched:   None
# [1009] ✅ Matched:   (30.0, 35.0, 'AUD', 'monthly')
# [1010] ✅ Matched:   None
# [1011] ✅ Matched:   None
# [1012] ❌ Predicted: (3000.0, 3600.0, 'MYR', 'monthly') | Expected: (3000.0, 3600.0, 'MYR', 'monthly')
# [1013] ❌ Predicted: (70.0, 70.0, 'HKD', 'hourly') | Expected: (70.0, 70.0, 'HKD', 'hourly')
# [1014] ✅ Matched:   None
# [1015] ✅ Matched:   None
# [1016] ❌ Predicted: (65.0, 75.0, 'HKD', 'hourly') | Expected: (65.0, 75.0, 'HKD', 'hourly')
# [1017] ✅ Matched:   (600.0, 600.0, 'HKD', 'monthly')
# [1018] ✅ Matched:   (60.0, 80.0, 'HKD', 'monthly')
# [1019] ✅ Matched:   None
# [1020] ❌ Predicted: (2600.0, 3500.0, 'SGD', 'monthly') | Expected: (2600.0, 3500.0, 'SGD', 'monthly')
# [1021] ✅ Matched:   None
# [1022] ✅ Matched:   None
# [1023] ✅ Matched:   None
# [1024] ✅ Matched:   None
# [1026] ❌ Predicted: (35000.0, 35000.0, 'THB', 'monthly') | Expected: (35000.0, 35000.0, 'THB', 'monthly')
# [1027] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [1028] ❌ Predicted: (2100.0, 2500.0, 'SGD', 'monthly') | Expected: (2100.0, 2500.0, 'SGD', 'monthly')
# ...
# [1929] ✅ Matched:   None
# [1930] ✅ Matched:   None
# [1931] ❌ Predicted: (14000.0, 15000.0, 'HKD', 'monthly') | Expected: (14000.0, 15000.0, 'HKD', 'monthly')
# [1932] ❌ Predicted: (60.0, 65.0, 'HKD', 'hourly') | Expected: (60.0, 65.0, 'HKD', 'hourly')
# [1933] ✅ Matched:   (100.0, 140.0, 'AUD', 'monthly')
# [1934] ✅ Matched:   (3000.0, 3000.0, 'MYR', 'monthly')
# [1937] ✅ Matched:   None
# [1938] ✅ Matched:   (25.39, 29.95, 'NZD', 'hourly')
# [1939] ✅ Matched:   (37.36, 37.36, 'AUD', 'hourly')
# [1940] ❌ Predicted: (60.0, 65.0, 'HKD', 'hourly') | Expected: (60.0, 65.0, 'HKD', 'hourly')
# [1941] ✅ Matched:   None
# [1942] ✅ Matched:   (2000.0, 2000.0, 'HKD', 'monthly')
# [1943] ✅ Matched:   None
# [1944] ✅ Matched:   (583.0, 583.0, 'HKD', 'monthly')
# [1945] ❌ Predicted: (70.0, 75.0, 'HKD', 'hourly') | Expected: (70.0, 75.0, 'HKD', 'hourly')
# [1946] ✅ Matched:   None
# [1947] ✅ Matched:   None
# [1948] ✅ Matched:   (150.0, 150.0, 'HKD', 'hourly')
# [1949] ❌ Predicted: (3000.0, 4000.0, 'SGD', 'monthly') | Expected: (3000.0, 4000.0, 'SGD', 'monthly')
# [1950] ✅ Matched:   (2800.0, 4500.0, 'SGD', 'daily')
# [1951] ✅ Matched:   None
# [1952] ✅ Matched:   None
# [1953] ✅ Matched:   None
# [1954] ✅ Matched:   (37.9, 37.9, 'AUD', 'hourly')
# [1955] ✅ Matched:   None
# [1957] ✅ Matched:   (29.08, 29.08, 'AUD', 'annual')
# [1958] ✅ Matched:   (36.0, 36.0, 'AUD', 'monthly')
# [1959] ✅ Matched:   None
# [1960] ✅ Matched:   (2100.0, 2800.0, 'SGD', 'monthly')
# [1961] ✅ Matched:   (129235.88, 129235.88, 'AUD', 'annual')
# [1962] ❌ Predicted: (75.0, 75.0, 'HKD', 'hourly') | Expected: (75.0, 75.0, 'HKD', 'hourly')
# [1963] ✅ Matched:   (27.5, 27.5, 'NZD', 'hourly')
# [1964] ❌ Predicted: (20000.0, 20000.0, 'PHP', 'monthly') | Expected: (20000.0, 20000.0, 'PHP', 'monthly')
# [1965] ✅ Matched:   (13.5, 13.5, 'SGD', 'hourly')
# [1966] ❌ Predicted: (5000.0, 6000.0, 'SGD', 'monthly') | Expected: (5000.0, 6000.0, 'SGD', 'monthly')
# [1967] ✅ Matched:   (31.36, 39.82, 'AUD', 'monthly')
# [1968] ✅ Matched:   None
# [1969] ✅ Matched:   (67357.32, 94568.44, 'AUD', 'annual')
# [1970] ✅ Matched:   (20.0, 20.0, 'AUD', 'weekly')
# [1971] ✅ Matched:   (56.3, 77.5, 'AUD', 'monthly')
# [1972] ❌ Predicted: (70.0, 70.0, 'HKD', 'hourly') | Expected: (70.0, 70.0, 'HKD', 'hourly')
# [1973] ❌ Predicted: (45.0, 45.0, 'HKD', 'hourly') | Expected: (45.0, 45.0, 'HKD', 'hourly')
# [1974] ❌ Predicted: (1500.0, 1500.0, 'MYR', 'monthly') | Expected: (1500.0, 1500.0, 'MYR', 'monthly')
# [1975] ❌ Predicted: (65.0, 65.0, 'HKD', 'hourly') | Expected: (65.0, 65.0, 'HKD', 'hourly')
# [1976] ✅ Matched:   (82928.0, 117928.0, 'NZD', 'monthly')
# [1978] ✅ Matched:   (15900.0, 15900.0, 'AUD', 'monthly')
# [1979] ✅ Matched:   (4.0, 8.0, 'HKD', 'hourly')
# [1980] ✅ Matched:   None
# [1981] ✅ Matched:   None
# [1982] ❌ Predicted: (60.0, 80.0, 'HKD', 'hourly') | Expected: (60.0, 80.0, 'HKD', 'hourly')
# [1984] ✅ Matched:   None
# [1985] ❌ Predicted: (20000.0, 30000.0, 'THB', 'monthly') | Expected: (20000.0, 30000.0, 'THB', 'monthly')
# [1986] ✅ Matched:   (2500.0, 35005.0, 'SGD', 'monthly')
# [1987] ❌ Predicted: (48.0, 50.0, 'HKD', 'hourly') | Expected: (48.0, 50.0, 'HKD', 'hourly')
# [1988] ✅ Matched:   None
# [1989] ✅ Matched:   None
# [1991] ❌ Predicted: (2500.0, 3000.0, 'SGD', 'monthly') | Expected: (2500.0, 3000.0, 'SGD', 'monthly')
# [1992] ❌ Predicted: (67.0, 83.0, 'MYR', 'daily') | Expected: (67.0, 83.0, 'MYR', 'daily')
# [1993] ✅ Matched:   None
# [1994] ✅ Matched:   (24.0, 24.0, 'NZD', 'monthly')
# [1996] ✅ Matched:   None
# [1998] ❌ Predicted: (67500.0, 67500.0, 'AUD', 'annual') | Expected: (67500.0, 67500.0, 'AUD', 'annual')
# [1999] ✅ Matched:   None
# [2000] ✅ Matched:   None
# [2001] ✅ Matched:   None
# [2002] ✅ Matched:   None
# [2003] ✅ Matched:   None
# [2004] ✅ Matched:   None
# [2005] ✅ Matched:   None
# [2006] ✅ Matched:   None
# [2007] ✅ Matched:   None
# [2008] ✅ Matched:   None
# [2009] ✅ Matched:   None
# [2010] ❌ Predicted: (3000.0, 3500.0, 'SGD', 'monthly') | Expected: (3000.0, 3500.0, 'SGD', 'monthly')
# [2011] ✅ Matched:   (417.0, 417.0, 'HKD', 'monthly')
# [2012] ✅ Matched:   (25.21, 25.86, 'AUD', 'annual')
# [2014] ✅ Matched:   None
# [2015] ✅ Matched:   None
# [2016] ✅ Matched:   (2000.0, 30005.0, 'SGD', 'monthly')
# [2017] ❌ Predicted: (100.0, 150.0, 'HKD', 'hourly') | Expected: (100.0, 150.0, 'HKD', 'hourly')
# [2018] ✅ Matched:   None
# [2021] ✅ Matched:   (3000.0, 3000.0, 'MYR', 'monthly')
# [2022] ✅ Matched:   None
# [2023] ✅ Matched:   (117.0, 200.0, 'SGD', 'monthly')
# [2025] ❌ Predicted: (160000.0, 180000.0, 'AUD', 'annual') | Expected: (160000.0, 180000.0, 'AUD', 'annual')
# [2028] ✅ Matched:   None
# [2030] ✅ Matched:   None
# [2031] ✅ Matched:   None
# [2032] ✅ Matched:   None
# [2034] ✅ Matched:   None
# [2035] ✅ Matched:   (2000.0, 2000.0, 'MYR', 'monthly')
# [2036] ❌ Predicted: (12000.0, 25000.0, 'THB', 'monthly') | Expected: (12000.0, 25000.0, 'THB', 'monthly')
# [2037] ❌ Predicted: (60.0, 60.0, 'HKD', 'hourly') | Expected: (60.0, 60.0, 'HKD', 'hourly')
# [2039] ✅ Matched:   None
# [2040] ❌ Predicted: (3000.0, 4500.0, 'SGD', 'monthly') | Expected: (3000.0, 4500.0, 'SGD', 'monthly')
# [2042] ✅ Matched:   (70.0, 70.0, 'MYR', 'hourly')
# [2044] ✅ Matched:   None
# [2045] ✅ Matched:   None
# [2046] ✅ Matched:   (26.24, 26.24, 'NZD', 'hourly')
# [2047] ✅ Matched:   (48.0, 60.5, 'HKD', 'hourly')
# [2048] ✅ Matched:   (825.0, 825.0, 'SGD', 'weekly')
# [2050] ✅ Matched:   (1700.0, 1700.0, 'MYR', 'monthly')
# [2051] ❌ Predicted: (70.0, 75.0, 'HKD', 'hourly') | Expected: (70.0, 75.0, 'HKD', 'hourly')
# [2052] ❌ Predicted: (4000.0, 5000.0, 'SGD', 'monthly') | Expected: (4000.0, 5000.0, 'SGD', 'monthly')
# [2053] ✅ Matched:   None
# [2054] ❌ Predicted: (65000.0, 95000.0, 'THB', 'monthly') | Expected: (65000.0, 95000.0, 'THB', 'monthly')
# [2055] ✅ Matched:   None
# [2056] ✅ Matched:   None
# [2057] ✅ Matched:   (2000.0, 2000.0, 'SGD', 'monthly')
# [2058] ✅ Matched:   None
# [2059] ❌ Predicted: (150.0, 283.0, 'SGD', 'daily') | Expected: (150.0, 283.0, 'SGD', 'daily')
# [2060] ✅ Matched:   None
# [2061] ✅ Matched:   (10000.0, 10000.0, 'AUD', 'monthly')
# [2062] ✅ Matched:   None
# [2063] ✅ Matched:   (67357.32, 94568.44, 'AUD', 'annual')
# [2064] ✅ Matched:   None
# [2065] ✅ Matched:   None
# [2066] ✅ Matched:   None
# [2067] ✅ Matched:   (30.71, 30.71, 'AUD', 'hourly')
# [2068] ✅ Matched:   None
# [2069] ✅ Matched:   None
# [2070] ✅ Matched:   None
# [2071] ✅ Matched:   (29.7, 30.01, 'AUD', 'monthly')
# [2072] ✅ Matched:   None
# [2074] ✅ Matched:   (1500.0, 1500.0, 'SGD', 'monthly')
# [2075] ✅ Matched:   None
# [2076] ✅ Matched:   (67357.32, 94568.44, 'AUD', 'annual')
# [2077] ❌ Predicted: (37.0, 46.0, 'NZD', 'hourly') | Expected: (37.0, 46.0, 'NZD', 'hourly')
# [2078] ✅ Matched:   None
# [2079] ✅ Matched:   (30.71, 30.71, 'AUD', 'hourly')
# [2080] ✅ Matched:   (23.65, 25.0, 'NZD', 'hourly')
# [2082] ✅ Matched:   (135591.23, 138111.46, 'AUD', 'annual')
# [2083] ❌ Predicted: (1500.0, 1500.0, 'MYR', 'monthly') | Expected: (1500.0, 1500.0, 'MYR', 'monthly')
# [2084] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [2085] ✅ Matched:   None
# [2086] ❌ Predicted: (2000.0, 2200.0, 'SGD', 'monthly') | Expected: (2000.0, 2200.0, 'SGD', 'monthly')
# [2087] ❌ Predicted: (625.0, 750.0, 'SGD', 'weekly') | Expected: (625.0, 750.0, 'SGD', 'weekly')
# [2088] ✅ Matched:   (2500.0, 2500.0, 'MYR', 'monthly')
# [2089] ✅ Matched:   None
# [2090] ✅ Matched:   None
# [2091] ✅ Matched:   None
# [2092] ❌ Predicted: (36000.0, 36000.0, 'PHP', 'monthly') | Expected: (36000.0, 36000.0, 'PHP', 'monthly')
# [2093] ❌ Predicted: (24.0, 24.0, 'HKD', 'monthly') | Expected: None
# [2094] ✅ Matched:   None
# [2095] ❌ Predicted: (800.0, 800.0, 'SGD', 'monthly') | Expected: (800.0, 800.0, 'SGD', 'monthly')
# [2096] ❌ Predicted: (875.0, 1000.0, 'SGD', 'weekly') | Expected: (875.0, 1000.0, 'SGD', 'weekly')
# [2097] ❌ Predicted: (2400.0, 3000.0, 'SGD', 'monthly') | Expected: (2400.0, 3000.0, 'SGD', 'monthly')
# [2098] ✅ Matched:   None
# [2099] ✅ Matched:   (3500.0, 3500.0, 'SGD', 'monthly')
# [2101] ✅ Matched:   (10000.0, 10000.0, 'AUD', 'monthly')
# [2102] ❌ Predicted: (17000.0, 17000.0, 'PHP', 'monthly') | Expected: (17000.0, 17000.0, 'PHP', 'monthly')
# [2103] ❌ Predicted: (120000.0, 120000.0, 'THB', 'monthly') | Expected: (120000.0, 120000.0, 'THB', 'monthly')
# [2104] ✅ Matched:   (21.3, 21.3, 'NZD', 'hourly')
# [2105] ✅ Matched:   None
# [2106] ❌ Predicted: (4750.0, 4750.0, 'HKD', 'weekly') | Expected: (4750.0, 4750.0, 'HKD', 'weekly')
# [2107] ✅ Matched:   (2000.0, 2000.0, 'HKD', 'monthly')
# [2108] ✅ Matched:   (45.0, 65.0, 'HKD', 'monthly')
# [2109] ❌ Predicted: (30.0, 38.0, 'AUD', 'hourly') | Expected: (30.0, 38.0, 'AUD', 'hourly')
# [2110] ✅ Matched:   (42.59, 42.59, 'AUD', 'hourly')
# [2112] ❌ Predicted: (85.0, 85.0, 'AUD', 'hourly') | Expected: (85.0, 85.0, 'AUD', 'hourly')
# [2113] ✅ Matched:   None
# [2116] ✅ Matched:   (70.0, 70.0, 'HKD', 'hourly')
# [2117] ✅ Matched:   None
# [2118] ❌ Predicted: (4000.0, 7000.0, 'SGD', 'monthly') | Expected: (4000.0, 7000.0, 'SGD', 'monthly')
# [2119] ✅ Matched:   None
# [2120] ✅ Matched:   None
# [2121] ✅ Matched:   (2800.0, 2800.0, 'SGD', 'monthly')
# [2122] ✅ Matched:   None
# [2123] ✅ Matched:   (28.0, 28.0, 'NZD', 'monthly')
# [2124] ✅ Matched:   None
# [2125] ✅ Matched:   None
# [2126] ❌ Predicted: (4000.0, 6000.0, 'SGD', 'monthly') | Expected: (4000.0, 6000.0, 'SGD', 'monthly')
# [2127] ✅ Matched:   (31.42, 31.42, 'AUD', 'monthly')
# [2128] ✅ Matched:   (48.0, 48.0, 'AUD', 'monthly')
# [2129] ✅ Matched:   None
# [2130] ❌ Predicted: (18400.0, 18400.0, 'PHP', 'monthly') | Expected: (18400.0, 18400.0, 'PHP', 'monthly')
# [2131] ✅ Matched:   (30.58, 30.58, 'AUD', 'hourly')
# [2132] ✅ Matched:   (27.0, 30.0, 'NZD', 'monthly')
# [2133] ✅ Matched:   None
# [2134] ✅ Matched:   None
# [2135] ✅ Matched:   None
# [2136] ✅ Matched:   None
# [2137] ✅ Matched:   (55000.0, 60000.0, 'AUD', 'monthly')
# [2138] ❌ Predicted: (89095.0, 139187.0, 'AUD', 'annual') | Expected: (89095.0, 139187.0, 'AUD', 'annual')
# [2139] ✅ Matched:   None
# [2140] ✅ Matched:   None
# [2141] ✅ Matched:   None
# [2142] ✅ Matched:   None
# [2143] ✅ Matched:   (105093.0, 108612.0, 'AUD', 'monthly')
# [2144] ✅ Matched:   None
# [2145] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [2146] ✅ Matched:   None
# [2148] ✅ Matched:   (55.24, 55.24, 'AUD', 'annual')
# [2149] ✅ Matched:   None
# [2150] ✅ Matched:   None
# [2151] ❌ Predicted: (30.0, 32.0, 'AUD', 'hourly') | Expected: (30.0, 32.0, 'AUD', 'hourly')
# [2152] ✅ Matched:   None
# [2153] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [2154] ❌ Predicted: (105093.0, 108612.0, 'AUD', 'annual') | Expected: (105093.0, 108612.0, 'AUD', 'annual')
# [2155] ✅ Matched:   (24.0, 24.0, 'NZD', 'weekly')
# [2157] ✅ Matched:   (150.0, 150.0, 'SGD', 'hourly')
# [2158] ✅ Matched:   None
# [2159] ✅ Matched:   None
# [2160] ✅ Matched:   None
# [2161] ✅ Matched:   None
# [2163] ✅ Matched:   (200.0, 200.0, 'NZD', 'monthly')
# [2164] ✅ Matched:   (39.0, 39.0, 'AUD', 'monthly')
# [2165] ✅ Matched:   None
# [2166] ✅ Matched:   (90000.0, 130000.0, 'AUD', 'monthly')
# [2167] ✅ Matched:   None
# [2168] ✅ Matched:   (41.76, 43.08, 'AUD', 'monthly')
# [2169] ✅ Matched:   None
# [2170] ✅ Matched:   (500.0, 625.0, 'HKD', 'monthly')
# [2171] ✅ Matched:   None
# [2172] ❌ Predicted: (2000.0, 2800.0, 'SGD', 'monthly') | Expected: (2000.0, 2800.0, 'SGD', 'monthly')
# [2173] ✅ Matched:   (43.6, 47.48, 'AUD', 'annual')
# [2175] ❌ Predicted: (16000.0, 16000.0, 'PHP', 'monthly') | Expected: (16000.0, 16000.0, 'PHP', 'monthly')
# [2176] ✅ Matched:   (500.0, 1000.0, 'SGD', 'monthly')
# [2178] ✅ Matched:   None
# [2179] ✅ Matched:   None
# [2180] ❌ Predicted: (52.0, 55.0, 'HKD', 'hourly') | Expected: (52.0, 55.0, 'HKD', 'hourly')
# [2181] ✅ Matched:   None
# [2183] ✅ Matched:   None
# [2184] ✅ Matched:   (2300.0, 2300.0, 'MYR', 'monthly')
# [2185] ✅ Matched:   (10000.0, 10000.0, 'AUD', 'monthly')
# [2186] ❌ Predicted: (25.0, 30.0, 'NZD', 'hourly') | Expected: (25.0, 30.0, 'NZD', 'hourly')
# [2187] ✅ Matched:   None
# [2188] ❌ Predicted: (28.0, 28.0, 'NZD', 'hourly') | Expected: (28.0, 28.0, 'NZD', 'hourly')
# [2189] ✅ Matched:   (105093.0, 108612.0, 'AUD', 'monthly')
# [2190] ✅ Matched:   None
# [2191] ✅ Matched:   (85000.0, 85000.0, 'AUD', 'annual')
# [2192] ✅ Matched:   None
# [2193] ❌ Predicted: (575.0, 650.0, 'SGD', 'weekly') | Expected: (575.0, 650.0, 'SGD', 'weekly')
# [2194] ✅ Matched:   (2000.0, 2000.0, 'MYR', 'monthly')
# [2195] ✅ Matched:   (38.0, 38.0, 'AUD', 'weekly')
# [2196] ✅ Matched:   None
# [2197] ✅ Matched:   None
# [2198] ✅ Matched:   (150.0, 200.0, 'HKD', 'monthly')
# [2199] ✅ Matched:   None
# [2200] ✅ Matched:   (25.0, 25.0, 'NZD', 'monthly')
# [2201] ✅ Matched:   (5000.0, 5000.0, 'AUD', 'monthly')
# [2203] ❌ Predicted: (2800.0, 3800.0, 'SGD', 'monthly') | Expected: (2800.0, 3800.0, 'SGD', 'monthly')
# [2204] ✅ Matched:   (38.8, 48.88, 'AUD', 'annual')
# [2205] ✅ Matched:   None
# [2206] ✅ Matched:   None
# [2207] ✅ Matched:   None
# [2208] ❌ Predicted: (35.0, 42.0, 'AUD', 'hourly') | Expected: (35.0, 42.0, 'AUD', 'hourly')
# [2209] ✅ Matched:   (4000.0, 4000.0, 'MYR', 'annual')
# [2210] ✅ Matched:   (49.88, 53.43, 'AUD', 'annual')
# [2211] ✅ Matched:   None
# [2212] ✅ Matched:   None
# [2213] ✅ Matched:   None
# [2214] ✅ Matched:   (9.0, 9.0, 'AUD', 'monthly')
# [2215] ❌ Predicted: (62.0, 65.0, 'HKD', 'hourly') | Expected: (62.0, 65.0, 'HKD', 'hourly')
# [2216] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [2220] ✅ Matched:   (36.0, 36.0, 'AUD', 'monthly')
# [2221] ❌ Predicted: (45.0, 60.0, 'HKD', 'hourly') | Expected: (45.0, 60.0, 'HKD', 'hourly')
# [2222] ✅ Matched:   None
# [2223] ✅ Matched:   (1800.0, 1800.0, 'SGD', 'monthly')
# [2224] ❌ Predicted: (117544.0, 120393.0, 'AUD', 'annual') | Expected: (117544.0, 120393.0, 'AUD', 'annual')
# [2225] ❌ Predicted: (4000.0, 5000.0, 'SGD', 'monthly') | Expected: (4000.0, 5000.0, 'SGD', 'monthly')
# [2226] ✅ Matched:   None
# [2227] ❌ Predicted: (55.0, 63.0, 'HKD', 'hourly') | Expected: (55.0, 63.0, 'HKD', 'hourly')
# [2228] ❌ Predicted: (700.0, 700.0, 'SGD', 'monthly') | Expected: (700.0, 700.0, 'SGD', 'monthly')
# [2229] ✅ Matched:   None
# [2230] ❌ Predicted: (73.0, 77.0, 'SGD', 'daily') | Expected: (73.0, 77.0, 'SGD', 'daily')
# [2231] ✅ Matched:   None
# [2232] ✅ Matched:   None
# [2233] ❌ Predicted: (25000.0, 25000.0, 'PHP', 'monthly') | Expected: (25000.0, 25000.0, 'PHP', 'monthly')
# [2234] ✅ Matched:   None
# [2235] ✅ Matched:   (27.75, 27.75, 'AUD', 'monthly')
# [2236] ✅ Matched:   (875.0, 875.0, 'SGD', 'monthly')
# [2238] ❌ Predicted: (1500.0, 1500.0, 'MYR', 'monthly') | Expected: (1500.0, 1500.0, 'MYR', 'monthly')
# [2239] ✅ Matched:   None
# [2240] ✅ Matched:   (29.0, 29.0, 'NZD', 'annual')
# [2241] ✅ Matched:   None
# [2242] ❌ Predicted: (100.0, 100.0, 'HKD', 'hourly') | Expected: (100.0, 100.0, 'HKD', 'hourly')
# [2243] ✅ Matched:   None
# [2244] ✅ Matched:   (90000.0, 90000.0, 'AUD', 'monthly')
# [2245] ✅ Matched:   (1900.0, 1900.0, 'MYR', 'monthly')
# [2246] ✅ Matched:   None
# [2247] ✅ Matched:   None
# [2248] ✅ Matched:   None
# [2249] ✅ Matched:   (15000.0, 15000.0, 'THB', 'monthly')
# [2250] ❌ Predicted: (161042.0, 180143.0, 'AUD', 'annual') | Expected: (161042.0, 180143.0, 'AUD', 'annual')
# [2251] ✅ Matched:   None
# [2252] ✅ Matched:   None
# [2253] ❌ Predicted: (85000.0, 90000.0, 'AUD', 'annual') | Expected: (85000.0, 90000.0, 'AUD', 'annual')
# [2254] ❌ Predicted: (40.0, 40.0, 'AUD', 'hourly') | Expected: (40.0, 40.0, 'AUD', 'hourly')
# [2255] ✅ Matched:   None
# [2256] ❌ Predicted: (17500.0, 17500.0, 'PHP', 'monthly') | Expected: (17500.0, 17500.0, 'PHP', 'monthly')
# [2257] ❌ Predicted: (81581.0, 108532.0, 'AUD', 'annual') | Expected: (81581.0, 108532.0, 'AUD', 'annual')
# [2258] ✅ Matched:   None
# [2259] ❌ Predicted: (18000.0, 18000.0, 'PHP', 'monthly') | Expected: (18000.0, 18000.0, 'PHP', 'monthly')
# [2260] ✅ Matched:   None
# [2261] ✅ Matched:   (2400.0, 2400.0, 'SGD', 'monthly')
# [2262] ✅ Matched:   None
# [2263] ✅ Matched:   None
# [2264] ✅ Matched:   None
# [2265] ❌ Predicted: (2500.0, 3000.0, 'SGD', 'monthly') | Expected: (2500.0, 3000.0, 'SGD', 'monthly')
# [2266] ✅ Matched:   None
# Total samples with actual info: 2267
# Number of correct predictions: 1498
# Accuracy: 0.6607851786501985
